# %%
import seml
import pandas as pd
from matplotlib import pyplot as plt
pd.options.display.max_columns = 100
# Out:
# /home/icb/leon.hetzel/miniconda3/envs/py38/lib/python3.8/site-packages/seml/database.py:5: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
results = seml.get_results('cpa_graphs_15', to_data_frame=True) # fields=['config', 'result', 'host']
print('Loaded Results')
# Out:
# ...
#   0%|          | 0/67 [00:00<?, ?it/s]
# Loaded Results
# /home/icb/leon.hetzel/miniconda3/envs/py38/lib/python3.8/site-packages/seml/evaluation.py:80: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   parsed = pd.io.json.json_normalize(parsed, sep='.')

# %%
results
# Out:
#     _id  config.overwrite config.db_collection  \
# 0     1                 1        cpa_graphs_15
# 1     3                 3        cpa_graphs_15
# 2     4                 4        cpa_graphs_15
# 3     5                 5        cpa_graphs_15
# 4     6                 6        cpa_graphs_15
# ..  ...               ...                  ...
# 62   96                96        cpa_graphs_15
# 63   97                97        cpa_graphs_15
# 64   98                98        cpa_graphs_15
# 65   99                99        cpa_graphs_15
# 66  100               100        cpa_graphs_15
#
#    config.dataset.data_params.covariate_keys  \
# 0                                  cell_type
# 1                                  cell_type
# 2                                  cell_type
# 3                                  cell_type
# 4                                  cell_type
# ..                                       ...
# 62                                 cell_type
# ...

# %%
# - How to evaluate?
