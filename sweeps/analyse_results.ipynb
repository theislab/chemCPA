# %%
import seml
import pandas as pd
from matplotlib import pyplot as plt
pd.options.display.max_columns = 100
# Out:
# /home/icb/leon.hetzel/miniconda3/envs/py38/lib/python3.8/site-packages/seml/database.py:5: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
results = seml.get_results('lincs_small_checkpoint_noGNN', to_data_frame=True) # fields=['config', 'result', 'host']
print('Loaded Results')
# Out:
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loaded Results

# %%
results
# Out:
#    _id  config.overwrite          config.db_collection  \
# 0    1                 1  lincs_small_checkpoint_noGNN
#
#   config.dataset.data_params.covariate_keys  \
# 0                                   cell_id
#
#   config.dataset.data_params.dataset_path config.dataset.data_params.dose_key  \
# 0              datasets/lincs_smiles.h5ad                           pert_dose
#
#   config.dataset.data_params.mol_featurizer  \
# 0                                 canonical
#
#   config.dataset.data_params.perturbation_key  \
# 0                                     pert_id
#
#   config.dataset.data_params.smiles_key config.dataset.data_params.split_key  \
# 0                      canonical_smiles                               split1
#
#   config.dataset.dataset_type  \
# 0                       lincs
#
#   config.model.additional_params.decoder_activation  \
# 0                                            linear
#
#   config.model.additional_params.doser_type  \
# ...

# %%
# - How to evaluate?
