# %%
import json
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from tqdm.auto import tqdm

from utils import load_smiles, compute_pred_ctrl,load_dataset

from chemCPA.data import load_dataset_splits
from chemCPA.paths import DATA_DIR, FIGURE_DIR, PROJECT_DIR, ROOT

# %%
pd.set_option('display.max_columns', 200)

# %%
# %load_ext lab_black
# %load_ext autoreload
# %autoreload 2
# Out:
# The lab_black extension is already loaded. To reload it, use:
#   %reload_ext lab_black
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
seml_collection = "baseline_comparison"

# %%
seml_collection = "baseline_comparison"

base_hash_dict = dict(
    baseline_A549="044c4dba0c8719985c3622834f2cbd58",
    baseline_K562="5ea85d5dd7abd5962d1d3eeff1b8c1ff",
    baseline_MCF7="4d98e7d857f497d870e19c6d12175aaa",
)

# %%
def load_config(seml_collection, model_hash):
    file_path = PROJECT_DIR / f"{seml_collection}.json"  # Provide path to json

    with open(file_path) as f:
        file_data = json.load(f)

    for _config in tqdm(file_data):
        if _config["config_hash"] == model_hash:
            # print(config)
            config = _config["config"]
            config["config_hash"] = _config["config_hash"]
    return config

# %%
config = load_config(seml_collection, base_hash_dict['baseline_A549'])

config["dataset"]["data_params"]["dataset_path"] = DATA_DIR/ "sciplex_complete_middle_subset_lincs_genes.h5ad"
config["model"]["embedding"]["directory"] = (
    ROOT / config["model"]["embedding"]["directory"]
)

dataset, key_dict = load_dataset(config)

config["dataset"]["n_vars"] = dataset.n_vars

canon_smiles_unique_sorted, smiles_to_pathway_map, smiles_to_drug_map = load_smiles(
    config, dataset, key_dict, True
)
# model_pretrained, embedding_pretrained = load_model(config, canon_smiles_unique_sorted)
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]

# %%
data_params = config["dataset"]["data_params"]
data_params['split_key'] = 'split_random'
datasets, dataset_all = load_dataset_splits(**data_params, return_dataset=True)

# %%
data_params
# Out:
# {'covariate_keys': 'cell_type',
#  'dataset_path': PosixPath('/nfs/staff-ssd/hetzell/code/chemCPA_v2/project_folder/datasets/sciplex_complete_middle_subset_lincs_genes.h5ad'),
#  'degs_key': 'lincs_DEGs',
#  'dose_key': 'dose',
#  'pert_category': 'cov_drug_dose_name',
#  'perturbation_key': 'condition',
#  'smiles_key': 'SMILES',
#  'split_key': 'split_random',
#  'use_drugs_idx': True}

# %%
dosages = [1e1, 1e2, 1e3, 1e4]
cell_lines = ["A549", "K562", "MCF7"]
use_DEGs = True

# %%
len(pd.Series(dataset_all.pert_categories).unique())
# Out:
# 2247

# %%
def get_baseline_predictions(
    hash,
    seml_collection="baseline_comparison",
    smiles=None,
    dosages=[1e1, 1e2, 1e3, 1e4],
    cell_lines=["A549", "K562", "MCF7"],
    use_DEGs=False,
    verbose=False,
    name_tag=None,
):
    if smiles is None:
        smiles = canon_smiles_unique_sorted

    config = load_config(seml_collection, hash)
    config["dataset"]["n_vars"] = dataset.n_vars
    config["dataset"]["data_params"]["dataset_path"] = (
        ROOT / config["dataset"]["data_params"]["dataset_path"]
    )
    config["model"]["embedding"]["directory"] = (
        ROOT / config["model"]["embedding"]["directory"]
    )
    data_params = config["dataset"]["data_params"]
    datasets = load_dataset_splits(**data_params, return_dataset=False)

    predictions, _ = compute_pred_ctrl(
        dataset_all,
        dataset_ctrl=datasets["test_control"],
        # dataset_ctrl=datasets["training_control"],
        dosages=dosages,
        cell_lines=cell_lines,
        use_DEGs=use_DEGs,
        verbose=verbose,
    )

    predictions = pd.DataFrame.from_dict(predictions, orient="index", columns=["R2"])
    if name_tag:
        predictions["model"] = name_tag
    predictions["genes"] = "degs" if use_DEGs else "all"
    return predictions

# %%
# drug_r2_baseline_degs, _ = compute_pred_ctrl(
#     dataset=datasets["ood"],
#     dataset_ctrl=datasets["test_control"],
#     dosages=dosages,
#     cell_lines=cell_lines,
#     use_DEGs=True,
#     verbose=False,
# )

# drug_r2_baseline_all, _ = compute_pred_ctrl(
#     dataset=datasets["ood"],
#     dataset_ctrl=datasets["test_control"],
#     dosages=dosages,
#     cell_lines=cell_lines,
#     use_DEGs=False,
#     verbose=False,
# )
predictions = []

predictions.extend(
    [
        get_baseline_predictions(_hash, name_tag=name_tag, use_DEGs=True)
        for name_tag, _hash in base_hash_dict.items()
    ]
)

predictions.extend(
    [
        get_baseline_predictions(_hash, name_tag=name_tag, use_DEGs=False)
        for name_tag, _hash in base_hash_dict.items()
    ]
)
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# ['A549', 'K562', 'MCF7']
# 0it [00:00, ?it/s]
#   0%|          | 0/9 [00:00<?, ?it/s]
# ['A549', 'K562', 'MCF7']
# 0it [00:00, ?it/s]
#   0%|          | 0/9 [00:00<?, ?it/s]
# ['A549', 'K562', 'MCF7']
# 0it [00:00, ?it/s]
#   0%|          | 0/9 [00:00<?, ?it/s]
# ['A549', 'K562', 'MCF7']
# 0it [00:00, ?it/s]
#   0%|          | 0/9 [00:00<?, ?it/s]
# ['A549', 'K562', 'MCF7']
# 0it [00:00, ?it/s]
#   0%|          | 0/9 [00:00<?, ?it/s]
# ['A549', 'K562', 'MCF7']
# 0it [00:00, ?it/s]

# %%
predictions
# Out:
# [                                     R2          model genes
#  A549_(+)-JQ1_0.001             0.977773  baseline_A549  degs
#  A549_(+)-JQ1_0.01              0.961488  baseline_A549  degs
#  A549_(+)-JQ1_0.1               0.877050  baseline_A549  degs
#  A549_(+)-JQ1_1.0               0.819917  baseline_A549  degs
#  A549_2-Methoxyestradiol_0.001  0.913421  baseline_A549  degs
#  ...                                 ...            ...   ...
#  MCF7_ZM_1.0                    0.966686  baseline_A549  degs
#  MCF7_Zileuton_0.001            0.986553  baseline_A549  degs
#  MCF7_Zileuton_0.01             0.991991  baseline_A549  degs
#  MCF7_Zileuton_0.1              0.989118  baseline_A549  degs
#  MCF7_Zileuton_1.0              0.993228  baseline_A549  degs
#
#  [2244 rows x 3 columns],
#                                       R2          model genes
#  A549_(+)-JQ1_0.001             0.977773  baseline_K562  degs
#  A549_(+)-JQ1_0.01              0.961488  baseline_K562  degs
#  A549_(+)-JQ1_0.1               0.877050  baseline_K562  degs
#  A549_(+)-JQ1_1.0               0.819917  baseline_K562  degs
#  A549_2-Methoxyestradiol_0.001  0.913421  baseline_K562  degs
#  ...                                 ...            ...   ...
#  MCF7_ZM_1.0                    0.966686  baseline_K562  degs
#  MCF7_Zileuton_0.001            0.986553  baseline_K562  degs
#  MCF7_Zileuton_0.01             0.991991  baseline_K562  degs
#  MCF7_Zileuton_0.1              0.989118  baseline_K562  degs
#  MCF7_Zileuton_1.0              0.993228  baseline_K562  degs
#
#  [2244 rows x 3 columns],
#                                       R2          model genes
#  A549_(+)-JQ1_0.001             0.977773  baseline_MCF7  degs
#  A549_(+)-JQ1_0.01              0.961488  baseline_MCF7  degs
#  A549_(+)-JQ1_0.1               0.877050  baseline_MCF7  degs
#  A549_(+)-JQ1_1.0               0.819917  baseline_MCF7  degs
#  A549_2-Methoxyestradiol_0.001  0.913421  baseline_MCF7  degs
#  ...                                 ...            ...   ...
#  MCF7_ZM_1.0                    0.966686  baseline_MCF7  degs
#  MCF7_Zileuton_0.001            0.986553  baseline_MCF7  degs
#  MCF7_Zileuton_0.01             0.991991  baseline_MCF7  degs
#  MCF7_Zileuton_0.1              0.989118  baseline_MCF7  degs
#  MCF7_Zileuton_1.0              0.993228  baseline_MCF7  degs
#
#  [2244 rows x 3 columns],
#                                       R2          model genes
#  A549_(+)-JQ1_0.001             0.910030  baseline_A549   all
#  A549_(+)-JQ1_0.01              0.908907  baseline_A549   all
#  A549_(+)-JQ1_0.1               0.885839  baseline_A549   all
#  A549_(+)-JQ1_1.0               0.850111  baseline_A549   all
#  A549_2-Methoxyestradiol_0.001  0.920125  baseline_A549   all
#  ...                                 ...            ...   ...
#  MCF7_ZM_1.0                    0.982842  baseline_A549   all
#  MCF7_Zileuton_0.001            0.985591  baseline_A549   all
#  MCF7_Zileuton_0.01             0.989460  baseline_A549   all
#  MCF7_Zileuton_0.1              0.989548  baseline_A549   all
#  MCF7_Zileuton_1.0              0.991491  baseline_A549   all
#
#  [2244 rows x 3 columns],
#                                       R2          model genes
#  A549_(+)-JQ1_0.001             0.910030  baseline_K562   all
#  A549_(+)-JQ1_0.01              0.908907  baseline_K562   all
#  A549_(+)-JQ1_0.1               0.885839  baseline_K562   all
#  A549_(+)-JQ1_1.0               0.850111  baseline_K562   all
#  A549_2-Methoxyestradiol_0.001  0.920125  baseline_K562   all
#  ...                                 ...            ...   ...
#  MCF7_ZM_1.0                    0.982842  baseline_K562   all
#  MCF7_Zileuton_0.001            0.985591  baseline_K562   all
#  MCF7_Zileuton_0.01             0.989460  baseline_K562   all
#  MCF7_Zileuton_0.1              0.989548  baseline_K562   all
#  MCF7_Zileuton_1.0              0.991491  baseline_K562   all
#
#  [2244 rows x 3 columns],
#                                       R2          model genes
#  A549_(+)-JQ1_0.001             0.910030  baseline_MCF7   all
#  A549_(+)-JQ1_0.01              0.908907  baseline_MCF7   all
#  A549_(+)-JQ1_0.1               0.885839  baseline_MCF7   all
#  A549_(+)-JQ1_1.0               0.850111  baseline_MCF7   all
#  A549_2-Methoxyestradiol_0.001  0.920125  baseline_MCF7   all
#  ...                                 ...            ...   ...
#  MCF7_ZM_1.0                    0.982842  baseline_MCF7   all
#  MCF7_Zileuton_0.001            0.985591  baseline_MCF7   all
#  MCF7_Zileuton_0.01             0.989460  baseline_MCF7   all
#  MCF7_Zileuton_0.1              0.989548  baseline_MCF7   all
#  MCF7_Zileuton_1.0              0.991491  baseline_MCF7   all
#
#  [2244 rows x 3 columns]]

# %%
def rename_model(str):
    str_list = str.split("_")
    if len(str_list) == 2:
        return str_list[0]
    else:
        assert len(str_list) == 3
        return "_".join([str_list[0], str_list[2]])

# %%
predictions = pd.concat(predictions)
predictions.reset_index(inplace=True)
predictions["cell_type"] = predictions["index"].apply(lambda s: s.split("_")[0])
predictions["condition"] = predictions["index"].apply(lambda s: s.split("_")[1])
predictions["dose"] = predictions["index"].apply(lambda s: s.split("_")[2])
predictions["model_ct"] = predictions["model"]
predictions["model"] = predictions["model"].apply(rename_model)

# %%
predictions['dose'].unique()
# Out:
# array(['0.001', '0.01', '0.1', '1.0'], dtype=object)

# %%
cond = (predictions['genes']=='degs') & (predictions['dose']=='1.0')
predictions[cond].groupby(['condition']).mean().sort_values('R2')
# Out:
#                            R2
# condition
# Panobinostat         0.000000
# Quisinostat          0.000000
# AR-42                0.000000
# Bisindolylmaleimide  0.004051
# Dacinostat           0.013970
# ...                       ...
# Aminoglutethimide    0.975252
# Zileuton             0.976290
# Amisulpride          0.976606
# Meprednisone         0.983226
# Lenalidomide         0.983726
#
# [187 rows x 1 columns]

# %%
mean_df = predictions[cond].groupby(['condition']).mean().sort_values('R2')
mol_set = set(mean_df.index[:50])

# %%
std_df = predictions[cond].groupby(['condition']).std().sort_values('R2')
std_df.rename(columns={"R2": "R2_std"}, inplace=True)

# %%
std_df
# Out:
#                        R2_std
# condition
# Quisinostat          0.000000
# Panobinostat         0.000000
# AR-42                0.000000
# Lenalidomide         0.002868
# Bisindolylmaleimide  0.006076
# ...                       ...
# Entinostat           0.377008
# Fluorouracil         0.391580
# Flavopiridol         0.408244
# Raltitrexed          0.414432
# Azacitidine          0.431641
#
# [187 rows x 1 columns]

# %%
mean_df
# Out:
#                            R2
# condition
# Panobinostat         0.000000
# Quisinostat          0.000000
# AR-42                0.000000
# Bisindolylmaleimide  0.004051
# Dacinostat           0.013970
# ...                       ...
# Aminoglutethimide    0.975252
# Zileuton             0.976290
# Amisulpride          0.976606
# Meprednisone         0.983226
# Lenalidomide         0.983726
#
# [187 rows x 1 columns]

# %%
df = pd.concat([mean_df, std_df], axis=1)

# %%
df_subset = df[(df['R2']<0.784) & (df['R2_std']<0.3)]
len(df_subset)
# Out:
# 45

# %%
ood_drugs = df_subset.sample(frac=1).index.to_list()

# %%
import scanpy as sc
adata_sciplex = sc.read(DATA_DIR/ "sciplex_complete_middle_subset_lincs_genes.h5ad")

# %%
pd.crosstab(adata_sciplex.obs['split_ood_multi_task'], adata_sciplex.obs['condition'].isin(['control']))
# Out:
# condition              False   True
# split_ood_multi_task
# ood                    11850      0
# test                   28338   1132
# train                 301448  11872

# %%
print(adata_sciplex.obs.dose.unique())
adata_sciplex = adata_sciplex[adata_sciplex.obs.dose.isin([0., 1e3])].copy()
# Out:
# [ 1000.     0.   100. 10000.    10.]

# %%
i = 0
n_drugs = 5
drug_sets = []
for j in range(n_drugs, len(ood_drugs), n_drugs):
    drug_set = ood_drugs[i:j+n_drugs]
    if (j+n_drugs) > len(ood_drugs):
        drug_set += ood_drugs[:2*n_drugs-len(drug_set)]
    i = j
    drug_sets.append(drug_set)

# %%
[print(s) for s in drug_sets]
# Out:
# ['YM155', 'Pracinostat', 'Givinostat', 'Trichostatin', 'TAK-901', 'TMP195', 'Resminostat', 'Trametinib', '(+)-JQ1', 'JNJ-7706621']
# ['TMP195', 'Resminostat', 'Trametinib', '(+)-JQ1', 'JNJ-7706621', 'Quisinostat', 'FLLL32', 'Momelotinib', 'Rigosertib', 'Cyclocytidine']
# ['Quisinostat', 'FLLL32', 'Momelotinib', 'Rigosertib', 'Cyclocytidine', 'CUDC-101', 'Fedratinib', 'Bisindolylmaleimide', 'AT9283', 'Dasatinib']
# ['CUDC-101', 'Fedratinib', 'Bisindolylmaleimide', 'AT9283', 'Dasatinib', 'UNC0379', 'Triamcinolone', 'Cediranib', 'PFI-1', 'Toremifene']
# ['UNC0379', 'Triamcinolone', 'Cediranib', 'PFI-1', 'Toremifene', 'CUDC-907', 'Tucidinostat', 'Nintedanib', 'Dacinostat', 'Pirarubicin']
# ['CUDC-907', 'Tucidinostat', 'Nintedanib', 'Dacinostat', 'Pirarubicin', 'Regorafenib', 'M344', 'SGI-1776', 'PHA-680632', 'Obatoclax']
# ['Regorafenib', 'M344', 'SGI-1776', 'PHA-680632', 'Obatoclax', 'KW-2449', 'Panobinostat', 'Belinostat', 'AR-42', 'ENMD-2076']
# ['KW-2449', 'Panobinostat', 'Belinostat', 'AR-42', 'ENMD-2076', 'Bosutinib', 'Danusertib', 'Sorafenib', 'Abexinostat', 'Tanespimycin']
# [None, None, None, None, None, None, None, None]

# %%
for i, drug_set in enumerate(drug_sets):
    for cell_type in adata_sciplex.obs.cell_type.unique():
        split = f'split_fold{i}_{cell_type}'
        print(split)
        adata_sciplex.obs[split] = adata_sciplex.obs['split_ood_multi_task']
        adata_sciplex.obs.loc[adata_sciplex.obs[split] == 'ood', split] = 'train'
        adata_sciplex.obs.loc[adata_sciplex.obs['condition'].isin(drug_set), split] = 'ood'

        sub_df = adata_sciplex.obs.loc[adata_sciplex.obs[split].isin(['ood']) * (adata_sciplex.obs.cell_type != cell_type)]
        train_test = sub_df.index
        test = sub_df.sample(frac=0.5).index 
        
        sub_df2 = adata_sciplex.obs.loc[adata_sciplex.obs[split].isin(['train'])]
        train_test2 = sub_df2.index
        test2 = sub_df.sample(frac=0.05).index 

        adata_sciplex.obs.loc[train_test,split] = 'train'
        adata_sciplex.obs.loc[test,split] = 'test'
        adata_sciplex.obs.loc[train_test2,split] = 'train'
        adata_sciplex.obs.loc[test2,split] = 'test'
# Out:
# split_fold0_A549
# split_fold0_MCF7
# split_fold0_K562
# split_fold1_A549
# split_fold1_MCF7
# split_fold1_K562
# split_fold2_A549
# split_fold2_MCF7
# split_fold2_K562
# split_fold3_A549
# split_fold3_MCF7
# split_fold3_K562
# split_fold4_A549
# split_fold4_MCF7
# split_fold4_K562
# split_fold5_A549
# split_fold5_MCF7
# split_fold5_K562
# split_fold6_A549
# split_fold6_MCF7
# split_fold6_K562
# split_fold7_A549
# split_fold7_MCF7
# split_fold7_K562

# %%
# split_fold0_A549
# split_fold0_MCF7
# split_fold0_K562
# split_fold1_A549
# split_fold1_MCF7
# split_fold1_K562
# split_fold2_A549
# split_fold2_MCF7
# split_fold2_K562
# split_fold3_A549
# split_fold3_MCF7
# split_fold3_K562
# split_fold4_A549
# split_fold4_MCF7
# split_fold4_K562
# split_fold5_A549
# split_fold5_MCF7
# split_fold5_K562
# split_fold6_A549
# split_fold6_MCF7
# split_fold6_K562
# split_fold7_A549
# split_fold7_MCF7
# split_fold7_K562
# Out:
# 'split_fold7_K562'

# %%
pd.crosstab(adata_sciplex.obs['split_fold7_A549'], adata_sciplex.obs['condition'])
# Out:
# condition         2-Methoxyestradiol  JQ1  A-366  ABT-737  AC480  AG-490  \
# split_fold7_A549
# ood                                0    0      0        0      0       0
# test                              22  232     19       23     25      25
# train                            567  340    528      405    606     569
#
# condition         AG-14361  AICAR  AMG-900  AR-42  AT9283   AZ  AZD1480  \
# split_fold7_A549
# ood                      0      0        0    107       0    0        0
# test                    27     20       11    171      11   24        9
# train                  514    554      435    161     256  455      430
#
# condition         Abexinostat  Alendronate  Alisertib  Altretamine  \
# split_fold7_A549
# ood                       113            0          0            0
# test                      180            9        164           31
# train                     171          347        231          600
#
# condition         Alvespimycin  Aminoglutethimide  Amisulpride  Anacardic  \
# split_fold7_A549
# ood                          0                  0            0          0
# test                         0                 14           16         21
# train                      277                533          498        566
#
# condition         Andarine  Aurora  Avagacestat  Azacitidine  BMS-265246  \
# split_fold7_A549
# ood                      0       0            0            0           0
# test                    13      22           23           35          20
# train                  529     514          501          527         515
#
# condition         BMS-536924  BMS-754807  BMS-911543  BRD4770  Barasertib  \
# split_fold7_A549
# ood                        0           0           0        0           0
# test                      21         229          29       28         179
# train                    477         261         562      559         247
#
# condition         Baricitinib  Belinostat  Bisindolylmaleimide  Bosutinib  \
# split_fold7_A549
# ood                         0         147                    0        156
# test                       20         211                   22        138
# train                     588         171                  500        101
#
# condition         Busulfan  CEP-33779  CUDC-101  CUDC-907  CYC116  \
# split_fold7_A549
# ood                      0          0         0         0       0
# test                    29         26       156       112      16
# train                  646        608       378       302     514
#
# condition         Capecitabine  Carmofur  Cediranib  Celecoxib  Cerdulatinib  \
# split_fold7_A549
# ood                          0         0          0          0             0
# test                        29        26         18         16            28
# train                      603       555        506        431           602
#
# condition         Cimetidine  Clevudine  Costunolide  Crizotinib  Curcumin  \
# split_fold7_A549
# ood                        0          0            0           0         0
# test                      25         23           20         218        22
# train                    561        550          510         261       592
#
# condition         Cyclocytidine  Dacinostat  Danusertib  Daphnetin  Dasatinib  \
# split_fold7_A549
# ood                           0           0          87          0          0
# test                         21           0         169         18        178
# train                       477         389         147        599        235
#
# condition         Decitabine  Disulfiram  Divalproex  Droxinostat  EED226  \
# split_fold7_A549
# ood                        0           0           0            0       0
# test                      15          17          18           26      24
# train                    321         528         617          602     595
#
# condition         ENMD-2076  Ellagic  Entacapone  Entinostat  Enzastaurin  \
# split_fold7_A549
# ood                     210        0           0           0            0
# test                    392       28          22         252           29
# train                   360      545         606         339          584
#
# condition         Epothilone  FLLL32  Fasudil  Fedratinib  Filgotinib  \
# split_fold7_A549
# ood                        0       0        0           0           0
# test                      76      27       24          28          22
# train                     98     527      595         496         539
#
# condition         Flavopiridol  Fluorouracil  Fulvestrant  G007-LK  GSK  \
# split_fold7_A549
# ood                          0             0            0        0    0
# test                         0            29          214       12   28
# train                      113           529          349      451  584
#
# condition         GSK1070916  GSK-LSD1  Gandotinib  Givinostat  \
# split_fold7_A549
# ood                        0         0           0           0
# test                     178        15          18           0
# train                    248       607         525         496
#
# condition         Glesatinib?(MGCD265)  Hesperadin  INO-1001  IOX2  ITSA-1  \
# split_fold7_A549
# ood                                  0           0         0     0       0
# test                                27           0        17    26      23
# train                              562         358       563   566     592
#
# condition         Iniparib  Ivosidenib  JNJ-7706621  JNJ-26854165  KW-2449  \
# split_fold7_A549
# ood                      0           0            0             0       97
# test                    26          26           27            29      182
# train                  579         520          518           594      183
#
# condition         Ki8751  Ki16425  Lapatinib  Lenalidomide  Linifanib  \
# split_fold7_A549
# ood                    0        0          0             0          0
# test                  26       24         17            29         19
# train                556      535        501           480        558
#
# condition         Lomustine  Luminespib  M344  MC1568  MK-0752  MK-5108  \
# split_fold7_A549
# ood                       0           0     0       0        0        0
# test                     25         132   206      27       29       25
# train                   619         173   306     662      590      510
#
# condition         MLN8054  Maraviroc  Meprednisone  Mercaptopurine  Mesna  \
# split_fold7_A549
# ood                     0          0             0               0      0
# test                   15         22            18              26     24
# train                 406        572           513             495    465
#
# condition         Mocetinostat  Momelotinib  Motesanib  NVP-BSK805  \
# split_fold7_A549
# ood                          0            0          0           0
# test                       210           22         19          25
# train                      286          588        575         561
#
# condition         Navitoclax  Nilotinib  Nintedanib  Obatoclax  Ofloxacin  \
# split_fold7_A549
# ood                        0          0           0          0          0
# test                      21         22         255         31         27
# train                    578        488         334        585        603
#
# condition         PCI-34051  PD98059  PD173074  PF-3845  PF-573228  PFI-1  \
# split_fold7_A549
# ood                       0        0         0        0          0      0
# test                     22       15        24       19         31     29
# train                   490      621       508      518        551    521
#
# condition         PHA-680632  PJ34  Panobinostat  Patupilone  Pelitinib  \
# split_fold7_A549
# ood                        0     0            75           0          0
# test                      29    18           192         131         20
# train                    394   627           176         191        529
#
# condition         Pirarubicin  Pracinostat  Prednisone  Quercetin  \
# split_fold7_A549
# ood                         0            0           0          0
# test                      150          211          16         22
# train                     340          287         471        599
#
# condition         Quisinostat  RG108  Raltitrexed  Ramelteon  Regorafenib  \
# split_fold7_A549
# ood                         0      0            0          0            0
# test                        0     15          121         23           28
# train                     398    607          283        573          569
#
# condition         Resminostat  Resveratrol  Rigosertib  Roscovitine  \
# split_fold7_A549
# ood                         0            0           0            0
# test                      236           28         108           18
# train                     311          493         136          508
#
# condition         Roxadustat  Rucaparib  Ruxolitinib  S3I-201  S-Ruxolitinib  \
# split_fold7_A549
# ood                        0          0            0        0              0
# test                      26         13           15       24             27
# train                    612        333          478      539            628
#
# condition         SB431542  SGI-1776  SL-327  SNS-314  SRT1720  SRT2104  \
# split_fold7_A549
# ood                      0         0       0        0        0        0
# test                    28        23      22       14       21       22
# train                  507       566     531      367      575      675
#
# condition         SRT3025  Selisistat  Sirtinol  Sodium  Sorafenib  \
# split_fold7_A549
# ood                     0           0         0       0        139
# test                   20          25        23      22        222
# train                 501         574       541     614        186
#
# condition         Streptozotocin  TAK-901  TG101209  TGX-221  TMP195  \
# split_fold7_A549
# ood                            0        0         0        0       0
# test                          19        0        17       23      11
# train                        500      337       484      570     375
#
# condition         Tacedinaline  Tanespimycin  Tazemetostat  Temsirolimus  \
# split_fold7_A549
# ood                          0            87             0             0
# test                       256            91            16            17
# train                      368           117           617           458
#
# condition         Thalidomide  Thiotepa  Tie2  Tofacitinib  Toremifene  \
# split_fold7_A549
# ood                         0         0     0            0           0
# test                       30        16    18           28          21
# train                     573       501   497          591         568
#
# condition         Tozasertib  Trametinib  Tranylcypromine  Triamcinolone  \
# split_fold7_A549
# ood                        0           0                0              0
# test                      12         172               32             21
# train                    278         380              547            578
#
# condition         Trichostatin  Tubastatin  Tucidinostat  UNC0379  UNC0631  \
# split_fold7_A549
# ood                          0           0             0        0        0
# test                       226          23           130       33       20
# train                      305         590           210      607      569
#
# condition         UNC1999  Valproic  Vandetanib  Veliparib  WHI-P154  WP1066  \
# split_fold7_A549
# ood                     0         0           0          0         0       0
# test                   26        26          22         22        30      30
# train                 612       568         565        510       611     595
#
# condition         XAV-939  YM155   ZM  Zileuton  control
# split_fold7_A549
# ood                     0      0    0         0        0
# test                   24     42   13        25     1132
# train                 640     57  428       623    11872

# %%
pd.crosstab(adata_sciplex.obs['split_fold7_A549'], adata_sciplex.obs['cell_type'])
# Out:
# cell_type          A549   K562   MCF7
# split_fold7_A549
# ood                1218      0      0
# test               2235   2763   6046
# train             24484  25866  49668

# %%
pd.crosstab(adata_sciplex.obs['split_fold7_A549'], adata_sciplex.obs['condition'].isin(['control']))
# Out:
# condition         False   True
# split_fold7_A549
# ood                1218      0
# test               9912   1132
# train             88146  11872

# %%
adata_sciplex.write(DATA_DIR/'adata_fold.h5ad', compression="gzip")
