# %% [markdown]
# # GROVER
# Generate GROVER fingerprints for SMILES-drugs coming from LINCS + SciPlex3.
#
# Steps:
# 1. Load LINCS + SciPlex3, extract SMILES
# 2. Generate fingerprints using GROVER
# 3. Save SMILES -> fingerprint mapping as a pandas df.

# %% [markdown]
# ## Step 1: Get all relevant SMILES from datasets

# %%
import scanpy as sc
from rdkit import Chem
import pandas as pd
import numpy as np
from pathlib import Path

# %%
def canonicalize(smiles): 
    if smiles:
        return Chem.MolToSmiles(Chem.MolFromSmiles(smiles), canonical=True)
    else:
        return None

# %%
# SET
datasets_fpath = Path("/home/icb/simon.boehm/Masters_thesis/MT_code/datasets")

# %%
for key, dataset in [("SMILES", "trapnell_cpa.h5ad"),
                     ("SMILES", "trapnell_cpa_subset.h5ad"),
                     ("canonical_smiles", "lincs_full_smiles.h5ad")]:
    outpath = Path("data/embeddings/") / dataset.replace(".h5ad", ".csv")
    if outpath.exists():
        print(outpath, "found, skipping")
    else:
        print("Generating", outpath)
        df = sc.read(datasets_fpath / dataset)
        # load all unique SMILES in the dataset and canonicalize them
        canonical_smiles = pd.Series(df.obs[key].unique()).apply(canonicalize).dropna()
        # dump to csv
        canonical_smiles.to_csv(outpath, index=False, header=["smiles"])
# Out:
# data/embeddings/trapnell_cpa.csv found, skipping
# data/embeddings/trapnell_cpa_subset.csv found, skipping
# data/embeddings/lincs_full_smiles.csv found, skipping

# %% [markdown]
# ## Step 2: Generate fingerprints
#
# - TODO: Right now we generate `rdkit_2d_normalized` features. Are these the correct ones?
# - TODO: There are pretrained & finetuned models also available, maybe that's useful for us:
#     - SIDER: Drug side effect prediction task
#     - ClinTox: Drug toxicity prediction task
#     - ChEMBL log P prediction task

# %%
# %%bash
# set -euox pipefail
# for file in data/embeddings/*.csv; do
#     # First we generate the feature embedding for the SMILES, which is an extra input
#     # into GROVER
#     echo "FILE: $file"
#     features=$(echo $file | sed 's:.csv:.npz:')
#     if [[ ! -f $features ]]; then
#         echo "Generating features: $features"
#         python scripts/save_features.py --data_path "$file" \
#                                 --save_path "$features" \
#                                 --features_generator rdkit_2d_normalized \
#                                 --restart
#     fi;
#
#     # Second we input SMILES + Features into grover and get the fingerprint out
#     # 'both' means we get a concatenated fingerprint of combined atoms + bonds features
#     outfile=$(echo $file | sed 's:.csv:_grover_base_both.npz:')
#     echo "EMB: $outfile"
#     if [[ ! -f $outfile ]]; then
#         echo "Generating embedding: $outfile"
#         python main.py fingerprint --data_path "$file" \
#                            --features_path "$features" \
#                            --checkpoint_path data/model/grover_base.pt \
#                            --fingerprint_source both \
#                            --output "$outfile"
#     fi;
# done;
# Out:
# FILE: data/embeddings/lincs_full_smiles.csv
# EMB: data/embeddings/lincs_full_smiles_grover_base_both.npz
# FILE: data/embeddings/trapnell_cpa.csv
# EMB: data/embeddings/trapnell_cpa_grover_base_both.npz
# FILE: data/embeddings/trapnell_cpa_subset.csv
# EMB: data/embeddings/trapnell_cpa_subset_grover_base_both.npz
# + for file in 'data/embeddings/*.csv'
# + echo 'FILE: data/embeddings/lincs_full_smiles.csv'
# ++ echo data/embeddings/lincs_full_smiles.csv
# ++ sed s:.csv:.npz:
# + features=data/embeddings/lincs_full_smiles.npz
# + [[ ! -f data/embeddings/lincs_full_smiles.npz ]]
# ++ echo data/embeddings/lincs_full_smiles.csv
# ++ sed s:.csv:_grover_base_both.npz:
# + outfile=data/embeddings/lincs_full_smiles_grover_base_both.npz
# + echo 'EMB: data/embeddings/lincs_full_smiles_grover_base_both.npz'
# + [[ ! -f data/embeddings/lincs_full_smiles_grover_base_both.npz ]]
# + for file in 'data/embeddings/*.csv'
# + echo 'FILE: data/embeddings/trapnell_cpa.csv'
# ++ echo data/embeddings/trapnell_cpa.csv
# ++ sed s:.csv:.npz:
# + features=data/embeddings/trapnell_cpa.npz
# + [[ ! -f data/embeddings/trapnell_cpa.npz ]]
# ++ echo data/embeddings/trapnell_cpa.csv
# ++ sed s:.csv:_grover_base_both.npz:
# + outfile=data/embeddings/trapnell_cpa_grover_base_both.npz
# + echo 'EMB: data/embeddings/trapnell_cpa_grover_base_both.npz'
# + [[ ! -f data/embeddings/trapnell_cpa_grover_base_both.npz ]]
# + for file in 'data/embeddings/*.csv'
# + echo 'FILE: data/embeddings/trapnell_cpa_subset.csv'
# ++ echo data/embeddings/trapnell_cpa_subset.csv
# ++ sed s:.csv:.npz:
# + features=data/embeddings/trapnell_cpa_subset.npz
# + [[ ! -f data/embeddings/trapnell_cpa_subset.npz ]]
# ++ echo data/embeddings/trapnell_cpa_subset.csv
# ++ sed s:.csv:_grover_base_both.npz:
# + outfile=data/embeddings/trapnell_cpa_subset_grover_base_both.npz
# + echo 'EMB: data/embeddings/trapnell_cpa_subset_grover_base_both.npz'
# + [[ ! -f data/embeddings/trapnell_cpa_subset_grover_base_both.npz ]]

# %%
trapnell_base = np.load("data/embeddings/trapnell_cpa_grover_base_both.npz")
trapnell_large = np.load("data/embeddings/trapnell_cpa_grover_large_both.npz")

# %%
print("Shape of GROVER_base embedding:", trapnell_base["fps"].shape)
print("Shape of GROVER_large embedding:", trapnell_large["fps"].shape)
# Out:
# Shape of GROVER_base embedding: (188, 3400)
# Shape of GROVER_large embedding: (188, 5000)

# %% [markdown]
# ## Step 3: Generate DataFrame with SMILES -> Embedding mapping

# %%
def flatten(x: np.ndarray):
    assert len(x.shape) == 2 and x.shape[0] == 1
    return x[0]

embeddings_fpath = Path("data/embeddings")
for file in embeddings_fpath.iterdir():
    final_dfs = []
    if str(file).endswith("csv"):
        # read original SMILES list
        df = pd.read_csv(file)
        # read generated embedding (.npz has only one key, 'fps')
        emb = np.load(str(file).replace(".csv", "_grover_base_both.npz"))["fps"]
        assert len(df) == emb.shape[0]
        # generate a DataFrame with SMILES and Embedding in each row
        final_df = pd.DataFrame(emb, index=df["smiles"].values, columns=[f"latent_{i+1}" for i in range(emb.shape[1])])
        final_dfs.append(final_df)
    # join into one dataframe
    final_df = pd.concat(final_dfs)
    # remove duplicates indices (=SMILES)
    final_df = final_df[~final_df.index.duplicated(keep="first")]
    final_df.to_parquet(embeddings_fpath / "grover_base.parquet")

# %%
df = pd.read_parquet("data/embeddings/grover_base.parquet")

# %%
df
# Out:
#                                                     latent_1  latent_2  \
# COc1cc2c(cc1O)CC[C@@H]1[C@@H]2CC[C@]2(C)[C@@H](...  0.195959 -0.278208
# COc1cc2c(cc1OCCCN1CCCC1)N=C(N)C21CCC1               0.139694  0.113071
# CN(C)CCC(CSc1ccccc1)Nc1ccc(S(=O)(=O)NC(=O)c2ccc...  0.211542 -0.666226
# Cc1c(NC(=O)OCC2COCCN2)cn2ncnc(Nc3ccc4c(cnn4Cc4c...  0.102223 -1.600725
# CN(C)Cc1ccc(-c2nc3cccc4c3n2CCNC4=O)cc1              0.244959 -0.644244
# ...                                                      ...       ...
# C[C@H](NC(=O)/C(C#N)=C/c1cccc(Br)n1)c1ccccc1        0.277825 -0.521337
# Oc1nc(-c2ccc(C(F)(F)F)cc2)nc2c1CSCC2                0.125752 -0.372700
# COCCn1c2c([n+](Cc3cnccn3)c1C)C(=O)c1ccccc1C2=O....  0.045635 -0.713219
# COc1cc2c(Nc3ccc(NC(=O)c4ccccc4)cc3)ncnc2cc1OCCC...  0.166708 -1.097559
# CC(c1cc2ccccc2s1)N(O)C(N)=O                         0.212519 -0.688607
#
#                                                     latent_3  latent_4  \
# COc1cc2c(cc1O)CC[C@@H]1[C@@H]2CC[C@]2(C)[C@@H](...  0.153157  0.105822
# COc1cc2c(cc1OCCCN1CCCC1)N=C(N)C21CCC1               0.175902  0.140174
# CN(C)CCC(CSc1ccccc1)Nc1ccc(S(=O)(=O)NC(=O)c2ccc...  0.157627  0.162469
# Cc1c(NC(=O)OCC2COCCN2)cn2ncnc(Nc3ccc4c(cnn4Cc4c...  0.061120  0.095598
# CN(C)Cc1ccc(-c2nc3cccc4c3n2CCNC4=O)cc1              0.087852  0.138099
# ...                                                      ...       ...
# C[C@H](NC(=O)/C(C#N)=C/c1cccc(Br)n1)c1ccccc1        0.039926  0.201971
# Oc1nc(-c2ccc(C(F)(F)F)cc2)nc2c1CSCC2                0.033391  0.128889
# COCCn1c2c([n+](Cc3cnccn3)c1C)C(=O)c1ccccc1C2=O....  0.065151  0.166694
# COc1cc2c(Nc3ccc(NC(=O)c4ccccc4)cc3)ncnc2cc1OCCC...  0.107598  0.107864
# CC(c1cc2ccccc2s1)N(O)C(N)=O                         0.120124 -0.080019
#
#                                                     latent_5  latent_6  \
# COc1cc2c(cc1O)CC[C@@H]1[C@@H]2CC[C@]2(C)[C@@H](... -0.083688  0.428338
# COc1cc2c(cc1OCCCN1CCCC1)N=C(N)C21CCC1              -0.099123  0.344958
# CN(C)CCC(CSc1ccccc1)Nc1ccc(S(=O)(=O)NC(=O)c2ccc... -0.182653  0.151127
# Cc1c(NC(=O)OCC2COCCN2)cn2ncnc(Nc3ccc4c(cnn4Cc4c... -0.132348  0.116600
# CN(C)Cc1ccc(-c2nc3cccc4c3n2CCNC4=O)cc1             -0.131626  0.028204
# ...                                                      ...       ...
# C[C@H](NC(=O)/C(C#N)=C/c1cccc(Br)n1)c1ccccc1       -0.025537  0.149467
# Oc1nc(-c2ccc(C(F)(F)F)cc2)nc2c1CSCC2               -0.080128  0.383126
# COCCn1c2c([n+](Cc3cnccn3)c1C)C(=O)c1ccccc1C2=O.... -0.011162  0.267313
# COc1cc2c(Nc3ccc(NC(=O)c4ccccc4)cc3)ncnc2cc1OCCC... -0.136008 -0.025259
# CC(c1cc2ccccc2s1)N(O)C(N)=O                        -0.192256  0.141297
#
#                                                     latent_7  latent_8  \
# COc1cc2c(cc1O)CC[C@@H]1[C@@H]2CC[C@]2(C)[C@@H](... -0.032398 -0.844538
# COc1cc2c(cc1OCCCN1CCCC1)N=C(N)C21CCC1               0.253862 -1.119520
# CN(C)CCC(CSc1ccccc1)Nc1ccc(S(=O)(=O)NC(=O)c2ccc...  0.100305  0.488502
# Cc1c(NC(=O)OCC2COCCN2)cn2ncnc(Nc3ccc4c(cnn4Cc4c...  0.056430 -0.221550
# CN(C)Cc1ccc(-c2nc3cccc4c3n2CCNC4=O)cc1              0.026444  0.449965
# ...                                                      ...       ...
# C[C@H](NC(=O)/C(C#N)=C/c1cccc(Br)n1)c1ccccc1        0.131638 -0.322467
# Oc1nc(-c2ccc(C(F)(F)F)cc2)nc2c1CSCC2                0.153452 -0.760426
# COCCn1c2c([n+](Cc3cnccn3)c1C)C(=O)c1ccccc1C2=O.... -0.118964 -0.868709
# COc1cc2c(Nc3ccc(NC(=O)c4ccccc4)cc3)ncnc2cc1OCCC...  0.194670  0.604208
# CC(c1cc2ccccc2s1)N(O)C(N)=O                         0.279940  1.571053
#
#                                                     latent_9  latent_10  ...  \
# COc1cc2c(cc1O)CC[C@@H]1[C@@H]2CC[C@]2(C)[C@@H](...  0.089965   1.319402  ...
# COc1cc2c(cc1OCCCN1CCCC1)N=C(N)C21CCC1              -0.246315   0.652924  ...
# CN(C)CCC(CSc1ccccc1)Nc1ccc(S(=O)(=O)NC(=O)c2ccc... -0.243197  -0.471426  ...
# Cc1c(NC(=O)OCC2COCCN2)cn2ncnc(Nc3ccc4c(cnn4Cc4c... -0.291598  -0.232704  ...
# CN(C)Cc1ccc(-c2nc3cccc4c3n2CCNC4=O)cc1             -0.200088  -0.053318  ...
# ...                                                      ...        ...  ...
# C[C@H](NC(=O)/C(C#N)=C/c1cccc(Br)n1)c1ccccc1       -0.397910  -0.610647  ...
# Oc1nc(-c2ccc(C(F)(F)F)cc2)nc2c1CSCC2               -0.054713   0.417102  ...
# COCCn1c2c([n+](Cc3cnccn3)c1C)C(=O)c1ccccc1C2=O.... -0.264098   0.250065  ...
# COc1cc2c(Nc3ccc(NC(=O)c4ccccc4)cc3)ncnc2cc1OCCC... -0.316389   0.297391  ...
# CC(c1cc2ccccc2s1)N(O)C(N)=O                        -0.593775  -0.176017  ...
#
#                                                      latent_3391  \
# COc1cc2c(cc1O)CC[C@@H]1[C@@H]2CC[C@]2(C)[C@@H](...  1.593061e-17
# COc1cc2c(cc1OCCCN1CCCC1)N=C(N)C21CCC1               1.593061e-17
# CN(C)CCC(CSc1ccccc1)Nc1ccc(S(=O)(=O)NC(=O)c2ccc...  9.999565e-01
# Cc1c(NC(=O)OCC2COCCN2)cn2ncnc(Nc3ccc4c(cnn4Cc4c...  1.593061e-17
# CN(C)Cc1ccc(-c2nc3cccc4c3n2CCNC4=O)cc1              1.593061e-17
# ...                                                          ...
# C[C@H](NC(=O)/C(C#N)=C/c1cccc(Br)n1)c1ccccc1        1.593061e-17
# Oc1nc(-c2ccc(C(F)(F)F)cc2)nc2c1CSCC2                1.593061e-17
# COCCn1c2c([n+](Cc3cnccn3)c1C)C(=O)c1ccccc1C2=O....  1.593061e-17
# COc1cc2c(Nc3ccc(NC(=O)c4ccccc4)cc3)ncnc2cc1OCCC...  1.593061e-17
# CC(c1cc2ccccc2s1)N(O)C(N)=O                         1.593061e-17
#
#                                                      latent_3392  \
# COc1cc2c(cc1O)CC[C@@H]1[C@@H]2CC[C@]2(C)[C@@H](...  5.766101e-14
# COc1cc2c(cc1OCCCN1CCCC1)N=C(N)C21CCC1               5.766101e-14
# CN(C)CCC(CSc1ccccc1)Nc1ccc(S(=O)(=O)NC(=O)c2ccc...  5.766101e-14
# Cc1c(NC(=O)OCC2COCCN2)cn2ncnc(Nc3ccc4c(cnn4Cc4c...  5.766101e-14
# CN(C)Cc1ccc(-c2nc3cccc4c3n2CCNC4=O)cc1              5.766101e-14
# ...                                                          ...
# C[C@H](NC(=O)/C(C#N)=C/c1cccc(Br)n1)c1ccccc1        5.766101e-14
# Oc1nc(-c2ccc(C(F)(F)F)cc2)nc2c1CSCC2                5.766101e-14
# COCCn1c2c([n+](Cc3cnccn3)c1C)C(=O)c1ccccc1C2=O....  5.766101e-14
# COc1cc2c(Nc3ccc(NC(=O)c4ccccc4)cc3)ncnc2cc1OCCC...  5.766101e-14
# CC(c1cc2ccccc2s1)N(O)C(N)=O                         5.766101e-14
#
#                                                      latent_3393  latent_3394  \
# COc1cc2c(cc1O)CC[C@@H]1[C@@H]2CC[C@]2(C)[C@@H](...  2.957989e-11     0.168378
# COc1cc2c(cc1OCCCN1CCCC1)N=C(N)C21CCC1               2.957989e-11     0.168378
# CN(C)CCC(CSc1ccccc1)Nc1ccc(S(=O)(=O)NC(=O)c2ccc...  2.957989e-11     0.168378
# Cc1c(NC(=O)OCC2COCCN2)cn2ncnc(Nc3ccc4c(cnn4Cc4c...  2.957989e-11     0.168378
# CN(C)Cc1ccc(-c2nc3cccc4c3n2CCNC4=O)cc1              2.957989e-11     0.168378
# ...                                                          ...          ...
# C[C@H](NC(=O)/C(C#N)=C/c1cccc(Br)n1)c1ccccc1        2.957989e-11     0.168378
# Oc1nc(-c2ccc(C(F)(F)F)cc2)nc2c1CSCC2                2.957989e-11     0.168378
# COCCn1c2c([n+](Cc3cnccn3)c1C)C(=O)c1ccccc1C2=O....  2.957989e-11     0.168378
# COc1cc2c(Nc3ccc(NC(=O)c4ccccc4)cc3)ncnc2cc1OCCC...  2.957989e-11     0.168378
# CC(c1cc2ccccc2s1)N(O)C(N)=O                         2.957989e-11     0.168378
#
#                                                     latent_3395   latent_3396  \
# COc1cc2c(cc1O)CC[C@@H]1[C@@H]2CC[C@]2(C)[C@@H](...      0.16738  1.481515e-18
# COc1cc2c(cc1OCCCN1CCCC1)N=C(N)C21CCC1                   0.16738  1.481515e-18
# CN(C)CCC(CSc1ccccc1)Nc1ccc(S(=O)(=O)NC(=O)c2ccc...      0.16738  1.481515e-18
# Cc1c(NC(=O)OCC2COCCN2)cn2ncnc(Nc3ccc4c(cnn4Cc4c...      0.16738  1.481515e-18
# CN(C)Cc1ccc(-c2nc3cccc4c3n2CCNC4=O)cc1                  0.16738  1.481515e-18
# ...                                                         ...           ...
# C[C@H](NC(=O)/C(C#N)=C/c1cccc(Br)n1)c1ccccc1            0.16738  1.481515e-18
# Oc1nc(-c2ccc(C(F)(F)F)cc2)nc2c1CSCC2                    0.16738  1.481515e-18
# COCCn1c2c([n+](Cc3cnccn3)c1C)C(=O)c1ccccc1C2=O....      0.16738  1.481515e-18
# COc1cc2c(Nc3ccc(NC(=O)c4ccccc4)cc3)ncnc2cc1OCCC...      0.16738  1.481515e-18
# CC(c1cc2ccccc2s1)N(O)C(N)=O                             0.16738  1.481515e-18
#
#                                                      latent_3397  \
# COc1cc2c(cc1O)CC[C@@H]1[C@@H]2CC[C@]2(C)[C@@H](...  2.324150e-16
# COc1cc2c(cc1OCCCN1CCCC1)N=C(N)C21CCC1               2.324150e-16
# CN(C)CCC(CSc1ccccc1)Nc1ccc(S(=O)(=O)NC(=O)c2ccc...  2.324150e-16
# Cc1c(NC(=O)OCC2COCCN2)cn2ncnc(Nc3ccc4c(cnn4Cc4c...  2.324150e-16
# CN(C)Cc1ccc(-c2nc3cccc4c3n2CCNC4=O)cc1              2.324150e-16
# ...                                                          ...
# C[C@H](NC(=O)/C(C#N)=C/c1cccc(Br)n1)c1ccccc1        2.324150e-16
# Oc1nc(-c2ccc(C(F)(F)F)cc2)nc2c1CSCC2                2.324150e-16
# COCCn1c2c([n+](Cc3cnccn3)c1C)C(=O)c1ccccc1C2=O....  2.324150e-16
# COc1cc2c(Nc3ccc(NC(=O)c4ccccc4)cc3)ncnc2cc1OCCC...  2.324150e-16
# CC(c1cc2ccccc2s1)N(O)C(N)=O                         1.000000e+00
#
#                                                      latent_3398  latent_3399  \
# COc1cc2c(cc1O)CC[C@@H]1[C@@H]2CC[C@]2(C)[C@@H](...  4.703598e-08     0.166633
# COc1cc2c(cc1OCCCN1CCCC1)N=C(N)C21CCC1               9.607067e-01     0.166633
# CN(C)CCC(CSc1ccccc1)Nc1ccc(S(=O)(=O)NC(=O)c2ccc...  4.703598e-08     0.166633
# Cc1c(NC(=O)OCC2COCCN2)cn2ncnc(Nc3ccc4c(cnn4Cc4c...  4.703598e-08     0.166633
# CN(C)Cc1ccc(-c2nc3cccc4c3n2CCNC4=O)cc1              4.703598e-08     0.166633
# ...                                                          ...          ...
# C[C@H](NC(=O)/C(C#N)=C/c1cccc(Br)n1)c1ccccc1        4.703598e-08     0.166633
# Oc1nc(-c2ccc(C(F)(F)F)cc2)nc2c1CSCC2                4.703598e-08     0.166633
# COCCn1c2c([n+](Cc3cnccn3)c1C)C(=O)c1ccccc1C2=O....  4.703598e-08     0.166633
# COc1cc2c(Nc3ccc(NC(=O)c4ccccc4)cc3)ncnc2cc1OCCC...  9.607067e-01     0.166633
# CC(c1cc2ccccc2s1)N(O)C(N)=O                         4.703598e-08     1.000000
#
#                                                     latent_3400
# COc1cc2c(cc1O)CC[C@@H]1[C@@H]2CC[C@]2(C)[C@@H](...     0.894112
# COc1cc2c(cc1OCCCN1CCCC1)N=C(N)C21CCC1                  0.867332
# CN(C)CCC(CSc1ccccc1)Nc1ccc(S(=O)(=O)NC(=O)c2ccc...     0.006762
# Cc1c(NC(=O)OCC2COCCN2)cn2ncnc(Nc3ccc4c(cnn4Cc4c...     0.122994
# CN(C)Cc1ccc(-c2nc3cccc4c3n2CCNC4=O)cc1                 0.853671
# ...                                                         ...
# C[C@H](NC(=O)/C(C#N)=C/c1cccc(Br)n1)c1ccccc1           0.380367
# Oc1nc(-c2ccc(C(F)(F)F)cc2)nc2c1CSCC2                   0.947664
# COCCn1c2c([n+](Cc3cnccn3)c1C)C(=O)c1ccccc1C2=O....     0.173384
# COc1cc2c(Nc3ccc(NC(=O)c4ccccc4)cc3)ncnc2cc1OCCC...     0.125852
# CC(c1cc2ccccc2s1)N(O)C(N)=O                            0.540851
#
# [188 rows x 3400 columns]
