# %%
import moses
from moses.vae import VAE
import torch
import pandas as pd
import numpy as np
from tqdm import tqdm
from rdkit import Chem, RDLogger
from pathlib import Path


RDLogger.logger().setLevel(RDLogger.CRITICAL)
RDLogger.DisableLog("rdApp.*")

# %%
config_fpath = Path("/storage/groups/ml01/projects/2021_chemicalCPA_leon.hetzel/embeddings/chemvae/config.txt")
state_dict_fpath = Path("/storage/groups/ml01/projects/2021_chemicalCPA_leon.hetzel/embeddings/chemvae/vae_checkpoint_final.pt")

# %%
config = torch.load(config_fpath)
vocab = torch.load(config.vocab_save)
state = torch.load(state_dict_fpath)

# %%
model = VAE(vocab, config)
model.load_state_dict(state)
model.to("cuda")
model.eval()
# Out:
# VAE(
#   (x_emb): Embedding(50, 50, padding_idx=48)
#   (encoder_rnn): GRU(50, 256, batch_first=True)
#   (q_mu): Linear(in_features=256, out_features=128, bias=True)
#   (q_logvar): Linear(in_features=256, out_features=128, bias=True)
#   (decoder_rnn): GRU(178, 512, num_layers=3, batch_first=True)
#   (decoder_lat): Linear(in_features=128, out_features=512, bias=True)
#   (decoder_fc): Linear(in_features=512, out_features=50, bias=True)
#   (encoder): ModuleList(
#     (0): GRU(50, 256, batch_first=True)
#     (1): Linear(in_features=256, out_features=128, bias=True)
#     (2): Linear(in_features=256, out_features=128, bias=True)
#   )
#   (decoder): ModuleList(
#     (0): GRU(178, 512, num_layers=3, batch_first=True)
#     (1): Linear(in_features=128, out_features=512, bias=True)
#     (2): Linear(in_features=512, out_features=50, bias=True)
#   )
#   (vae): ModuleList(
#     (0): Embedding(50, 50, padding_idx=48)
#     (1): ModuleList(
#       (0): GRU(50, 256, batch_first=True)
#       (1): Linear(in_features=256, out_features=128, bias=True)
#       (2): Linear(in_features=256, out_features=128, bias=True)
#     )
#     (2): ModuleList(
#       (0): GRU(178, 512, num_layers=3, batch_first=True)
#       (1): Linear(in_features=128, out_features=512, bias=True)
#       (2): Linear(in_features=512, out_features=50, bias=True)
#     )
#   )
# )

# %%
all_smiles = list(pd.read_csv("/storage/groups/ml01/projects/2021_chemicalCPA_leon.hetzel/embeddings/lincs_trapnell.smiles")["smiles"].values)

# %%
embeddings = []
for s in tqdm(all_smiles):
    with torch.no_grad():
        tensors = [model.string2tensor(s)]
        emb, _ = model.forward_encoder(tensors)
    embeddings.append(emb.cpu().numpy())
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 17869/17869 [00:24<00:00, 742.18it/s]

# %%
emb = np.concatenate(embeddings, axis=0)
final_df = pd.DataFrame(emb, index=all_smiles, columns=[f"latent_{i+1}" for i in range(emb.shape[1])])
final_df.to_parquet("chemvae.parquet")
final_df
# Out:
#                                                     latent_1  latent_2  \
# C[C@H](NC(=O)/C(C#N)=C/c1cccc(Br)n1)c1ccccc1        1.557116  0.449109
# Cc1cc(Nc2cc(CN3CCOCC3)c3nc(C)c(Cc4ccc(Cl)cc4F)n...  1.067754  0.533023
# Cc1cc(N2CCOCC2)cc2[nH]c(-c3c(NCC(O)c4cccc(Cl)c4...  0.607472  1.015737
# Cl.Cl.c1ccc([C@@H]2C[C@H]2NC2CCNCC2)cc1             1.902807  0.023736
# O=C(c1ccc(/C=C/c2n[nH]c3ccccc23)cc1)N1CCNCC1       -2.072833  0.183836
# ...                                                      ...       ...
# CCCC(=O)Nc1ccc2c(c1)C(=O)N(C)C[C@H](OC)[C@@H](C... -0.198073  0.768631
# Cc1cc(CS(=O)(=O)c2ccccc2)cc(OCc2ccc(CN3CCC[C@@H... -0.332620 -0.690646
# CN(C)CCOc1ccc(/C(=C(\CCCl)c2ccccc2)c2ccccc2)cc1    -0.633693 -0.070029
# CC1(C)C=Cc2c(ccc3c2[N+]([O-])=C2C3=C[C@@]34NC(=...  0.842776  0.310461
# C[C@@H]1CC(=O)NN=C1c1ccc(N)c([N+](=O)[O-])c1       -0.546669  1.202175
#
#                                                     latent_3  latent_4  \
# C[C@H](NC(=O)/C(C#N)=C/c1cccc(Br)n1)c1ccccc1       -0.212241  0.265395
# Cc1cc(Nc2cc(CN3CCOCC3)c3nc(C)c(Cc4ccc(Cl)cc4F)n...  0.595420  0.754059
# Cc1cc(N2CCOCC2)cc2[nH]c(-c3c(NCC(O)c4cccc(Cl)c4... -0.442386 -1.595294
# Cl.Cl.c1ccc([C@@H]2C[C@H]2NC2CCNCC2)cc1             0.216138 -0.263214
# O=C(c1ccc(/C=C/c2n[nH]c3ccccc23)cc1)N1CCNCC1        1.759904  0.790609
# ...                                                      ...       ...
# CCCC(=O)Nc1ccc2c(c1)C(=O)N(C)C[C@H](OC)[C@@H](C... -0.656850 -0.485141
# Cc1cc(CS(=O)(=O)c2ccccc2)cc(OCc2ccc(CN3CCC[C@@H... -0.650203 -0.319614
# CN(C)CCOc1ccc(/C(=C(\CCCl)c2ccccc2)c2ccccc2)cc1    -0.264711  0.803552
# CC1(C)C=Cc2c(ccc3c2[N+]([O-])=C2C3=C[C@@]34NC(=... -1.037071 -0.107875
# C[C@@H]1CC(=O)NN=C1c1ccc(N)c([N+](=O)[O-])c1       -0.686635  0.480349
#
#                                                     latent_5  latent_6  \
# C[C@H](NC(=O)/C(C#N)=C/c1cccc(Br)n1)c1ccccc1        1.368745 -0.865343
# Cc1cc(Nc2cc(CN3CCOCC3)c3nc(C)c(Cc4ccc(Cl)cc4F)n...  0.904944  0.480257
# Cc1cc(N2CCOCC2)cc2[nH]c(-c3c(NCC(O)c4cccc(Cl)c4...  0.497546  0.812311
# Cl.Cl.c1ccc([C@@H]2C[C@H]2NC2CCNCC2)cc1            -1.295511 -0.631556
# O=C(c1ccc(/C=C/c2n[nH]c3ccccc23)cc1)N1CCNCC1       -0.334443 -1.022856
# ...                                                      ...       ...
# CCCC(=O)Nc1ccc2c(c1)C(=O)N(C)C[C@H](OC)[C@@H](C... -0.118598 -0.862468
# Cc1cc(CS(=O)(=O)c2ccccc2)cc(OCc2ccc(CN3CCC[C@@H...  0.423077  0.155828
# CN(C)CCOc1ccc(/C(=C(\CCCl)c2ccccc2)c2ccccc2)cc1     1.716896  0.495845
# CC1(C)C=Cc2c(ccc3c2[N+]([O-])=C2C3=C[C@@]34NC(=...  0.680730  0.074522
# C[C@@H]1CC(=O)NN=C1c1ccc(N)c([N+](=O)[O-])c1       -0.689785 -0.076944
#
#                                                     latent_7  latent_8  \
# C[C@H](NC(=O)/C(C#N)=C/c1cccc(Br)n1)c1ccccc1        0.090169 -0.367736
# Cc1cc(Nc2cc(CN3CCOCC3)c3nc(C)c(Cc4ccc(Cl)cc4F)n... -0.454201 -0.470015
# Cc1cc(N2CCOCC2)cc2[nH]c(-c3c(NCC(O)c4cccc(Cl)c4...  1.622832 -1.344401
# Cl.Cl.c1ccc([C@@H]2C[C@H]2NC2CCNCC2)cc1             0.723728  1.488993
# O=C(c1ccc(/C=C/c2n[nH]c3ccccc23)cc1)N1CCNCC1       -1.063119 -0.542503
# ...                                                      ...       ...
# CCCC(=O)Nc1ccc2c(c1)C(=O)N(C)C[C@H](OC)[C@@H](C...  1.554209 -0.019635
# Cc1cc(CS(=O)(=O)c2ccccc2)cc(OCc2ccc(CN3CCC[C@@H... -1.601239 -1.608535
# CN(C)CCOc1ccc(/C(=C(\CCCl)c2ccccc2)c2ccccc2)cc1    -1.544559  2.549381
# CC1(C)C=Cc2c(ccc3c2[N+]([O-])=C2C3=C[C@@]34NC(=...  0.323799 -0.014356
# C[C@@H]1CC(=O)NN=C1c1ccc(N)c([N+](=O)[O-])c1       -1.154470 -1.102232
#
#                                                     latent_9  latent_10  ...  \
# C[C@H](NC(=O)/C(C#N)=C/c1cccc(Br)n1)c1ccccc1        0.105361   0.530865  ...
# Cc1cc(Nc2cc(CN3CCOCC3)c3nc(C)c(Cc4ccc(Cl)cc4F)n... -0.320997  -1.815178  ...
# Cc1cc(N2CCOCC2)cc2[nH]c(-c3c(NCC(O)c4cccc(Cl)c4... -0.495128  -0.564234  ...
# Cl.Cl.c1ccc([C@@H]2C[C@H]2NC2CCNCC2)cc1            -2.693938   0.349539  ...
# O=C(c1ccc(/C=C/c2n[nH]c3ccccc23)cc1)N1CCNCC1       -0.627536   0.971684  ...
# ...                                                      ...        ...  ...
# CCCC(=O)Nc1ccc2c(c1)C(=O)N(C)C[C@H](OC)[C@@H](C... -1.222284   0.432182  ...
# Cc1cc(CS(=O)(=O)c2ccccc2)cc(OCc2ccc(CN3CCC[C@@H... -2.804836  -0.260143  ...
# CN(C)CCOc1ccc(/C(=C(\CCCl)c2ccccc2)c2ccccc2)cc1    -1.420597   0.407462  ...
# CC1(C)C=Cc2c(ccc3c2[N+]([O-])=C2C3=C[C@@]34NC(=... -0.188539  -0.145040  ...
# C[C@@H]1CC(=O)NN=C1c1ccc(N)c([N+](=O)[O-])c1       -1.231153  -0.093928  ...
#
#                                                     latent_119  latent_120  \
# C[C@H](NC(=O)/C(C#N)=C/c1cccc(Br)n1)c1ccccc1          0.242221   -0.231116
# Cc1cc(Nc2cc(CN3CCOCC3)c3nc(C)c(Cc4ccc(Cl)cc4F)n...   -1.151122   -1.349364
# Cc1cc(N2CCOCC2)cc2[nH]c(-c3c(NCC(O)c4cccc(Cl)c4...   -0.843197   -0.461671
# Cl.Cl.c1ccc([C@@H]2C[C@H]2NC2CCNCC2)cc1              -2.564500   -1.536878
# O=C(c1ccc(/C=C/c2n[nH]c3ccccc23)cc1)N1CCNCC1          0.870260   -0.474700
# ...                                                        ...         ...
# CCCC(=O)Nc1ccc2c(c1)C(=O)N(C)C[C@H](OC)[C@@H](C...   -0.025859    1.828059
# Cc1cc(CS(=O)(=O)c2ccccc2)cc(OCc2ccc(CN3CCC[C@@H...    0.462508   -0.834634
# CN(C)CCOc1ccc(/C(=C(\CCCl)c2ccccc2)c2ccccc2)cc1      -0.858744    1.012648
# CC1(C)C=Cc2c(ccc3c2[N+]([O-])=C2C3=C[C@@]34NC(=...   -1.735851    2.686139
# C[C@@H]1CC(=O)NN=C1c1ccc(N)c([N+](=O)[O-])c1         -0.644633    0.550913
#
#                                                     latent_121  latent_122  \
# C[C@H](NC(=O)/C(C#N)=C/c1cccc(Br)n1)c1ccccc1         -2.729977    0.919116
# Cc1cc(Nc2cc(CN3CCOCC3)c3nc(C)c(Cc4ccc(Cl)cc4F)n...    0.794603   -1.816965
# Cc1cc(N2CCOCC2)cc2[nH]c(-c3c(NCC(O)c4cccc(Cl)c4...    1.076396   -0.859824
# Cl.Cl.c1ccc([C@@H]2C[C@H]2NC2CCNCC2)cc1               0.546583    0.523096
# O=C(c1ccc(/C=C/c2n[nH]c3ccccc23)cc1)N1CCNCC1          0.221147   -1.369071
# ...                                                        ...         ...
# CCCC(=O)Nc1ccc2c(c1)C(=O)N(C)C[C@H](OC)[C@@H](C...    0.993634   -0.957795
# Cc1cc(CS(=O)(=O)c2ccccc2)cc(OCc2ccc(CN3CCC[C@@H...    1.057046   -0.566899
# CN(C)CCOc1ccc(/C(=C(\CCCl)c2ccccc2)c2ccccc2)cc1      -0.314032    0.011283
# CC1(C)C=Cc2c(ccc3c2[N+]([O-])=C2C3=C[C@@]34NC(=...   -1.082980    0.094797
# C[C@@H]1CC(=O)NN=C1c1ccc(N)c([N+](=O)[O-])c1          0.631621   -0.315455
#
#                                                     latent_123  latent_124  \
# C[C@H](NC(=O)/C(C#N)=C/c1cccc(Br)n1)c1ccccc1         -0.453863    0.219208
# Cc1cc(Nc2cc(CN3CCOCC3)c3nc(C)c(Cc4ccc(Cl)cc4F)n...   -0.291386    2.363030
# Cc1cc(N2CCOCC2)cc2[nH]c(-c3c(NCC(O)c4cccc(Cl)c4...    0.022334    1.221702
# Cl.Cl.c1ccc([C@@H]2C[C@H]2NC2CCNCC2)cc1              -0.223104    1.028180
# O=C(c1ccc(/C=C/c2n[nH]c3ccccc23)cc1)N1CCNCC1          0.712489   -1.004885
# ...                                                        ...         ...
# CCCC(=O)Nc1ccc2c(c1)C(=O)N(C)C[C@H](OC)[C@@H](C...    1.776462    0.822132
# Cc1cc(CS(=O)(=O)c2ccccc2)cc(OCc2ccc(CN3CCC[C@@H...    1.631578    1.147480
# CN(C)CCOc1ccc(/C(=C(\CCCl)c2ccccc2)c2ccccc2)cc1      -0.380853    2.732352
# CC1(C)C=Cc2c(ccc3c2[N+]([O-])=C2C3=C[C@@]34NC(=...    1.601195    1.199945
# C[C@@H]1CC(=O)NN=C1c1ccc(N)c([N+](=O)[O-])c1          1.602481    0.956231
#
#                                                     latent_125  latent_126  \
# C[C@H](NC(=O)/C(C#N)=C/c1cccc(Br)n1)c1ccccc1          0.485712    0.634920
# Cc1cc(Nc2cc(CN3CCOCC3)c3nc(C)c(Cc4ccc(Cl)cc4F)n...   -0.085799   -0.386940
# Cc1cc(N2CCOCC2)cc2[nH]c(-c3c(NCC(O)c4cccc(Cl)c4...   -0.349340    0.164777
# Cl.Cl.c1ccc([C@@H]2C[C@H]2NC2CCNCC2)cc1              -0.352723   -1.239876
# O=C(c1ccc(/C=C/c2n[nH]c3ccccc23)cc1)N1CCNCC1          0.844010    0.255219
# ...                                                        ...         ...
# CCCC(=O)Nc1ccc2c(c1)C(=O)N(C)C[C@H](OC)[C@@H](C...   -1.658626   -1.435088
# Cc1cc(CS(=O)(=O)c2ccccc2)cc(OCc2ccc(CN3CCC[C@@H...    2.037716    1.406872
# CN(C)CCOc1ccc(/C(=C(\CCCl)c2ccccc2)c2ccccc2)cc1      -0.685940   -0.252476
# CC1(C)C=Cc2c(ccc3c2[N+]([O-])=C2C3=C[C@@]34NC(=...    2.200440    1.683513
# C[C@@H]1CC(=O)NN=C1c1ccc(N)c([N+](=O)[O-])c1          0.096436   -0.094039
#
#                                                     latent_127  latent_128
# C[C@H](NC(=O)/C(C#N)=C/c1cccc(Br)n1)c1ccccc1          0.439277    0.078147
# Cc1cc(Nc2cc(CN3CCOCC3)c3nc(C)c(Cc4ccc(Cl)cc4F)n...    0.036858   -0.809442
# Cc1cc(N2CCOCC2)cc2[nH]c(-c3c(NCC(O)c4cccc(Cl)c4...   -1.027404    0.745297
# Cl.Cl.c1ccc([C@@H]2C[C@H]2NC2CCNCC2)cc1               0.246064    1.211902
# O=C(c1ccc(/C=C/c2n[nH]c3ccccc23)cc1)N1CCNCC1          0.302455    0.778227
# ...                                                        ...         ...
# CCCC(=O)Nc1ccc2c(c1)C(=O)N(C)C[C@H](OC)[C@@H](C...    0.541937    1.202558
# Cc1cc(CS(=O)(=O)c2ccccc2)cc(OCc2ccc(CN3CCC[C@@H...   -0.171140   -0.583970
# CN(C)CCOc1ccc(/C(=C(\CCCl)c2ccccc2)c2ccccc2)cc1      -0.519152    0.563595
# CC1(C)C=Cc2c(ccc3c2[N+]([O-])=C2C3=C[C@@]34NC(=...   -0.571433    0.032320
# C[C@@H]1CC(=O)NN=C1c1ccc(N)c([N+](=O)[O-])c1         -0.179094    0.290972
#
# [17869 rows x 128 columns]

# %% [markdown]
# ## Bit of testing
#
# Testing sampled SMILES for validitiy

# %%
def smiles_is_syntatically_valid(smiles):
    return Chem.MolFromSmiles(smiles, sanitize=False) is not None


def smiles_is_semantically_valid(smiles):
    valid = True
    try:
        Chem.SanitizeMol(Chem.MolFromSmiles(smiles, sanitize=False))
    except:
        valid = False
    return valid

# %%
samples = model.sample(1000)
# Out:
# /home/icb/simon.boehm/miniconda3/envs/chemical_CPA/lib/python3.7/site-packages/moses/vae/model.py:217: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /opt/conda/conda-bld/pytorch_1639180594101/work/aten/src/ATen/native/IndexingUtils.h:30.)
#   x[~eos_mask, i] = w[~eos_mask]
# /home/icb/simon.boehm/miniconda3/envs/chemical_CPA/lib/python3.7/site-packages/moses/vae/model.py:219: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (Triggered internally at  /opt/conda/conda-bld/pytorch_1639180594101/work/aten/src/ATen/native/cuda/Indexing.cu:963.)
#   end_pads[i_eos_mask] = i + 1

# %%
syn_valid = sum(smiles_is_syntatically_valid(s) for s in samples) / len(samples)
sem_valid = sum(smiles_is_syntatically_valid(s) for s in samples) / len(samples)
print(f"TOTAL: {len(samples)} SYN: {syn_valid} SEM: {sem_valid}")
# Out:
# TOTAL: 1000 SYN: 0.954 SEM: 0.954

# %%
samples
# Out:
# ['O=C(COC(=O)c1csc2c1CCCC2)[C@H]1C[C@@H](O)[C@H](O)C[C@H]1C(=O)O)C(C)(C)C',
#  'CC(C)c1nc(CNC(=O)c2ccc(-n3cccc3)cc2F)cs1',
#  'CN(C)C(=O)c1ccc(S(=O)(=O)NC[C@H](c2cccc3ccccc23)[NH+]2CCCC2)cc1',
#  'C[C@H]1CC(C(=O)Nc2cc(C(=O)N(C)C)ccc2F)C[C@@H](C)O1',
#  'COc1ccc2c3c([nH]c2c1)[C@@H](CO)N(C(=O)c1ccncc1)CC31CN(C)C1',
#  'CCOc1ccc([C@@H]2CCCN2C(=O)N[C@H](C)c2cn(C)nc2C)cc1',
#  'CC(=O)c1c(C)[nH]c(C(=O)[C@H]2Cc3cc(C)c(C)cc3O2)c1C',
#  'CCc1nn(C)cc1NC(=O)C1C[C@H](C)O[C@H](C)C1',
#  'C[NH+](C)[C@H](CNC(=O)c1cccc(NC(=O)C2CCCCC2)c1)c1ccccc1',
#  'Oc1ccc(-c2csc(C3CCCC3)c2)[nH]1',
#  'Cc1cc(C)cc(C2=CCN(C(=O)c3csc(Cc4cccs4)n3)CC2)c1',
#  'COc1ccc(N2CCOCC2)cc1COC(C)C',
#  'O=C(c1ccn(Cn2cccn2)n1)N1CCC[C@@H](c2nnc3n2CCCC3)C1',
#  'C=CCNC(=O)c1csc(Cc2ccc(F)cc2)n1',
#  'OCC[C@H]1CN(Cc2ccccc2)CC[NH+]1C[C@H]1CCCO1',
#  'CCCN(CC(N)=O)C(=O)C1C(C)(C)C1(C)C',
#  'O=C(NCc1ccc(Cl)cc1)c1cccc(S(=O)(=O)N2CCNC2)c1',
#  'Cc1ccc(NC(=O)COc2ccc3c(=O)c4ccccc4o3)cc2c1',
#  'C#CC[C@H]([NH2+]C1CCC(O)CC1)c1cccs1',
#  'CC1(C#N)CS[C@H]1c1ccccc1',
#  'CC[C@@H](C)[C@H](NS(=O)(=O)c1ccc(F)cc1Br)C(=O)[O-]',
#  'CCN(C(=O)NC1CCN(C(=O)c2c(C)cc(C)cn2)CC1)[C@H]1CCS(=O)(=O)C1',
#  'O=C(Nc1cc(N2CCCC2)ncn1)c1ncnc2[nH]ccc12',
#  'COCCn1c(-c2ccc(OC(F)F)cc2)csc1=S',
#  'O=C(CSCc1ccc(Cl)cc1)N/N=C\\c1ccncc1',
#  'CCC(=O)N[C@H]1C=C[C@@H](C(=O)NCCC)[C@H](CC)C1',
#  'CC(=O)NC(c1cccs1)c1cc(Br)c(Br)s1',
#  'CCO[C@H](C)c1noc(CN2CCN(Cc3ccc4c(c3)OCO4)CC2)n1',
#  'COc1ccc(NC(=O)Nc2ccc3c(c2)CC(=O)N([C@H](C)CO)C[C@H](C)[C@H](CN(C)C(=O)Nc2ccccc2)O3)cc1',
#  'Nc1c(Cl)cc(NC(=O)[C@H]2C[C@H]2c2ccccc2)cc1[N+](=O)[O-]',
#  'CO[C@@H]1CN(C)C(=O)c2ccc(NC(=O)C3=CCCCC3)cc2OC[C@H](C)N(C(=O)Cc2cccnc2)C[C@@H]1C',
#  'CC(C)(C)n1cc(NC(=O)C2CCN(C(=O)c3ccc(O)cc3)CC2)nn1',
#  'O=C(CS(=O)(=O)c1ccccn1)c1ccccc1O[C@@H]1CCOC1',
#  'Cc1cc2occ(CC(=O)Nc3ccc(NC(=O)c4ccc(F)cc4)cc3)c(C)c2nc1C',
#  'C/C(=N\\N1CCN(c2cccc[nH+]2)CC1)c1ccc([N+](=O)[O-])cc1',
#  'CCCCSc1nc(-c2ccccc2)c(-c2ccc(OC)cc2)o1',
#  'O=C(c1ccc(N2CCCC2)c([N+](=O)[O-])c1)N1CCS[C@H]1c1cccc(F)c1',
#  'COc1ccc(NC(=O)c2sc3nc(C)nn3c2C)cc1S(=O)(=O)N1CCCCC1',
#  'O=C1CN(C(=O)c2cc(F)ccc2Br)C(=O)N1c1ccccc1',
#  'O=C1NN(c2cccc(O)c2)C(=O)c2ccsc21',
#  'Cc1cccc(/C=C2\\C(=O)N(c3ccc(Cl)cc3)N=C2C)c1',
#  'Cc1ncccc1-c1noc(-c2ccc3ccccc3c2)n1',
#  'CC(C)NC(=O)N1CC2(C1)[C@@H](c1ccccc1)[C@H](CO)N2C(=O)c1cccs1',
#  'COC(=O)[C@@]1(F)CCN(C(=O)c2sccc2SC)C1',
#  'CC(C)c1nc(CCC(=O)Nc2cnn(C(C)(C)C)c2)cs1',
#  'CCN(Cc1noc(C)n1)C(=O)CCN1C(=O)c2ccccc2S1(=O)=O',
#  'COc1cccc(N2C(=O)C[C@@H](C(=O)NC3CCCCC3)[C@H]2c2ccccc2OC)c1',
#  'Cc1ccc(C[NH2+][C@H](C)CC(C)C)cc1Br',
#  'COc1ccc(Cn2c(N)c([N+](=O)[O-])c(=O)c3ccc(C)cc32)cc1',
#  'C[C@@H]1CCC[C@@H]1NC(=O)C(=O)Nc1ccc(CCSC)cc1',
#  'CCC[C@H](C)NC(=O)[C@H](C)[S@@](=O)Cc1ccc(C)cc1',
#  'C[C@@H](c1cccc(F)c1)N(C)C(=O)c1cn(-c2ccccc2)nn1',
#  'O=C1CN(Cc2ccon2)CCN1',
#  'O=C1NC(=O)N[C@H]1c1cc(F)ccc1NC/C(Cl)=C/Cl',
#  'COc1ccc(N2C(=O)c3cnc4c(c(C)nn4-c4cccc(F)c4)c3N2)cc1OC',
#  'CCCCOc1ccc(/C=C2\\N=C([O-])/C=C/c3ccccc3Cl)cc2NC(=O)COc2ccccc2)c1',
#  'CCNC(=O)C1CCN(C(=O)c2cccc(C3=NC(=O)N(c4ccccc4)C3=O)n2)CC1',
#  'COCCn1c(C)cc(/C=C2\\SC(=O)N(CC(=O)N3CCOCC2)C(=O)N2C)c1C',
#  'CC1CCN(c2nc(C(=O)[O-])cn(-c3cccc(C(F)(F)F)c3)c2=S)CC1',
#  'O=C(N[C@H]1CC(=O)N(CCc2ccccc2)C1)c1ccccc1Cl',
#  'O=C(CNC(=O)Nc1ccccc1Cn1cncn1)c1ccccc1',
#  'Cn1nnc2cc(C(=O)NC3(CN4CCOCC4)CCOCC3)ccc21',
#  'O=C(NCc1ccccn1)c1ccc(COc2ccc(F)cc2)o1',
#  'O=C([C@H]1CC(=O)N(c2cccc(Br)c2)C1)N1CCN(CC(F)F)CC1',
#  'CC(C)NC(=O)Nc1ccc2c(c1)C(=O)N([C@@H](C)CO)C[C@@H](C)[C@H](CNC(=O)Nc1ccc(F)cc1)O2',
#  'CC[C@H](C(=O)NCc1ccc2c(c1)CCC2)n(C)c1=O',
#  'O=C(Nc1cccc2c1C(=O)N(c1ccccc1)C2=O)c1cccc([N+](=O)[O-])c1',
#  'CCC[C@@H]([NH2+]C1CC[NH+]([C@@H]2CCOC2)C1)C(=O)N1C[C@@H](C)C[C@@H](C)C1',
#  'CC(=O)N1CCNc2cc(Cl)ccc2C(=O)c2ccccc21',
#  'COc1nc2cccc(C(=O)N[C@@H](C)C3CC3)c2n(C)c1=O',
#  'CC[C@H]1CCCC[C@@H]1[C@H](OC[C@@H](F)C(=O)OC)c1cccc(C)c1',
#  'C[C@H]1CN([C@@H](C)CO)C(=O)c2c(c3ccccc3n2C)-c2ccccc2CO[C@H]1CN(C)C(=O)Cc1ccncc1',
#  'COc1sc(NC(=O)N[C@H](C)C(=O)N2CCCC[C@@H]2C)c(C)c1C',
#  'C[C@@H]1CC(NC[C@@H](Cc2ccccc2)[NH2+]C2CC2)C[C@H](C)O1',
#  'CCN(Cc1ccoc1)S(=O)(=O)c1ccc(CC#N)cc1',
#  'O[C@@H](CNCc1ccc(C(F)(F)F)cc1)c1ccco1',
#  'CCN(CC)C(=O)c1cccc(NC(=O)[C@H]2C[C@H]2C)c1',
#  'Cc1nn(-c2ccccc2)c(N2CCCN(C(=O)COc3ccccc3)CC2)n1',
#  'CCO[C@@H]1C[C@H]([O-])C12CC[NH+](Cc1c[nH]nc1-c1ccc(OC)cc1)CC2',
#  'CC(=O)N[C@H](C(=O)N[C@H]1CCCCOCC1)[C@@H](C)CO',
#  'O=C([O-])c1ccccc1S[C@H]1CCOC2(CCC2)C1',
#  'Cc1ccc(OC[C@@H](O)CN2CCN(c3ccc([N+](=O)[O-])c(N)c3)CC2)c(C)c1',
#  'O=C1C[NH+](Cc2ccccc2)C[C@H]1CN([C@H]1CCSC1)C(=O)c1cccs1',
#  'C[C@H](C[C@H]1CCCCC[NH2+]1)[NH2+]CCn1cccn1',
#  'C[C@H]1CCCN(C(=O)CN(CCO)c2ccccc2)C1',
#  'CN1CCOc2ccc(NS(=O)(=O)c3ccc4[nH]c(C)cc4c3)c(Br)c2O1',
#  'CC[C@@](C)(CC1=NN(Cc2ccccc2)C(=O)N1c1cccc(Br)c1)OC',
#  'CC(C)C[C@@H](C[NH3+])C(=O)N[C@@H]1CCSc2c(F)cccc21',
#  'CCNC(=O)Nc1ccc(OC)c(NC(=O)CNC(F)(F)F)c1',
#  'Cc1ccc(C(=O)CCCCSC(C)(C)C)cc1O',
#  'Cc1noc(C)c1COC(=O)c1cc(S(=O)(=O)N2CCOCC2)c(Cl)cc1Cl',
#  'C[C@H]1CCC[C@H]1[NH2+]C[C@@H](C)S(=O)(=O)c1ccc(F)cc1F',
#  'COc1ccc(-c2nc3s/c(=C\\c4ccc(N(C)C)c(C)c4)c(=O)n32)cc1OC',
#  'Cc1ccc(S(=O)(=O)[C@H]2CS(=O)(=O)C[C@@H]2[N+](=O)[O-])cc1',
#  'CC(C)(CNC(=O)/C=C/c1cnc2ccccc2n1)c1ccco1',
#  'O=S(=O)(NC[C@H](C[NH+]1CCCC1)c1ccc(F)cc1)c1ccc(F)cc1',
#  'O=C(NCC1CCN(S(=O)(=O)c2cccc(F)c2)CC1)C(=O)Nc1cccc2ccccc12',
#  'CCC1CCN(C(=O)c2cccc(Oc3ccc(C)cc3)n2)CC1',
#  'O=C1C[C@H](Nc2cccc(Cl)c2Cl)C(=O)N1Cc1ccc(Cl)cc1',
#  'C[C@H]1CCCCO[C@@H](CN(C)CC2CC2)[C@@H](C)CN([C@H](C)CO)C(=O)c2cc(NC(=O)c3ccncc3)ccc2O1',
#  'COc1ccc(S(N)(=O)=O)cc1NC(=O)c1ccc[nH]1',
#  'Cc1ccccc1CC[C@H]1CCC[NH+](Cc2nnc(-c3ccccc3C)n2C)C1',
#  'C=C(Cl)CSc1ncnc2sc(-c3ccccc3)cc12',
#  'C[NH+](C)C(C)(C)[C@@H](N)c1ccc(O)cc1[N+](=O)[O-]',
#  'CN1C(=O)c2ccc(NC(=O)Cc3cccs3)cc2C1=O',
#  'N#CCCOC(=O)COc1ccc(Br)cc1Cl',
#  'CCCOC(=O)c1c(O)cc(O)cc1OC',
#  'COc1cccc([C@@H](CNC(=O)[C@H]2Cc3cc(F)ccc3O2)N2CCOCC2)c1',
#  'CC(C)[C@@H](NC(=O)Nc1ccccc1Cl)c1ccccc1',
#  'OC[C@@H](Cc1ccccc1)NCc1cnc(-c2cccs2)s1',
#  'O=C([O-])c1ccc(/C=N/N2C(=S)[N/C3=NC=C[C@H]3S2)cc1',
#  'Cn1c(=O)[nH]c(=O)c2c1nc(SCC(=O)[O-])n2CCCc1ccccc1',
#  'Cc1cc(OC(C)(C)C)cc([C@@H](Br)[C@H]2CCS(=O)(=O)C2)[nH+]1',
#  'Cc1ccc(-c2cc(CNC(=O)CO[C@H]3CC(C)(C)C[C@@H]3N4)co2)cc1',
#  'O=C(CCn1c(=O)oc2ccccc21)Nc1ccnn1C1CCN(c2ccc(O)cc2)CC1',
#  'CCc1cc(C(=O)N[C@H]2CCCC[C@H]2NS(N)(=O)=O)c(C)o1',
#  'CC(=O)CCCC(=O)N1CCC2=NN=C(C2=c4ccccc4=[NH+][C@@H]2[C@H]1c2ccccc2C)C1',
#  'C[C@@H]1CN(C(=O)c2n[nH]c3ccc(Cl)cc23)C(C)(C)CO1',
#  'COC(=O)[C@@H](C)N(C(=O)c1cnc(-c2cccc(Cl)c2)nc1C)C1CC1',
#  'O=C(C[C@H]1CC[C@H]2[C@@H](COC[C@H](O)CN2Cc2ccc3c(c2)OCO3)O1)N1CCCCC1',
#  'CCOc1cc(/C=C2/NC(=S)N(C)C2=O)cc(Cl)c1OC',
#  'C[C@H]1CCCCO[C@H](CN(C)CC2CC2)[C@@H](C)CN([C@@H](C)CO)C(=O)c2cc(NC(=O)c3ccncc3)ccc2O1',
#  'CC(C)(C)OC(=O)N1Cc2ccccc2N[C@@H]1Cc1cccc(C2CC2)c1',
#  'C[C@H](c1ccncc1)c1nnc(SCC(=O)Nc2c(C)cccc2C)o1',
#  'Cc1n[nH]c(C)c1C[C@H](C)C(=O)NCCc1ccccc1',
#  'COc1ccccc1-n1cnnc1S[C@H](C)c1nc2sc(C)c(C)c2c(=O)[nH]1',
#  'O=C(CN1N=C(c2ccc(F)cc2)CCCC1)N1CCN(Cc2ccc3c(c2)OCO3)CC1',
#  'Cc1n[nH]c(C)c1CCCNC(=O)Nc1ccc2[nH]ccc2c1',
#  'COc1cc2c(cc1OC)C(CCNC(=O)c1ccc(CN3CCCC3=O)cc1)OCCO2',
#  'Cn1c(=O)c2ccccc2n2c(CN3CCOCC3)nnc12',
#  'CCNc1nc([C@@H]2CN3CCC[C@@H]3CO2)n[nH]c1N',
#  'Nc1[nH]ncc1NC(=O)CCCO',
#  'COC(=O)C(C)(C)NC(=O)[C@@H](C)NC(=O)c1ccc(C)cc1',
#  'Cc1ccc(F)c(NC(=O)Cn2ccc(=O)c3cccnc32)c1',
#  'CCOc1ccc(S(=O)(=O)Nc2ccc3c(c2)CCC(=O)N3C)cc1',
#  'Cc1cccc(C)c1NC(=O)[C@@H](C)SCC(=O)N1CCC(n2c(=O)[nH]c3ccccc32)CC1',
#  'C[C@H]1[NH2+]CC[C@@H]1C(=O)NCCc1cccc(F)c1',
#  'CCN(C(=O)C1CCN(S(=O)(=O)c2ccccc2Cl)CC1)c1ccc(C(C)C)cc1',
#  'CC[C@@H](NC(=O)CN1CC[C@H]([N+]2=CCCC2)C1)c1ccc(F)cc1',
#  'C[C@@H](c1ccc(Cl)cc1)[C@@H](C)N1C(=O)c2ccccc2S1(=O)=O',
#  'CC(=O)N[C@H](NC(=O)COc1ccc(Br)cc1F)C(C)C',
#  'COc1cccc(C[NH+](C)[C@H](C)Cn2cc(Br)cn2)c1',
#  'C[C@@](C#N)(Nc1cccc2ccccc12)C(F)(F)F',
#  'O=C1NC(=O)N2CCSc3ccc(C(=O)Nc4ccc([N+](=O)[O-])cc4)cc3C1c1ccccc12',
#  'OCCN(CCC(F)(F)F)Cc1c[nH]cn1',
#  'O=C(Nc1nc2c(s1)CN(C(=O)CCC[NH+]1CCc2ccccc21)CC2)[C@H]1CCCO1',
#  'O=C(NCCc1ccccc1)[C@H]1C[C@@H]1c1cccc(Cl)c1F',
#  'CCc1ccc(C(=O)NCc2ccccc2OC(F)F)cc1',
#  'Cc1ccc(-n2[nH]c(C(=O)[O-])cc2N2CCN(C(=O)c3ccoc3)CC2)cc1',
#  'CC(=O)[C@@]1(O)CCC2C3CC=CC(C3)CC[C@H]12',
#  'CCS(=O)(=O)[N-]c1ccc([N+](=O)[O-])c(C(=O)OC)c1',
#  'C[C@H]([NH3+])c1ccccc1N(C)C1CCC1',
#  'COCCO[C@@H](C)C(=O)Nc1ccc2c(c1)COC2',
#  'Cc1[nH]c2ccc(F)cc2c1CSCCO',
#  'COc1ccc(OCC(=O)N2CCn3cccc3[C@@H]2C)cc1',
#  'Cc1nccn1-c1ccccc1C[C@@H](Cl)c1ccccc1',
#  'COc1ccc([C@H](O)[C@H](C)NC(=O)C[C@@H]2C[NH2+]CCO2)cc1',
#  'O=C1CN=C(c2ccc(Cl)cc2)C(c2ccc(C(=O)Nc3ccc([N+](=O)[O-])cc3)c2O)N1',
#  'O=C(NN=Cc1ccc([N+](=O)[O-])cc1)N1CCN(C(=O)c2cccs2)CC1',
#  'C[C@H]1SCCN(Cc2cccc(N3CCOCC3)c2)[C@@H]1C',
#  'CC(C)NC(=O)Nc1ccc2c(c1)CC(=O)N([C@H](C)CO)C[C@H](C)[C@H](CN(C)CC1CCOCC1)O2',
#  'CC(=O)N1CCN(c2cc(Cl)nc3ccccc23)CC1',
#  'Clc1cccc([C@H]2C[NH2+]C[C@@H]2c2ccccc2Cl)n1',
#  'CCC(=O)c1ccc(OCc2ccc(C(=O)N(C)CC(C)C)o2)cc1',
#  'O=[N+]([O-])c1cnc(NCCc2ccc(Cl)cc2)cc1[N+](=O)[O-]',
#  'O=S(=O)(NC[C@]1(O)CCC[NH+](Cc2ccncc2)C1=O)C1CCCC1',
#  'Cc1nn([C@H]2CCCS[C@@H]2C)c2ccccc12',
#  'CCN(CC)C(=O)N[C@@H](c1ccccc1)C(C)(C)C',
#  'CC(C)NC(=O)N(C)C[C@H]1OCCCC[C@@H](C)Oc2ccc(NC(=O)c3ccccc3)cc2C(=O)N([C@H](C)CO)C[C@H]1C',
#  'CC1(C)CN(C(=O)[C@H]2CCC[C@H]2Cl)CCC1=O',
#  'C[C@@H]1c2ccccc2O[C@H]1C(=O)NNC(=O)C(C)(C)C',
#  'CCC(=O)N1CC2(CN(CC3CCCC3)[C@H](CO)c3c2c2ccc(OC)cc2n3C)C1',
#  'Cc1cc(C)cc(NC(=O)N[C@@H](CCO)c2cccs2)c1',
#  'CC[NH+](CC)c1ccc(NC(=O)c2cc(C)nc3ccccc23)cc1',
#  'CCC(=O)[C@H](C)CCCC',
#  'C[C@]1(c2ccc3c(c2)OCO3)NC(=O)N(CC(=O)Nc2ccc3c(c2)OCCO3)C1=O',
#  'CC[C@H]1CCCC[C@]12NC(=O)N(CC(=O)Nc1cc(C)on1)C1=O',
#  'C[C@@H]1CCCC[C@H]1N(C)C(=O)CCNS(=O)(=O)c1ccc(F)cc1',
#  'FC(F)(F)c1cc([C@H]2CCCN2S(=O)(=O)c2cccs2)cn1',
#  'CC1CCN(c2ncnc(N(C[NH+](C)C)c3ccccc32)CC(C)(C)[NH2+]C(C)CC1',
#  'O=S(=O)(c1ccc(Cl)s1)N1CCSC[C@H]1c1ccc(F)cc1',
#  'Cc1ccc(C(=O)Nc2ccc(NC(=O)N3C[C@H](C)O[C@H](C)C3)cc2)cc1F',
#  'CN(C)/C=N/Nc1ccc([N+](=O)[O-])cc1Br',
#  'Cc1ccc(N2C(=O)NC(=O)/C(=C\\c3ccccc3Oc3ccccc3)C2=O)cc1',
#  'CC(C)[NH+](CC(=O)Nc1ccc(N2CCCC2)cc1)C[C@@H]1CCS(=O)(=O)C1',
#  'Cc1noc(C)c1[C@@H](C)CN[C@@H](C)c1cnc(C)s1',
#  'CN(C)c1cc(COC(C)(C)C[NH2+]C2CC2)ccc1F',
#  'Cc1cc2ncc([C@@H](C)[NH2+]Cc3cc(F)cc(F)c3)c(C)n2n1',
#  'CC(C)[C@@H]1CN(Cc2ccc3c(c2)OCO3)C(=O)NC1=O',
#  'CC[C@@H](OC(=O)c1cn(Cc2cccnc2)nn1)[C@@H]1COc2ccccc21',
#  'Cc1nc2ccc(N(C)C(=O)CCc3cccc(F)c3)cc2o1',
#  'COc1cc([C@@H](O)Cc2nccs2)ccn1',
#  'NC(=O)CC1CC[NH+](Cc2cccc(Cl)c2)CC1',
#  'COc1ccc(-c2nc([C@H](C)NC(=O)c3ccncc3)c(-c3ccoc3)c2Cl)c([N+](=O)[O-])c1',
#  'Cc1ccccc1CCNC(=O)C[S@](=O)c1nnn(-c2ccccc2F)n1',
#  'c1[nH+]cn([C@@H]2CNCCO2)c1[O-]',
#  'c1cc(CN2CCN(Cc3cnc(N4C[C@H]4CCCC[NH2+]4)CC3)c[nH+]2)c[nH+]1',
#  'O[C@@]1(C(F)(F)F)CCN(Cc2cc(F)cc(Br)c2)C1',
#  'CC(C)c1cccc(S(=O)(=O)OCC#CCSc2ncn[nH]2)c1',
#  'CCN(CCCc1ccc(F)cc1)c1ccccc1/C=C1/C(=N)N2N=CSC2=NC1=O',
#  'Cc1ccc(CC(=O)NC[C@@H]2CCS(=O)(=O)C2)cc1F',
#  'COc1ccc2c3c([nH]c2c1)[C@@H](CO)N(Cc1cccc(F)c1)CC31CN(S(=O)(=O)c2ccc(Cl)cc2)C1',
#  'CCOc1ccc(N2/C(=N\\C(=O)c3cc4ccccc4oc3=O)CC[NH+]2C)cc1NC(C)=O',
#  'C[C@H](Sc1ccccn1)C(=O)Nc1ccccc1OC(C)(C)C',
#  'C[C@H]1CCN(C(=O)CN2CCCCC2)[C@@H]2CS(=O)(=O)C[C@H]2S1',
#  'NNc1nc(Cl)nc2sc3c(c12)CCCCC3',
#  'O=S(=O)(c1ccc(F)cc1)N1CCCN(CC2=Cc3ccccc3OC2)CC1',
#  'C[C@@]1(c2ccc(F)c(F)c2)C[NH2+]C[C@@H]1C',
#  'CCCCN(C)C(=O)N1CCCC[C@@H]1[C@@H]1CCC(C)(C)[C@@H]1[NH+](C)C',
#  'C[C@@H]1CCC[C@H]1NC(=O)CCn1c2ccccc2c2ccccc21',
#  'Cc1ccc2ncc(C(=O)NCC(C)(C)c3ccncc3)c2n1',
#  'COc1ccc(CN(Cc2cc3cc(C)c(C)cc3[nH]2)C(C)C)cc1',
#  'COC(=O)c1cn(-c2cc(N)c3c(C)c(Cl)ccc3[nH]2)nn1',
#  'C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2ccc(-c3ccccc3)cc2)Oc2ccc(NC(=O)Nc3ccccc3)cc2CC1=O',
#  'CCc1noc(C)c1C(=O)Nc1cc(Cl)ccc1C(N)=O',
#  'CC[C@H]1CCCCN1C(=O)CN(C)Cc1nc2cc(C(=O)[O-])ccc2n1C',
#  'O=C(Oc1ccc(-n2cnnn2)cc1)c1ccccc1C(F)(F)F',
#  'NC(=O)CN1CC(CO)(CO)Cc1ccccc1',
#  'C[C@@](O)(CNC(=O)/C=C/c1ccc([C@@H]2C[C@H]2C)o1)c1cccs1',
#  'O=C1NC(=O)[C@H](c2cccc(F)c2)C1',
#  'COc1ccccc1[C@@H]1CCCN1S(=O)(=O)c1ccccc1',
#  'C[C@@H](CNC(=O)NC[C@H]1CCS(=O)(=O)C1)[NH+]1CCC(c2ccc(F)cc2)CC1',
#  'COc1ccc2c3c(n(C)c2c1)[C@H](CO)N(C(=O)c1ccc(F)cc1)CC3',
#  'COc1cccc([C@@H](NC(=O)c2ccc([N+](=O)[O-])cc2)C(C)C)c1',
#  'OCc1ccc(O[C@H]2CCO[C@]3(CCOC3)C2)cc1',
#  'COc1ccc(NC(=O)c2cc(C)nc(N)n2)cc1S(=O)(=O)N1CCOCC1',
#  'O=C(N[C@@H]1CCN(c2ccccc2)C1)C12CC3CC(CC(C3)C1)C2',
#  'CO[C@@H](C)c1nc(Cc2nc3ccccc3[nH]2)ccc1F',
#  'CC(C)CC[C@@H](C)NC(=O)c1ccnc(OCc2ccccc2)c1',
#  'COc1ccc(CNC(=O)CC2(O)CCCC2)c(-c2ccc(Cl)cc2)n1',
#  'Cn1c(=O)c(=O)[nH]c2cc(C(=O)NCc3c[nH]c4ccccc34)ccc21',
#  'C[C@H]1CCC[C@](CO)(NC(=O)N[C@@H]2CCC[C@@H](C)[C@@H]2C)C1',
#  'CN(C(=O)COC[C@H]1CCCCO1)[C@H]1CCCc2ccccc21',
#  'CCOc1cc([C@H](C)NCCc2cn(C)nc2C(C)(C)C)ccc1OC',
#  'COc1c(Br)cc(Cl)cc1NC1CCN(C)CC1',
#  'Cc1cccc(N2C[C@H](C(=O)NC[C@@](O)(N3CCOCC3)C3CCCCC3)CC2=O)cc1C',
#  'COc1c(F)cc(NC(=O)[C@@H](C)Oc2ccc(F)cc2)cc1C(C)C',
#  'O=C(CCc1cccc(F)c1)NN[C@@H](C(N)=O)c1ccccc1',
#  'COC1CCN(C(=O)Cc2ccc3c(c2)OCO3)CC1',
#  'CN[C@]1(C(=O)OC)CCC[C@H]([NH+](C)C2CCCCC2)C1',
#  'COc1ccc(N2C[C@H](C)SC2=C2C#N)cc1OC(C)=O',
#  'C=CCN(C(=O)[C@@H]1CSC(=O)N1)[C@H]1C=C(CO)C[C@@H]1C',
#  'C[C@@H](NC(=O)CCN1CCN(C)CC1)c1ccc(F)c(F)c1',
#  'CCOc1ccc(CC(=O)NCc2cnn(-c3ccccc3)c2)cc1',
#  'COCc1nn(C)c2c1NC(=O)C[C@@]21C(=O)NCc2cc(OC)c(OC)cc2OC[C@H]1C',
#  'N#CCC[NH+](CC1CCCCC1)CC1CC1',
#  'Cc1nn(C)c(Cl)c1C[NH2+]C[C@@H]1CCN(c2ccc(Cl)cc2)C1',
#  'Cc1cc([C@@H](C)[NH2+]Cc2cn(-c3ccccc3)nn2)cc(F)c1F',
#  'COc1cc2c(cc1OC)[C@@H](c1ccccc1)N(Cc1cc(=O)n3cc(C)ccc3n1)CC2',
#  'COc1ccc(OC)c(S(=O)(=O)N[C@@H](C)c2ccc(F)c(F)c2)c1',
#  'CC[NH+]1CCN(C2=NC(=O)C[C@@H](c3ccc(C)o3)(C(F)(F)F)C2=O)CC1',
#  'CCn1c(C[C@H](N)c2c(C)cc(C)c(C)n2)nc2cc(Cl)c(C)cc21',
#  'O=C(N[C@@H]1CCOc2ccccc21)[C@@H]1CC=CCC1',
#  'COc1ccc(NC(=O)Cn2cc(C(=O)c3c(Cl)cccc3Cl)c(=O)c3cc(Cl)ccc32)cc1',
#  'O=C(C[C@H]1C[C@@H]2c3cc(NC(=O)C4CCC4)ccc3O[C@@H]2[C@@H](CO)O1)NC1CCCC1',
#  'Cc1ccc(NC(=O)c2cccnc2)cc1S(=O)(=O)N(CCC)[C@H]1CCc2ccccc21',
#  'O=C(NC(=S)Nc1ccc(NC(=O)c2ccco2)c([N+](=O)[O-])c1)c1ccc2c(c1)CCCC2',
#  'CS(=O)(=O)c1ccc(NC(=O)N2CC[C@@]3(O)CCCC[C@@H]32)c(Cl)c1',
#  'CS(=O)(=O)[C@H]1CCC[C@H](NC(=O)[C@@H]2C[C@@H]2c2cccc(F)c2F)C1',
#  'Cc1c(P(=S)(c2ccccc2)c2ccccc2)c2ncnn2n(-c2ccc(F)cc2)c1=O',
#  'C[C@H]1CN(C)c2ccccc2CN1S(=O)(=O)c1ccc(C=O)nc1',
#  'COc1ccc([C@@H](CC(=O)NC(N)=O)C(C)(C)C)cc1',
#  'O=C(N=c1[nH]c2ccccc2n1)N1CCC(n2cncn2)CC1',
#  'CN1C(=O)C[C@@H](NC(=O)N2CC[C@H]([NH+]3CCOCC3)C2)C12CCC2',
#  'Cc1ccc(CC(=O)N/N=C/c2ccc(O)cc2O)cc1',
#  'Fc1cc(Br)cc(-c2n[nH]c(CO)n2)c1',
#  'C[NH+]1CCC[C@H](CNc2ccc(CCN3cc3ccccc23)C1',
#  'CCCCN(CC(N)=O)C(=O)c1ccc(NC#N)cc1',
#  'CCOc1ccc(/C(C)=N/NC(=O)C(O)(c2ccccc2)c2ccccc2)cc1',
#  'CC[C@@H](C)N(Cc1csc(CO)n1)[C@H]1CCSC1',
#  'Cc1ccc(C#N)c([C@@H]2CCCN2C(=O)c2cncc(F)c2)n1',
#  'CO[C@]1(C)C[C@H](N(CC(=O)[O-])C(C)C)C1(C)C',
#  'C[C@@H]1CN([C@H](C)CO)C(=O)c2cccc(NS(C)(=O)=O)c2O[C@@H]1CN(C)C(=O)Nc1cccc2ccccc12',
#  'CO[C@@H](C)c1nc(C[NH+](C)CCc2cccs2)cs1',
#  'CCC1(CC)CC(=O)N(c2cc(C)ccc2C)C1=O',
#  'COc1ccc(-c2csc(N3CCN(C(=O)c4c[nH]c5ccccc45)CC3)n2)cc1OC',
#  'C[C@@H](Sc1nnc(C2CC2)n1C1CC1)C(=O)Nc1ccccc1C#N',
#  'COc1cccc(CNC(=O)c2cnc3snnc3c2)c1',
#  'COCC(=O)N[C@@H]1CCCc2ccc(F)cc21',
#  'COc1ccc([C@@H](CNC(=O)c2cc3ccccc3[nH]2)[NH+]2CCCC2)cc1',
#  'C[NH+](C)CCSCc1nonc1C',
#  'C[C@@H](Cc1ccsc1)NC(=O)[C@H]1C[C@@H]1c1ccc(F)cc1',
#  'COC1(c2ccc(OC)cc2)CCN(C(=O)[C@H]2C[C@@H]2[N+](=O)[O-])CC1',
#  'Nc1ccc([N+](=O)[O-])cc1C(=O)[O-]',
#  'CCOc1c(Cl)cc(CN2CCO[C@H](C)[C@H]2C)cc1OC',
#  'C[C@@H]([NH2+]CC1([C@](C)(O)CCOCC1)C(=O)Nc1ccccc1)Cc1ccccc1',
#  'Cc1cscc1C(=O)N[C@@H]1CCCN(c2cnn(C)c(C)c2)C1',
#  'CCOc1ccc2ccccc2c1/C=N\\C(=O)c1ccc(=O)n(C)c1',
#  'C[C@@H]1C[C@H]1c1ccc(C[NH+](C)Cc2nnc(C)n2C)o1',
#  'C/[NH+]=C(/NCC[NH+]1CCC[C@H](C)C1)N[C@@H]1CS[C@@H](C)C1',
#  'C[C@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]1CN(C)C(=O)Nc1ccccc1',
#  'C[NH+]1CCC(C(=O)c2ccc3ccccc3c2)CC1',
#  'C#CCNC(=O)c1cc2ccccc2oc1=O',
#  'O=[S@](Cc1nnc(Cc2ccccc2)nc1-c1ccccc1)S(C)(=O)=O',
#  'Cc1cc(NC(=O)CCc2ccc3ccccc3c2)no1',
#  'CC(=O)Nc1cc(NC(=O)C(=O)NC[C@@H]2CCCc3ccccc32)ccc1Cl',
#  'O=C([O-])CC[NH+]1CCc2ccccc2[C@@H]1c1ccccn1',
#  'CN1C(=O)[C@]2(c3ccccc31)c1ccccc1S2',
#  'FC(F)(F)C1(C(F)F)CCN(c2ncnc3ccsc23)C1',
#  'Cc1ccc(Nc2ncnc(N3CCN(c4cccc(Cl)c4)CC3)c2[N+](=O)[O-])cc1C',
#  'Cn1nnnc1Sc1cc(Cl)cc(Cl)c1N',
#  'CC(=O)N1CCCN(C(=O)[C@@H]2CCCC[C@H]2C(=O)OC)CC1',
#  'COc1ccc(N[C@@H](C)[C@H](C)O)cc1OC1CCCC1',
#  'COc1ccccc1OCC(=O)Nc1ccccc1-n1cccn1',
#  'Cc1nc(C[C@@H]([NH3+])[C@@H]2CN(C)CCO2)sc1C',
#  'CC(=O)CCCc1c(S(C)=O)c(C)nn1-c1ccccc1',
#  'O=C1CC[C@H](n2nnc3ccccc32)[C@H]1Cl',
#  'CN(N)c1ccc([N+](=O)[O-])c(-c2ccc(F)cc2)[nH+]1',
#  '[NH3+]CC1([C@H](O)c2ccc(OC(F)(F)F)cc2)CCCC1',
#  'O=C1N(CCC2CCCCC2)CCC[C@]1(O)CN1C(=O)c2ccccc2C1=O',
#  'Cc1ccc(CS(=O)(=O)Nc2ccccc2)cc1[N+](=O)[O-]',
#  'O=C(NC[C@H]1CC[NH+](C2CC2)C1)N1CCN(c2cc[nH+]cc2)CC1',
#  'CC[C@H](OC1CCC1)C(=O)Nc1ccccc1C(=O)Nn1cnnc1',
#  'Cc1ccn2cc(C(=O)N3CCC(CO)(Cc4ccc(F)cc4)CC3)nc2c1',
#  'CCn1cc(S(=O)(=O)N2CCC(C(=O)Nc3ccc(C)cc3)CC2)cn1',
#  'C[C@@H](O)CC[NH+](C)Cc1c([O-])cc(Br)cc1[N+](=O)[O-]',
#  'Cc1oc2c(C)c(OC(C)=O)c(C)c(-c3ccc(Cl)cc3)cc2c1C',
#  'Cc1cc(C)c(NC(=O)CN(C)C(=O)C[NH+]2CCC[C@H](C)C2)c(C)c1',
#  'c1cc(-c2n[nH]c([C@@H]3C[NH2+]C[C@H]3CO)n2)cs1',
#  'Cc1cccc([C@@H](CO)NC(=O)[C@@H]2CC(=O)N(Cc3ccccc3)C2)c1',
#  'CCO[C@H]1NC(=O)c2cc(NC(=O)c3cscn3)ccc2OC[C@H]1C',
#  'CCOc1ccc(NS(=O)(=O)c2c[nH]cn2)cc1F',
#  'CCC(CC)[C@@H](C[NH3+])c1ccccc1F',
#  'N#Cc1ncn(CC(=O)c2ccco2)n1',
#  'CC[C@H](C)NC(=O)c1ccc2c(c1)[C@H]1C=CC[C@H]1[C@@H](c1ccc([N+](=O)[O-])cc1)N2',
#  'CCc1nn(C)cc1NC(=O)NC(C)(C)CC(C)(C)C',
#  'CCOc1ccc(OCC)c(N[C@H]2CC[C@H]([NH3+])C2)c1',
#  'CCC[NH2+][C@H]1CC[C@@H](SC[C@H](C)O)C1',
#  'CO[C@@H](CNC(=O)C(=O)Nc1c(C)nn(C)c1C)c1ccc(C)c(F)c1',
#  'N#C[C@@H]1[C@@H](c2ccc(C#CC3CC3)cc2)[C@@H](CO)N1C(=O)C1CCCC1',
#  'COC(=O)[C@@H]1CN(C(=O)NC[C@@H]2CCCO2)C[C@H]1C',
#  'COc1ccc([C@H]2Oc3ccc(C)cc3C(=O)N2[C@H](C)c2nccs2)cc1OC',
#  'COc1cccc([C@H]2Nc3ccc(F)cc3[C@H](c3ccc(F)cc3)N2)c1O',
#  'Cc1cc(C)c(NC(=O)CC[C@@H]2CCCN(C(=O)c3cnn(C)c3)C2)nc1C',
#  'COCCN1CCN(C(=O)/C=C/c2cc(C)[nH]n2)CC1',
#  'C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]1CN(C)Cc1ccc(-c2ccccc2)cc1',
#  'CC(=O)Nc1cccc(NC(=O)[C@@H]2CCCCN2C(=O)c2ccc(Cl)cc2)c1',
#  'Cc1ccc2nc(C(=O)OCCNC(=O)N3CCOCC3)c(C3CC3)c(Cl)c2c1',
#  'C[NH+]1CCC[C@H](CNC(=O)c2sccc2Br)C1',
#  'COc1cc(I)c(C)cc1S(=O)(=O)N[C@H]1C[C@H]2CC[C@@H]1C2',
#  'C#CCNC(=O)[C@@]1(Cc2ccccc2-c2cccnc2)CCN(C(=O)c2ccccc2)C1',
#  'COc1ccccc1CNC(=O)C[C@@H]1CC[C@H]2[C@@H](COC[C@H](O)CN2Cc2cccc(-c3ccccc3F)c2)O1',
#  'Cc1ccc(C(=O)N(C)C)cc1/N=C/c1cc2ccccc2[nH]1',
#  'O=C1CN(C(=O)c2ccnc(OC3CCC3)c2)CCN1',
#  'CNc1cccc(CN2CC[C@@H]([NH+]3CCc4ccccc4C3)C2)c1[N+](=O)[O-]',
#  'C=C(C)COc1ccccc1NS(=O)(=O)c1ccc(CCCC)cc1',
#  'CCNC(=O)c1cc2cc(C)c(NC(=O)c3cccnc3C)cc2oc1=O',
#  'CC1(C)[C@@H](Br)C2(CCCCC2)C1',
#  'Cn1/c(=N/C(=O)Cc2ccc3c(c2)OCO3)sc2c1CCN(Cc1ccccc1)C2',
#  'Cc1cc(Cl)ccc1OCC(=O)Nc1cccc(C(=O)N2CCC(C)CC2)c1',
#  'CSc1cccc(CNC(=O)N[C@@H]2C[C@@H]3CCCc4cccc2c43)c1',
#  'Cc1cc(OCC(=O)c2ccc(F)cc2)c(C)n1C1CC1',
#  'COC(=O)c1cc(C)sc1NC(=O)C(=O)NCc1ccco1',
#  'CC(C)(C)OC(=O)[C@@H]1[C@@H]2C(=O)N(C3CCCCC3)C[C@]2(O)C1(C)CO',
#  'Nc1c(C(=O)NCc2ccco2)cc(=O)n2nccc12',
#  'CC(C)[C@@H](NC(=O)C1CCN(C(=O)NC2CCCC2)CC1)c1cccnc1',
#  'Cc1ccc(CC(=O)N2CC[NH+](C)CC2)c2nccnc12',
#  'C[C@H](Nc1ccc2c(c1)N(C)CC2)C(=O)N[C@H]1CC[NH+](C)[C@H]1c1cccc(C#N)c1',
#  'O=C(Cc1csc(-c2ccoc2)n1)N1CCN(C(=O)C2CC2)CC1',
#  'CO[C@H]1CCCN(C(=O)N[C@H](c2ncc(Cc3cccs3)o2)C2CC2)C1',
#  'Cc1cc(CNC(=O)c2cc(=O)c3cccc(OCC#N)c3)on2)cc1',
#  'O=C1/C(=C\\c2ccc(-c3cc(Cl)ccc3[N+](=O)[O-])o2)C(=O)NC1=S',
#  'COc1ccc(S(=O)(=O)N[C@@H]2CC[C@@H](CCN)O[C@@H]2CO)cc1',
#  'COc1cccc(NC(=O)[C@H]2Cc3ccccc3CN2S(=O)(=O)c2cc(C)ccc2F)c1',
#  'Cc1ccc(C)c(Cn2nnc3c(=O)[nH]c(N4CCN(CC(=O)[O-])CC4)nc32)c1',
#  'Cc1ccc([C@@](C)(O)[C@H]2CCOC3(CCCC3)C2)o1',
#  'O=S(=O)(C[C@@H](O)CO)CCCCCc1ccccc1',
#  'Cc1ccc(-c2ncc(Cl)c(-c3cc([N+](=O)[O-])ccc3O)c2)nn1',
#  'Cc1nc(CNC(=O)/C=C/c2ccc(-c3ccc(Cl)cc3)s2)co1',
#  'C[N+@](Cc1ccon1)S(=O)(=O)Cc1ccc(Cl)s1',
#  'Cc1ccc(/C=C/C(=O)c2ccc(-c3ccccc3)s2)c(SC)n1',
#  'CCCc1occc1C(=O)Nc1sc2c(c1C#N)CC[NH+](CC(C)C)CC2',
#  'COc1ccc(C)cc1/C=C/C[NH+]1CCN([C@H](C)C(N)=O)CC1',
#  'Cc1ccc(-c2nc(CNC(=O)c3ccnc4ccccc34)no2)cc1',
#  'O=C([O-])CCOc1ccc([N+](=O)[O-])cc1Br',
#  'CCc1nn(C)cc1NC(=O)N[C@H]1CCO[C@@H]1c1cccc(F)c1',
#  'COc1ccc(NC(=O)[C@](C)(O)c2nc(C)cs2)c(N)c1',
#  'C[NH+](C)[C@H]1CC[C@@H](NC(=O)NC[C@@H](O)c2ccc(N3CCOCC3)cc2)C1',
#  'C[NH+](C)CC1CCN(C(=O)c2cc(-c3cc(F)cc(Br)c3)[nH]n2)CC1',
#  'CCOC[C@H]1CCCN(C(=O)c2ccccc2S(C)(=O)=O)C1',
#  'CCCCO[C@@H]1CCC[C@H]([NH2+]C)C1',
#  'CS(=O)(=O)c1cccc(Cn2c(-c3ccc4ncccc4c3)c3nn(-c4ccccc4)c(C(F)(F)F)nc32)c1',
#  'CN(c1ccc(C(F)(F)F)cc1)S(=O)(=O)c1ccc(Br)o1',
#  'Cc1ccc(C(=O)[O-])c(OCC2(CS)CCC2)c1',
#  'CC1(C)CN(c2ccc(C#N)c(C#N)c2)CC[NH2+]1',
#  'O=C(/C=C/c1cnccn1)N1CCc2ccc(Cl)cc2C1',
#  'CCOc1cccc(COC(=O)[C@H]2[C@@H](C=O)c3ccccc3C2)c1',
#  'CC(C)(CNC(=O)N1C[C@H]2CCCC[C@@H]2C1)[NH+]1CCCC1',
#  'CC(C)N1C(=O)/C(=C2\\C(=O)Nc3ccc(Cl)cc32)SC1=S',
#  'Oc1ccc(/C=C/c2ccc3ccc(Cl)cc3n2)cn1',
#  'Cn1cnnc1SCC(=O)O[C@@H](C#N)C1CC1',
#  'O=C(NCCOc1ccc([N+](=O)[O-])cc1)c1ccsc1',
#  'Cc1ccc(C(N)=O)c(OCC(=O)N[C@@H](C)C(C)C)c1',
#  'C=CCCCN(C)C(=O)c1ccc(NN)nc1',
#  'Cc1cc(F)cc(N[C@@H](Cc2cnccn2)C2CC2)c1',
#  'Cc1nc(CN(C)[C@@H]2CS(=O)(=O)C[C@@H]2O)cs1',
#  'O=c1cc(CN(CC(F)(F)F)C2CCCC2)ncn1-c1cccc2cccnc12',
#  'C[C@@H]1C[C@H](Nc2ccc3nnnn3n2)c2ccccc21',
#  'Cc1ccc2c(c1)C(=O)N([C@@H](C)c1ccc(N3CCCCC3)c([N+](=O)[O-])c1)SC2',
#  'CCCCNS(=O)(=O)c1cc(C)ccc1C',
#  'Cc1ccc(C(=O)N2C[C@@H](C)OCC2(C)C)cc1F',
#  'N#Cc1ccc(OC[C@H](O)CN2CCO[C@H](c3cccc(F)c3)C2)c1',
#  'Cc1cccc(C)c1O[C@@H](C)C(=O)N(Cc2ccco2)[C@H](C)C1)c1ccccn1',
#  'C[C@H]([NH3+])[C@H]([NH+](C)CCC1CC1)c1ccccc1',
#  'Cc1nc(CNC(=O)N2CCC[C@@H]2C)cs1',
#  'COc1ccc2cc(C(=O)N(Cc3ccccn3)Cc3noc4ccccc34)c(C)oc2c1',
#  'C[C@@H](c1ccncc1)[C@H]([NH3+])CC(=O)N(C)C',
#  'CC(C)(C(=O)NCCNC(=O)c1ccc(F)cc1)c1ccc(Cl)cc1',
#  'Cc1cc2nc(NC(=O)c3ccc4c(c3)OCCO4)sc2cc1C',
#  'COc1ccc([C@H]([NH3+])c2sccc2C)c(OC)c1',
#  'C=C(C)C(=O)c1c(N)n(CC(=O)c2cccc(F)c2)c2nc3ccccc3nc12',
#  'CNc1nc(SCc2ccncc2)n[nH]1',
#  'O=C(CCCCC[NH+]1CCN(Cc2ccccc2)CC1)Nc1cccc(F)c1',
#  'COC(=O)N1CCC(Nc2c(SC(C)C)nn3cc(-c4ccccc4)nc23)CC1',
#  'O=C(Cc1ccccc1)NCC[C@H]1C[C@H]2C=C[C@H]1C2',
#  'O=C(c1ccc2nnc([C@@H]3CCC[NH2+]3)C2)c(Cl)c1',
#  'O=C(CSC1CCCC1)N1CCCC[C@H]1CO',
#  'O=S(=O)(c1cccc([N+](=O)[O-])c1)N(Cc1ccsc1)C[C@H]1CCCO1',
#  'CCOC(=O)C[C@@H](C)[C@@H]1CCCN1C(=O)C12CC3CC(CC(C3)C1)C2',
#  'CC[NH+](CCn1cc(Br)cs1)C1([NH+]2CCCC2)CCCC1',
#  'Cc1ccc(NC(=O)CCc2ccncc2)c(NC(=O)c2cccs2)c1',
#  'COC(=O)C[C@@H]1CC[C@H](NC(=O)Nc2ccc(C(F)(F)F)cc2)[C@H](CO)O1',
#  'CN(C)C(=O)c1ccc(CNC(=O)N(Cc2ccco2)C[C@H]2CCCO2)cc1',
#  'COc1cc(OC)cc(NC(=O)C[C@@H]2Oc3ccccc3[C@H]2C(C)=O)c1',
#  'CC(C)C[C@@H](C(=O)NNC(=O)CC(C)(C)C)[C@@H]1CCCO1',
#  'CCc1ccc(C(=O)NCc2ccc(N3CCOCC3)[nH+]c2)cn1',
#  'Cc1cc(N2CCOCC2)nc(N[C@@H](C)c2nc3ccccc3[nH]2)n1',
#  'COc1ccc(N2CCN(c3nc(C)nc4sc4c(c33)CC(C)(C)C4)CC2)cc1',
#  'CCN1C(=O)c2ccccc2N[C@@H]1c1cccc(OC2CCCC2)n1',
#  'C[C@@H]1CN([C@H](C)CO)C(=O)c2cccc(NC(=O)c3ccncc3)c2O[C@@H]1CN(C)Cc1ccc(C(F)(F)F)cc1',
#  'CCOc1cccc([C@H](C)N[C@H](C)C(=O)NCC(C)C)c1',
#  'C[C@H]([NH2+][C@H](C)CCc1ccccc1F)[C@@H]1CCCO1',
#  'C[C@@H](Cn1cccn1)NC(=O)[C@H]1CN(Cc2ccccc2)CCO1',
#  'CC(=O)N(C)c1nc2cc(NC(=O)NCCc3ccco3)ccc2o1',
#  'CCOC(=O)c1sc2nc(C[NH+]3CCC(C)CC3)nc([O-])c2N1',
#  'Cc1cc([N+](=O)[O-])ccc1N[C@H](C)c1ccc(F)cn1',
#  'O=C([C@@H]1COc2ccccc2O1)N1CCC[C@H]1c1cccs1',
#  'COc1cc(/C=C2/SC(=O)N(CC(=O)Nc3ccc4c(c3)OCO4)C2=O)ccc1O',
#  '[O-]c1c(-c2cccc([N+](=O)[O-])c2)nc2sccn12',
#  'C[C@H]1CN([C@@H](C)CO)C(=O)Cc2cc(NC(=O)CC3CC3)ccc2O[C@H]1CN(C)Cc1ccncc1',
#  'NC(=O)C1CCN(c2nc(Cl)ncc2Br)CC1',
#  'Cc1csc(=O)n1CCC(=O)N1CCC(C(=O)NC2CCCCC2)CC1',
#  'Cc1sc2nc(/C(C#N)=C\\c3ccc(O)cc3)nc(C)n2[C@@H]1c1ccccc1',
#  'C=CCc1cc(CN2CCO[C@@H](c3ccc(F)c(C)c3)C2)c(O)c(O)c1',
#  'O=C(CCn1c(=O)[nH]c(=O)c2ccccc21)N[C@H]1CCCC[C@@H]1CO',
#  'O=[N+]([O-])c1cc(Cl)c(Cl)cc1C[NH+]1CC[C@@H](c2cnc(C3CCCC3)nn2)C1',
#  'CCCCC[C@H](C)Nc1ccc(C(N)=O)cn1',
#  'O=[N+]([O-])c1c(Nc2cccc(Br)c2)ncnc1N1CCN(c2cccc[nH+]2)CC1',
#  'Cc1ccc(S(=O)(=O)Nc2ccc(C)cc2N)cc1C',
#  'COc1cc(C(=O)Nc2ccc(N)cc2)ccc1OCC(N)=O',
#  'O=C(NNC(=O)c1ccc(Br)o1)c1ccc[n+](Cl)c1',
#  'C[C@]1(CO)CCCN(C(=O)c2c[nH]c3ccc([N+](=O)[O-])cc23)C1',
#  'Cn1nc(CNC(=O)Nc2cccc(Br)c2)c2c1CCN(Cc1ccc(F)cc1)C2',
#  'O=C(c1cccc(F)c1)N(CC(=O)N1CCCCC1)c1ccccn1',
#  'CCC[C@H]1[C@@H](C)CCCN1C(=O)NCc1ccccc1-n1ccnc1',
#  'CO[C@@H]1CN(C)C(=O)c2cc(NC(=O)Nc3cccc(F)c3)ccc2OC[C@H](C)N(C(C)=O)C[C@@H]1C',
#  'COc1ccc(/C=C/c2cc(OC)ccc2OC)cc1OC',
#  'Cc1nn(CC(=O)NCCC#N)c(C)c1[N+](=O)[O-]',
#  'COc1ccc(/[NH+]=c2\\oc3ccccc3cc2C(=O)Nc2ccc(F)cc2)c(OC)c1',
#  'CN(C(=O)c1ccc(OC[C@H]2CCCO2)cc1)c1nc2c(s1)CCCC2',
#  'NC(=S)[C@@H]1CN(C(=O)c2cn3ccccc3n2)CC1',
#  'O=C(NC[C@H](O)c1ccccc1F)c1cccc(OCc2ccccn2)c1',
#  'CC(C)N(Cc1cccnc1)C(=O)c1ccc2c(c1)NC(=O)[C@H](C)O2',
#  'CC1CC[NH+](CCNC(=O)C(=O)Nc2ccc3ccccc3c2)CC1',
#  'CC(C)(C)[C@@H](CS)CN1CCN(CCOC)[C@H](C#N)C1',
#  'CC(C)c1noc(CCNS(=O)(=O)c2ccccc2F)n1',
#  'COC(=O)[C@H](C)N1CCN(C(=O)c2cccc(Cl)c2)CC1',
#  '[NH3+]C[C@H]1CC[C@@H](Cc2nnc(C3CCCC3)n2C2)C1',
#  'CN(Cc1nc2ccccc2o1)C(=O)c1cncn1-c1ccccc1',
#  'Cc1nnsc1C(=O)N1CCC[C@H]1c1ncc2c(n1)CCN(C(C)C)C2',
#  'Cc1csc([S@@](=O)Cc2ccc(Cn3ccnc3)cn2)n1',
#  'COc1ccc(N(C(=O)c2sc(C)nc2C)C(C)C)cc1',
#  'Cc1cccc(C)c1O[C@H](C)C(=O)Oc1cccc(I)c1',
#  'CC(C)(C)c1ccc(Oc2nccnc2N2CCN(C(=O)C[C@@H]3C=CCC3)CC2)cc1',
#  'NC(=O)c1ccc(N2C(=O)c3ccccc3C2=O)nc1',
#  'CCCCCC1=Br)c2ccc(Br)cc21',
#  'CCOC(=O)N1CCN(C(=O)c2cc(C3CC3)nc3c(C)ccc(C)n23)CC1',
#  'CC[C@@](C)(NC(=O)C[C@H](O)c1cccc(Cl)c1)C(=O)OC',
#  'CC1=C(C(=O)OCCOC(C)(C)C)[C@H](c2ccccc2)NC(=S)N1',
#  'C#C[C@]1(O)CC[C@@H]2[C@H]3CCC4=CCCCC[C@@H]4[C@@H]3CC[C@@]21C',
#  'CC(C)CCC(=O)NNC(=O)[C@H](O)c1ccccc1',
#  'CC(C)Oc1ccccc1CC(=O)Nc1ccc(S(N)(=O)=O)cc1',
#  'C[NH2+][C@H](Cc1ccccc1F)C(=O)N[C@H](C)Cc1cccs1',
#  'COc1ccc(C(=O)n2ccnn2)cc1S(=O)(=O)N(C)c1ccccc1',
#  'CCCCNC(=O)c1ccccc1C(=O)OCC',
#  'CC1=NN=C(COc2cnn(C)c2)C(=O)C1',
#  'O=C1C(=O)N(Cc2ccc(-c3ccc(F)c(F)c3)s2)c2ccc(C(F)(F)F)cc21',
#  'C[C@]12CO[C@]4(CNC(=O)C=C[C@]5(C)[C@@H](C6CCCC[C@]55C7CC[C@]53)[C@@H]4CC[C@]312)C2',
#  'N#Cc1cccc(C(=O)NNC(=O)CCSc2ccccc2F)c1',
#  'CC(C)(C)[NH+](CCC[NH3+])C[C@@H]1CCCO1',
#  'COc1ccc2c(c1)c(C[C@H]1CCCN(C(=O)C(C)C)C3)cn1C',
#  'Cc1ccc(C(=O)NNC(=O)N[C@@H](C)c2ccc(F)c(F)c2)c(Cl)n1',
#  'CNC(=O)[C@@H](C)C[NH+](C)Cc1csc2ccc(Cl)cc12',
#  'COc1ccccc1[C@@H]1Nc2c(cc(Br)cc2[N+](=O)[O-])C[C@@H](C)C1',
#  'O=C(NCCCn1cccn1)NC[C@H](O)C1CCCCC1',
#  'Cc1cccc(CN2C[C@](C)(C(=O)NNc3cccc(F)c3)Oc3cccnc32)c1',
#  'Cc1cccc(S(=O)(=O)N2C[C@@H]3[C@H](c4ccccc42)[C@H](CO)N3CC(C)C)c1',
#  'Cc1noc(C)c1CC(=O)NCCc1c[nH]c2ccc(Cl)cc12',
#  'N#CC(C#N)=C(N)c1ccc(Br)cc1',
#  'N#Cc1cccc(C(=O)NN/N=C/c2ccco2)c1',
#  'O[C@@H]([C@@H]1CCOC2(CCSCC2)C1)[C@@H]1CCCO1',
#  'CC(=O)N1c2ccc(S(=O)(=O)N3CCC[NH+](C4CCCCC4)CC3)cc2C[C@H]1CNC(=O)CC1CCCCC1',
#  'CC(=O)c1cc(-c2cccnc2)[nH]c(=O)c1C#N',
#  'O=C(NCc1ccc2c(c1)OCO2)[C@H]1CCCN1C(=O)c1ccc2c(c1)CCC2',
#  'COc1ccc(-c2csc(N3[C@@H](C)C[C@H](N)C(=O)N4C3=O)n2)cc1OC',
#  'CC(C)(C)c1nnsc1C[NH2+]Cc1cnc(-c2cccs2)s1',
#  'Cc1nnc(N2CCC[C@H](CSc3ccccc3)C2)n(-c2ccccc2)c1=O',
#  'Cc1cc(N[C@H](C)C[C@@H]2CCCO2)c([C@@H](C)O)cc1F',
#  'N#C/C(=C\\c1c[nH]c(=O)[nH]1)OCCC#N',
#  'COc1ccc(CCNC(=O)CNc2ccc(C(N)=O)cc2)cc1Br',
#  'CC[C@H](C(=O)N1CCC(c2nnsc2C)CC1)n1cc[nH+]c1',
#  'CC(C)Sc1ccc(C(=O)N2CCC[C@H](CO)C2)cc1',
#  'Cc1cc(C)n(CC(=O)N2CCC[C@H](c3[nH]ncc3-c3cc(C)no3)C2)n1',
#  'COC(=O)CNC(=O)[C@H](C)c1ccc(O)cc1',
#  'CCOCC(=O)Nc1ccn(-c2ncccn2)n1',
#  'Cc1[nH]ncc1C(=O)N1CCC(C(=O)N2CCCC[C@H]2C)CC1',
#  'Cc1cc(C)c(Cn2c([C@@H](C)N)c3ccccc3n2)n[nH]1',
#  'Cc1cccc(C(=O)Nc2cc(OC[C@@H]3CCCO3)ccc2C)c1[N+](=O)[O-]',
#  'CCCN1C(=O)CCn2c(cc3c(c(=O)c2=O)CCC3)c1ccccc1',
#  'COc1cc([C@H]2c3c(C)nn(C)c3NOC(=O)c2c(-c3ccc(-c4noc(C)n4)cc3)C(=O)N(C)C(=O)C3=O)ccc2oc1=O',
#  'CC(=O)[C@H](Cc1ccccc1)NC(=O)c1c(N)n(C)c(=O)n(C)c1=O',
#  'O=C(c1coc(-c2ccccc2)n1)N1CCCc2cc(F)cc(F)c21',
#  'Cn1ccc(C(=O)N[C@H]2C[C@@H]2c2cc(F)ccc2F)cn1',
#  'COc1ccc(-n2c(S[C@H]3CCC[C@@H](C)C3)nc3ccccc3c2=O)cc1',
#  'CN(C)C(=O)c1cccc([C@@H]2CCCN(Cc3cnn(C(C)(C)C)n3)C2)n1',
#  'NC(=O)[C@@H]1CCN(C(=O)CCc2ccccc2)c2ccccc21',
#  'CCOC(=O)c1ccc(N2C[C@H](c3ccccc3)O[C@@](CO)(C(=O)OC(C)C)C2=O)cc1',
#  'Cc1cccc(O[C@@H](C)C(=O)O[C@H](C)c2nnc(C3c4ccccc4C3=O)n2-n2cccc2)c1',
#  'CCOC(=O)[C@H]1CC[C@H](NC(=O)c2ccccc2[N+](=O)[O-])[C@H]1C',
#  'C[C@H](NS(=O)(=O)c1ccc2c(c1)CCC(=O)N2)c1ccccc1',
#  'O=C(NCc1nccn1Cc1cccc(Cl)c1)C(=O)N[C@@H]1CCC[C@H]1c1ccccc1C(F)(F)F',
#  'CS(=O)(=O)OC[C@@H]1CCCC[NH+]1Cc1noc(Cc2ccccc2)n1',
#  'Cc1nc(-c2ccc(CCNC(=O)C[C@@H](C)n3cccc3)cc2)cs1',
#  'C[C@@H](c1ccc(Cl)cc1)N(C)C(=O)Nc1cccc(CC[NH+]2CCCC2)c1',
#  'CCn1nc(C)cc1C(=O)NCc1c(C)nn(Cc2ccc(Cl)cc2)c1C',
#  'C[C@H]1CCCC[C@H]1NC(=O)CSc1nnc(-c2ccco2)n1C',
#  'CCc1nn(C)cc1CNC[C@@H]1CC[NH+](CC(C)C)C1',
#  'CS(=O)(=O)N1CCCN(Cc2ccon2)CC1',
#  'COC(=O)CNc1c(F)cc(F)cc1F',
#  'C[C@H]([NH2+][C@H](C)C[C@@H](O)c1ccccc1)c1cccs1',
#  'CC(C)CC(C)(C)C(=O)Nc1ccc([C@@H](C)OCC(F)(F)F)cc1',
#  'Cc1cccc(OC(=O)Cc2ccn(C(C)C)c2N)c1',
#  'Cc1sc(NC(=O)CN2C[C@H](C)O[C@H](C)C2)c(C#N)c1C',
#  'C[C@H](Nc1ccc(CNC(N)=O)cc1)c1occc1Br',
#  'COc1ccc([C@@H](CC(=O)/C=C/Sc2cnccn2)Cc2ccco2)cc1',
#  'CN1C(=O)c2cc(NC(=O)Cc3cccs3)ccc2OC[C@H]2O[C@H](CC(=O)N[C@@H]3CCN(Cc4ccccc4)C3)CC[C@@H]21',
#  'COc1ccc(C2=NC(C)(C)N(C(C)=O)[C@H](c3cccnc3)[C@H]2c2cccn2C)cc1',
#  'CC[NH+]1CCN(CCc2nsc(NC(=O)c3scnc3C)n2)CC1',
#  'Cc1ccc(C(=O)NC[C@@H](C)Oc2ccc(Cl)cc2)s1',
#  'O=C(COc1ccc(Cl)cc1Cl)N1CCc2[nH]c3c(Cl)cccc3c2C1',
#  'CN1C(=O)c2cc(NC(=O)Nc3ccccc3)ccc2OC[C@@H]2O[C@@H](CC(=O)NCC3CCCCC3)CC[C@@H]21',
#  'CO[C@H]1CN(C)C(=O)c2ccc(NS(=O)(=O)c3ccc(C)cc3)cc2OC[C@H](C)NC[C@@H]1C',
#  'CC[C@H](C)CN(C)C(=O)[C@@H]1CC(=O)N(Cc2ccco2)C1',
#  'Cc1nc([C@H]2CCCCN2C(=O)c2ccc(F)c(C)c2)c(C)o1',
#  'Cn1cc(C(=O)NC2CCCCC2)cc(NC(=O)c2ccc(-n3cccc3)cc2)c1=O',
#  'Cc1ccc(-c2nc(C)c(C)c(S(=O)(=O)NCCN3CCOCC3)c2C)c(C)c1',
#  'COc1ccc(CCC(=O)c2sccc2NO)c(Br)c1',
#  'CC[C@H](O)C[C@@H](C(=O)[O-])c1cccc2cccnc12',
#  'COc1ccc([C@@H]2CC(=O)c3cccnc3N2)cc1OC',
#  'O=S(=O)(c1ccco1)N1CCCSC[C@@H]1CN1CCOCC1',
#  'CCC(C)(C)NC(=O)/C=C/c1cccs1',
#  'Cc1ccc(CN(C)C(=O)Nc2c(C(C)(C)C)nn(-c3ccc(F)cc3)c2Cl)cn1',
#  'Cc1ncc(CNC[C@@]2(O)CCOC2)c(=O)[nH]1',
#  'CC(C)=CCC/C(C)=N/N=C1\\CCC[C@H]1C[NH3+]',
#  'NC(=S)c1c[nH]nc1-c1ccc(Br)cc1',
#  'CC(C)[C@H](C)CC(=O)N[C@H]1CCO[C@H]1c1ccc(Cl)c(F)c1',
#  'C[C@@H](C(=O)Nc1ccc(N2CCOCC2)cc1)S(=O)(=O)c1nncn1C(C)C',
#  'O=C1CN(C(=O)COC(=O)c2cc(Cl)c(Cl)c3cccnc23)C(=O)N1',
#  'O=S(=O)(NCc1ccc(CN2CCOCC2)cc1)c1ccc(Br)cc1',
#  'CCOC(=O)CCc1nc(CN2CCN(C(C)=O)CC2)no1',
#  'CC[C@H](SC1=NN=C2NC(=O)CC2)[C@@H]1N',
#  'CC(=O)N1CC[C@@H]2[C@H]1c1cc(-c3ccc(C#N)cc3)ccc1N(C)[C@H]2CO',
#  'Cc1cccc(NC(=O)N2CCC[C@H](C)C2)c1OC(C)C',
#  'CN(CC1=NC(=O)/C(=C\\c2ccccc2F)S1)C(=O)C1=c2ccccc2=[NH+]C1',
#  'O=C(Nc1ccccn1)C1CCN(c2nnc(Cl)cc2C#N)CC1',
#  'CCc1n[nH]c(=S)n1NCc1ccon1',
#  'O=S(=O)(c1ccccc1)N1CCc2ccc(NS(=O)(=O)c3ccc(N)cc3)cc2C1',
#  'CC(C)CNC(=O)Cc1ccc(NC(=O)C(=O)N2CCCC2)cc1',
#  'C[NH+](C)CCCNC(=O)[C@H]1[C@H](CO)[C@H]2Cn3c(cccc3=O)[C@@H]1N2C(=O)CC1CC1',
#  'COCCOC(=O)c1ccc(C)o1',
#  'COc1ccccc1/C=C/C=C/C(=O)C(F)(F)F',
#  'CC(C)CCCC(=O)N(C)Cc1ccco1',
#  'C[C@H]1CCC[C@@H](C)N1C(=O)CSc1nnc(-c2cccnc2)n1C1CCCCC1',
#  'CCc1nn(C)cc1CNc1c[nH]cc(Br)c1=O',
#  'CNC(=O)C1(CNC(=O)N2CCS(=O)(=O)CC2)CCC1',
#  'C[C@H]1CCC[C@@H](Cc2nsc(NCCc3cccc(Cl)c3)n2)C1',
#  'Cc1ccc(O[C@H](C)CNC(=O)c2sc(-n3cccc3)nc2C)cc1',
#  'CCOCCN(C)C(=O)c1nn(-c2ccccc2F)c2c1CCC2',
#  'CN(CC(F)(F)F)c1[nH]c2ccccc2n1CN1CC(c2ccccc2)=N1',
#  'NC(=O)[C@H](Cc1c[nH]c2ccccc12)N1C(=O)c2ccccc2C1=O',
#  'C[C@H]1CN([C@@H](C)CO)C(=O)c2cc(NS(=O)(=O)c3ccccc3)ccc2O[C@H](C)CCCCO[C@H]1CN(C)C(=O)CCC(F)(F)F',
#  'O=c1[nH]c2ccccc2cc1CN1CCC(OCc2ccccn2)CC1',
#  'N#CC1=C(N)N(N(C)C)C2=C(C(=O)CC(C)(C)C2)[C@H]1c1ccccc1Cl',
#  'COc1ccc(NC(=O)NCCc2csc3nc4ccccc4n23)c([N+](=O)[O-])c1',
#  'CS(=O)(=O)Cc1ccccc1NS(=O)(=O)c1ccc(Cl)s1',
#  'C[C@@H](O)CC#N',
#  'Cc1ccc(C)c(N2CCN(CC(=O)Nc3c(C)cccc3C)C2=O)c1',
#  'CCS(=O)(=O)c1ccc(CCNC(=O)N[C@H](C)c2ncc(C#N)cn2)s1',
#  'Cc1ccc(S(=O)(=O)N2CCC[C@H](C(=O)Nc3cccc(O)c3)C2)cc1[N+](=O)[O-]',
#  'CC1(C)Cc2ccccc2CON1C(=O)c1ccc(-c2cnco2)cc1',
#  'CCc1ccc(NC(=O)[C@H](SCC2CCCC2)c2cccnn2)cc1',
#  'C[C@@H]1CN(c2ccc(NC(=O)NCC[C@@H]3CCCO3)cc2)CCO1',
#  'CO[C@H]1CCCN(C(=O)NCc2ccc(C(=O)N(C)C)cc2)C1',
#  'OC[C@H]1CCC[C@@H]1C[NH2+]Cc1ccc(Br)cc1Br',
#  'Cc1ccc(-n2nnnc2S[C@@H]2CCC[C@@](C)(O)C2)c(C)c1',
#  'CCOC(=O)C1=C(C)NC2=C(C(=O)CC(C)(C)C2)[C@H]1c1cccs1',
#  'CCCOc1ccc(-c2oc3ccccc3c2NC(=O)COc2ccc(C)cc2)cc1',
#  'Cc1csc(N2CCN([C@H](c3ccccc3Cl)C(C)C)CC2)n1',
#  'O=C(C1CC1)N(Cc1nnc(-c2ccc(C(F)(F)F)cc2)o1)c1ccccc1',
#  'CCOc1cc([C@H]2SC(NC(C)=O)=NN2C(C)=O)ccc1O',
#  'O=C(CCc1c(F)cccc1Cl)Nc1nc2c(s1)COCC2',
#  'CS(=O)(=O)CCN(Cn1ncnc1-c1ccc(Cl)cc1Cl)CC1CC1',
#  'O=C1CSc2ccccc2N[C@H]1c1ccccc1',
#  'Cc1cccc(-c2ccc([C@H]3[C@H]4CNC[C@@H]3N4)cc2)c1',
#  'O=C(NCc1cscn1)Nc1cc([N+](=O)[O-])ccc1F',
#  'CO[C@H](C)C(=O)Nc1ccc(OCC)cc1',
#  'O=C1CN(C(=O)[C@@H]2CC2(Cl)Cl)CCN1',
#  'Cc1csc(-c2ccc(C(N)=O)cc2N2CCOCC2)n1',
#  'O=C(NC[C@@]1(O)CCOc2ccccc21)C1CCN(S(=O)(=O)c2ccc(Cl)cc2)CC1',
#  'CC(=O)Oc1cc(C)c(N)cc1C',
#  'COc1cccc(-c2nn(-c3ccccc3)cc2/C=N\\N[C@@H]2CCS(=O)(=O)C2)c1',
#  'COCc1nn2c(-c3ccc4c(c3)OCCO4)nnn2c2ccc(C)cc12',
#  'CCN(CC)C(=O)[C@@H]1CCC[NH+](C[C@H](O)c2ccc(F)cc2F)C1',
#  'CC[C@@H](CCC#N)N(C)Cc1cnn(C2CCCCC2)c1',
#  'C[C@H]1CN(C(=O)c2cnc([C@H](C)[NH3+])cn2)C[C@H]1C',
#  'CCOC(=O)[C@]1([NH2+]C(C)C)CC[C@@H](Sc2cccc(C)c2)C1',
#  'C[C@@H](NC(=O)C[C@H]1CC[C@@H]2[C@H](COC[C@H](O)CN2C(=O)Nc2cccc(Cl)c2)O1)c1ccccc1',
#  '[NH3+]CC#Cc1cc(F)cc(CSCCc2cccs2)c1',
#  'CNC(=O)[C@@H]1CCC[NH+]1C1(CC2CC2)Cc2ccccc2C1',
#  'CN(Cc1cccs1)S(=O)(=O)c1c(F)cccc1F',
#  'COc1cccc(-n2c(=S)[nH]c3c(C)cccn3c2=O)c1',
#  'CC1(C)C[NH+](CC(=O)Nc2nccn(C)c2=O)CC12CCCC2',
#  'COc1ccccc1[C@@H]1C[C@H]1C(=O)Nc1ccc(C)cc1N1CCOCC1',
#  'C[C@H](Nc1cccc(F)c1C(N)=[NH2+])C1CCCC1',
#  'O=C(COc1ccc(Cl)cc1)NCC(=O)N1CCc2ccccc21',
#  'O=S(=O)(CC1CCCCC1)Nc1ccc(Cl)cn1',
#  'C[C@H]1CN(C(=O)c2cnc([C@@H]3CCCO3)s2)[C@H](C)CO1',
#  'Cc1cc(NCC(=O)N(C)CCC2CCN(c3cc[nH+]cc3)CC2)no1',
#  'CCC(C)(C)N(C)C(=O)c1cc(F)ccc1Br',
#  'C[C@@H](NS(=O)(=O)c1ccc(Cl)cc1)C(=O)N1CCCCCCC1',
#  'CCOc1ccc(S(=O)(=O)NC(=O)c2ccc(Br)cc2)cc1NC(C)=O',
#  'Cc1sc2nc(Cc3ccccc3)[n+](CCC(=O)N3CCCC3)c2c1C',
#  'Cc1nc(C(C)(C)NC(=O)NCc2nnc3ccccn23)cs1',
#  'CCOC(=O)[C@@H]1CCCN(C(=O)Nc2cccc(C#Cc3ccccc3)c2)C1',
#  'Cc1ccc(C(=O)OCC(=O)N2CCOCC2)s1',
#  'CCO[P@](=O)(O)c1cccc(Br)c1',
#  'O=C(Nc1cccc(N2CCCS2(=O)=O)c1)[C@@H]1CCCc2ccccc21',
#  'CCc1nn(C)c(OC)c1CNc1ccc(F)c(F)c1',
#  'CCOc1ccc(C(=O)N[C@](C)(C(=O)[O-])C2CC2)nn1',
#  'O=[S@@](c1cc2cccc(Cl)c2o3)[n+]2[O-])[C@H](c2ccccc2)O1',
#  'CS(=O)(=O)c1cnc(N2CCN(c3ccc(O)cc3)CC2)nc1',
#  'CC(=O)Nc1ccc(C(C)=O)cc1OCc1nccs1',
#  'N#Cc1cccc(-c2ccc3c(c2)[C@H]2[C@H](CCN2S(=O)(=O)c2ccccc2F)[C@H](CO)N1)C2',
#  'O=C(c1ccccc1)N1CCN(C(=S)NC[C@@H]2C=Nc3ccccc32)CC1',
#  'C[C@H](O)[C@H](C)[NH+](CC1CC[NH2+]CC1)C1CC1',
#  'CSc1ccc(CN(C)S(=O)(=O)N2C[C@H](C)O[C@@H](C)C2)cc1',
#  'C[C@H](C(=O)Nc1cccc(C(F)(F)F)c1)n1cc(C#CC[NH3+])nn1',
#  'CCN(CC)S(=O)(=O)c1ccc(CC(=O)N[C@@H](c2ccccc2)C2CC2)cc1',
#  'Cc1ccc(N2CCC[C@@H](C(=O)NCc3nc(-c4cccs4)no3)C2)nc1',
#  'CC(C)(O)CCNc1ccc2oc(=O)[nH]c2c1',
#  'C[C@@](O)(CNC(=O)[C@@H]1C[C@@H]1c1ccc(Cl)c(Cl)c1)c1ccncc1',
#  'CCC[C@@H]1CN(C(=O)c2ccc(-n3cccc3)nc2)C[C@H]1NC(=O)OC(C)(C)C',
#  'Cc1ccc(C(=O)NCC(C)C)cc1NC(=O)NC[C@H](C)C#N',
#  'O=C(C[NH+]1CCC(CN2CCOCC2)CC1)Nc1ccc(Br)cc1',
#  'N#Cc1csc(C(=O)NCc2csc(C3CC3)n2)c1',
#  'C[C@H](c1c[nH]nc1-c1ccccc1)NC(=O)NCC(=O)N1CCCC1',
#  'C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]1CN(C)Cc1ccc(-c2ccccc2)cc1',
#  'Cc1csc([C@H](NC(=O)N2CCO[C@H](C#N)C2)C2CC2)n1',
#  'CC[NH+](Cc1cn(C)nc1-c1ccncc1)[C@H]1C[C@H](C(C)(C)C)CC1',
#  'CC(C)C(=O)N(C)CC(=O)Nc1c2c(nn2Cc1ccccc1)C(=O)Nc1cc(F)ccc1F',
#  'CSc1nc2ccc3c(c2N=C(NC(C)=O)CC[C@H](c2ccc(OC)c(OC)c2)N3)c1',
#  'COc1ccc([C@H]2C3=C(CC(C)(C)CC3=O)Nc3cc(C)ccc32)c(OC)c1OC',
#  'CO[C@@H]1CN(C)C(=O)c2cc(NS(=O)(=O)CC(F)(F)F)ccc2OC[C@@H](C)N(CC2CCCCC2)C[C@H]1C',
#  'CN(C[C@@H]1CNC(=O)C1)Oc1cccc(Cl)c1F',
#  'O=C(CNC(=O)N1CCN(C(=O)[C@@H]2Cc3ccccc3C2=O)CC1)NCc1ccccc1',
#  'CCN(CC(=O)Nc1ccccc1OC)C(=O)c1ccc2[nH]c(C)c(C)c2c1',
#  'Cn1cnc(S(=O)(=O)N[C@@H]2CC[C@H](CC(=O)NCCCN3CCCCC3)O[C@H]2CO)c1',
#  'Cc1oc2ncnc(N[C@H]3CCOC3)c2c1C',
#  'COc1ccc(C(=O)NC[C@@H]2CN3CCCC[C@@H]3CO2)cc1OC(F)F',
#  'N#CCC[C@@H]([NH3+])c1nc2ccc(F)cc2[nH]1',
#  'CCn1nc(C)c(NC(=O)N[C@@H](C[NH+](C)CC)C2CCCCC2)c1C',
#  'CCn1nccc1-c1cnc([C@H]2C[NH+]=C(N)N2C)s1',
#  'COc1cc([C@@H]2C3=C(CC(C(C)=O)=NC3=C2C(=O)OC3CCCC3)NC(=O)N[C@H]2c2ccco2)ccc1O',
#  'N#Cc1c(CNC(=O)c2ccc(-c3ccccc3F)cc2)noc1-c1ccccc1',
#  'CC[C@H](C)[C@H]1CN(Cc2ccccc2C)CC[NH+]1C1CC1',
#  'Cc1c([C@H](C)NC(=O)N[C@H](CO)c2ccco2)cnn1C',
#  'NS(=O)(=O)c1ccc(C(=O)OCc2coc(-c3ccccc3)n2)cn1',
#  'O=C(Cn1c(C(F)(F)F)nc2ccccc21)NCc1cccnc1',
#  'COc1cccc(-c2cc(C(=O)N[C@H]3[C@@H]4CCO[C@@H]4C3(C)C)cn2[C@H]1CC(=O)Nc2ccccc2OC1=O',
#  'Cc1cc(-n2cnnc2)c(C)cc1NCC(=O)Nc1ccc(Cl)cc1F',
#  'CC/C(=C\\c1ccc(OCc2ncc(Cl)cc2Cl)o1)C(C)C',
#  'COC[C@@H]1CCCCN1C(=O)c1cc(C(F)(F)F)ccc1F',
#  'C[C@@H](C#N)Oc1ccc(-c2coc(-c3ccc(F)cc3)n2)cc1',
#  'C=CCN(Cc1ccccc1)C(=O)Cn1nc(C)cc1C',
#  'O=C(Nc1ccc(N2CCOCC2)nc1)C1(c2ccccc2F)CCOCC1',
#  'COc1ccc(/C=C/C(=O)O[C@@H](c2ccccc2)n2cnnn2)cc1',
#  'CCNS(=O)(=O)[C@H]1CCN(C(=O)C[C@H](CS(N)(=O)=O)c2ccccc2)C1',
#  'COc1cc(/C=C2/C(=O)NC(=O)N(c3ccc(C)c(C)c3)C2=O)ccc1OCC(=O)N1CCOCC1',
#  'O=C(c1ccc(S(=O)(=O)NCc2ccccn2)cc1)N1CCCC[C@H]1CCO',
#  'COc1ccc(-c2nc(-c3cnc4ccccc4c3O)o2)cc1S(=O)(=O)NC1CCCC1',
#  'CCN(CC)C(=O)c1ccc(CNC(=O)c2ccc(F)cc2F)cc1',
#  'CN1CCN(C(=O)c2cc3c(c(-c4cccc(Br)c4)c3)CC[C@@H]21)C(=O)NCc1ccco1',
#  'Cc1ccc(N[C@@H](C)C(=O)NCc2ccco2)cc1S(=O)(=O)N1CCCCC1',
#  'O=C(NC[C@](O)(c1cccs1)C1CC1)c1ccc[nH]1',
#  'CCOCCN(C)Cc1cccc(Cl)n1',
#  'COc1ccc(OC)c(N2CC[NH+](Cc3cccc(C)c3C)CC2)c1',
#  'CC(C)NC(=O)N(C)C[C@@H]1OCCCC[C@@H](C)Oc2ccc(NC(=O)CCC(F)(F)F)cc2C(=O)N([C@H](C)CO)C[C@@H]1C',
#  'Cc1nc(C[NH2+]C[C@H](C(C)C)N2CCOCC2)no1',
#  'CN(C)S(=O)(=O)c1ccc(Cl)c(C(=O)N2CCC[C@H]([NH+]3CCCC3)CC2)c1',
#  'CCC1(CNC(=O)NC[C@H](C)Oc2ccccc2F)CC1',
#  'NC(=O)[C@@H]1CCCN(C(=O)c2cc3c(s2)CC[NH2+]C3)C1',
#  'CCc1ccc(C(=O)N2CCCc3c(cncc3N)C2)s1',
#  'Nn1c(SCC(=O)Nc2ccc(F)cc2)nnc1-c1ccc(F)cc1',
#  'CC[C@@H]1CCC[C@@H](NC(=O)N2CCCC[C@H]2C[NH+](C)C)C1',
#  'CS(=O)(=O)[C@@H]1CCC[C@@H](NC(=O)c2cccc(OC(F)F)c2)C1',
#  'O=C1NC2(CCCCC2)C(=O)N1Cc1ccc(Cl)c(Cl)c1',
#  'CCOc1ccc(NC(=O)C(=O)NCC(=O)Nc2cc(C)sc2C)cc1S(=O)(=O)NC',
#  'CCCOc1cc(CN2CCN(S(=O)(=O)c3ccc(C)cc3)CC2)no1',
#  'CC(C)NC(=O)CN1CCN(Cc2nc3c(N)cccc3s2)CC1',
#  'C[C@H]1CN([C@@H](C)CO)C(=O)c2c(c3ccccc3n2C)-c2ccccc2CO[C@@H]1CN(C)C(=O)Nc1ccccc1',
#  'Cc1cc(Cl)c(S(=O)(=O)N(C)CC(N)=O)c(F)c1F',
#  'Cc1ccc(C(=O)N(Cc2ccccc2F)c2ccc3c(c2)CCO3)s1',
#  'Cc1ccc(N2CCN(C(=O)c3cc(C#N)cn3C)CC2)cc1C',
#  'C#CCN(C[C@@H]1COc2ccccc21)[C@H]1CCCC[C@@H]1C',
#  'C[C@@H](NC(=O)OC(C)(C)C)c1nc(-c2ccsc2)n[nH]1',
#  'COC(=O)c1ccc(/C=C(\\C#N)c2nc(-c3ccccc3C)cs2)cc1',
#  'Cc1ccc(NCCCn2c(C)nc3ccccc32)cc1',
#  'C[C@H]1O[C@H](n2cnc3c(N)nnc3c3ccccc23)[C@H](C)N1',
#  'CCOc1cc(NC(=O)N[C@H]2CCCCC[C@@H]2C)ccc1OC',
#  'COc1ccc(CC(=O)NNC(=O)Cc2c(C)[nH]c(=O)c3ccccc23)cc1',
#  'Cc1noc(C)c1[C@@H](C)NC(=O)Cc1csc(NC(=O)c2ccco2)n1',
#  'Cc1ccc(C(=O)[C@H]2CCOC2)cc1[N+](=O)[O-]',
#  'C[NH+](CCOc1ccc(F)cc1)C1CN(C(=O)OC(C)(C)C)C1',
#  'COCCN1CCN(C(=O)c2cc(F)cc(F)c2)CC1=O',
#  'CCOC[C@@H]1CCN(C(=O)NCCC2CCN(c3cc(C)[nH+]c(C)n3)CC2)C1',
#  'Cc1cccc(CNC(=O)c2nn(C)c(=O)c3ccccc23)c1',
#  'N[C@@H](C[NH3+])c1cscc1Br',
#  'Cc1ccccc1C(=O)N1C[C@H]2CC[C@@H]1CN(C(=O)c1ccc(N3CCOCC3)c(Cl)c1)CC2',
#  'O=C(NCc1noc(COc2ccc(Cl)cc2)n1)N1CCc2ccccc21',
#  'CCOc1ccc(/C=C(/C#N)C(=O)Nc2ccccc2)cc1',
#  'C[NH+]1CCC[C@H](CNCc2cc(F)c(O)cc2F)C1',
#  'Cc1cc(NC(=O)CN(C)C(=O)CC2CCCC2)c(C)o1',
#  'CCOc1cc(/C=C2/S/C(=N\\c3ccc(Cl)c(Cl)c3)NC2=O)c([N+](=O)[O-])cc1OC',
#  'C=CCn1cc(C(=O)N2CCN(c3ccc(OC)cc3)CC2)cn1',
#  'CC1(C)CCC(CNC(=O)N[C@H](C(=O)[O-])c2ccccc2)CC1',
#  'O=C(Nc1ccc(Cl)cn1)c1c([S-])nnn1CC(=O)Nc1ccccc1F',
#  'Cc1cc(C)cc(CS(=O)(=O)Cc2ncc(C(=O)NC[C@H]3CCCO3)s2)c1',
#  'O=C(CNC(=O)c1ccc(OCC(F)F)nc1)NCc1ccccn1',
#  'Cc1nc(CNC(=O)CC[NH+]2CCCC2)no1',
#  'Cc1oc2c(c3c(cnc4n2CCCCC4)c1OCCC(=O)NC(C)C)CCN(Cc1ccncc1)C3',
#  'CC(C)n1cccc1C(=O)NC[C@@H](C(=O)OC(F)(F)F)c1ccccc1',
#  'CCC(=O)Nc1cc(C(=O)N[C@@H](C)CN2CCOCC2)on1',
#  'C[C@H]1[NH2+]CC[C@@H]1c1ncnc2ccc(Cl)cn12',
#  'C[NH+]1CCN(Cc2cc(Cl)c3c(c2)OCCCO3)CC1',
#  'CN(C)c1nc(N)nc(CCS(=O)(=O)c2ccccc2Cl)n1',
#  'O=C(Nc1ccccc1-n1cccn1)O1',
#  'Nc1c(N[C@H]2CCOc3ccccc32)nc(-c2ccccc2)n1-c1ccccc1',
#  'COCC[C@H](C)C(=O)Nc1cc(F)ccc1F',
#  'O=C1C=C(N2CCN(CCO)CC2)[C@@H]1C1CCN(CC2CCCCC2)CC1',
#  'COC(=O)C(C)(C)NC(=O)CNC(=O)c1ccc(Br)cc1',
#  'CCc1nc(C[NH+]2CCC(CC(=O)N3[C@H](C)CCC[C@@H]3C)CC2)no1',
#  'CN1C(=O)C2=NN=C[C@@H]2N1S(=O)(=O)c1ccc(F)cc1',
#  'CCOc1cc(C=O)cc(Cl)c1O',
#  'COCCNc1nc([C@@H]2C[NH+](C)CC[NH2+]2)nc2cc(C)cnc12',
#  'CCc1nc(-c2ccc(N3CCN(C(=O)c4cc(C(C)C)no4)CC3)n2)cs1',
#  'Cc1ccn2nc(N[C@@H](C)c3nc(C(C)(C)C)cs3)nc2c1',
#  'CN(c1ccccc1)C1CCN(C(=O)N[C@H](C(N)=O)C(C)(C)C)CC1',
#  'CCOC(=O)N1CCN([C@H](C)C(=O)Nc2nncs2)CC1',
#  'CCc1ccc([C@@H](O)C2([NH+](C)C)CCCCC2)o1',
#  'N#Cc1c(Cl)nsc1NC[C@@H]1CN(C2CC2)CCO1',
#  'O=C(c1ccc(-n2cnnn2)cc1)N1CCN(c2ccc(Cl)cn2)CC1',
#  'O=C([O-])c1c(C)nn2c1NCCS2',
#  'CCOCCN(C)C(=O)[C@H]1COc2ccccc21',
#  'CCOC(=O)c1cn(CC)c2cc(Cl)ccc2c1=O',
#  'CCCN1CNc2c(c(=O)[nH]c(=S)n2CCOc2ccc(F)cc2)C1',
#  'c1cc2c(cc1/C=N/NCc1ccncc1)OCCO2',
#  'COc1ccccc1CN(C(=O)N1CCOCC1)C[C@@H]1CCCCO1',
#  'COc1ccc2c3c([nH]c2c1)[C@H](CO)N(Cc1ccncc1)CC31CN(C(=O)Nc2cccc(F)c2)C1',
#  '[NH3+][C@@H]1CC2(CCC2)C[C@@H]1[N+](=O)[O-]',
#  'CCN(CC)C(=O)CSc1nnc(-c2ccncc2)n1-c1ccccc1F',
#  'COc1ccc(NC(=O)CSc2ccc(N3CCOCC3)cc2NC(=O)[C@@H]2COc3ccccc3O2)cc1',
#  'N#Cc1cccc(CS(=O)(=O)NCC#Cc2ccccc2F)c1',
#  'Cc1n[nH]c(SCC2=NC(=O)C([N+]3=CCCC3)(c3ccccc3)C2=O)n1',
#  'O=C1CCc2cc(F)ccc2N1CCNC(=O)CCn1c(=O)[nH]c2ccccc21',
#  'CSc1ccc([C@H](O)[C@H]2CCOC3(CCC3)C2)cc1',
#  'CCS[C@@H]1CC[C@H](NC(=O)N2CCO[C@H](C)C2)C1',
#  'C[C@@H](C(=O)NC(=O)NCCc1ccccc1)[NH+](C)Cc1cncs1',
#  'C[C@H]1C[C@@H]1NC(=O)N(C)[C@H](C)c1ccc(-c2ccc([N+](=O)[O-])cc2)o1',
#  'CCn1c(SCCOc2cccc(F)c2)nnc1[C@@H]1COCCO1',
#  'COc1ccc(NC(=O)CCC(=O)Nc2ccc3c(c2)CCC3)c(OC)c1',
#  'CN(C)c1ccc(/C=C/CN2CCOc3ccccc32)cc1',
#  'C[C@@H](CNC(=O)[C@@H]1CC(=O)N(Cc2ccccn2)C1)c1cccs1',
#  'COc1ccc2c(c1)[C@H](N1C[C@H]([NH3+])[C@H](C)[C@@H](C)C1)NC2=O',
#  'N#Cc1ccccc1CSCc1nc(-c2ccco2)no1',
#  'COc1c(Cl)cc(C(=O)[O-])cc1S(=O)(=O)NC[C@@H]1CCCO1',
#  'Cc1cccnc1C[C@H](O)c1ccc(CC(C)C)cc1',
#  'CC(=O)Nc1ccc(NC(=O)Cc2ccccc2C)cc1',
#  'CCn1nc(C(=O)Nc2cc(C)ccc2C)cs1',
#  'O=C(O)CCCNc1ccc(N2CCSCC2)c([N+](=O)[O-])c1',
#  'CCOC(=O)C(=O)N1CCN(C(=O)c2ccc(OC)cc2)CC1',
#  'CNC(=O)C[NH+](C)Cc1nc(-c2ccc3c(c2)CCO3)no1',
#  'CCn1c(SCC(=O)N/N=C/c2ccco2)nnc1-c1ccc(C)cc1',
#  'C=CC[NH+](CC(=O)[O-])Cc1[nH+]c(C)ccc1[O-]',
#  'CC[C@](C)(NC(=O)c1ccccc1C)C(=O)OC',
#  'COCC/N=C(\\N)SCc1cc(=O)nc2sc(C)cc12)c1ccccc1Cl',
#  'Cc1cc(C)cc(N2[C@H](C#N)[C@H](c3ccc(Br)cc3)[C@H]2CO)c1',
#  'OC[C@@H]1CCC[C@@H]1N1CCCc2ccccc21',
#  'Nc1nc(CSc2nnc(N3CCCC3)n2-c2ccccc2)cs1',
#  'O=C(C[C@@H]1C[C@@H]2c3cc(NC(=O)c4cccnc4)c(F)cc3CO[C@H]2CO)c2ccccc2O1)C[C@@H]1CCCO1',
#  'CCC[NH2+][C@@H](Cc1ccc(Br)cc1C)C1CC[NH+](C)CC1',
#  'Cc1nc2ccccn2c1C(=O)N(CC[NH+](C)C)C[C@@H]1CCCO1',
#  'O[C@H](CNCc1cccc(F)c1F)c1ccc(Cl)cc1',
#  'NC(=O)[C@H]1CN(C(=O)[C@H]2CSC(=O)N2)C[C@H]1c1ccncc1',
#  'C[C@H]1[C@@H](C(=O)[O-])CC[NH+]1C1CCC(C[NH3+])CC1',
#  'C[NH+](C[C@@H]1CSc2ccccc21)C1CCSCC1',
#  'NC(=O)[C@@H]1CN(Cc2ccc(-c3ccc(Cl)cc3)c3)cc(=O)[nH]2)c1',
#  'C[C@@H]1CCC[C@@H]1NC(=O)N(C)CCc1ccc(F)cc1',
#  'CCn1c([C@@H]2CC[C@@H](C(=O)[O-])O2)nnc1[O-]',
#  'Fc1ccc(/C=C/c2cnc(N3CCCC3)nc2)s1',
#  'COCCC[C@]1(CO)CCCN(C(=O)c2cn(-c3ccccc3)nn2)C1',
#  'C/C=C(/C)C(=O)N1C[C@@H](OC)[C@H](C(=O)OC)C1',
#  'CS[C@H]1CCC[C@H]1NC(=O)Nc1c(F)cc(F)cc1F',
#  'CCOC(=O)/C=C1/Sc2ccc(C)cc2N[C@H]1C#N',
#  'COc1c([N+](=O)[O-])cc([C@@H]([NH3+])CC)cc1Br',
#  'CN(C[C@H]1CCCO1)C(=O)N1Cc2[nH+]c[nH]c2C[C@@H]1C(=O)[O-]',
#  'C[C@@H](NC(=O)c1cc(=O)c2ccccc2o1)c1cccc(C#N)c1',
#  'O=C(Cc1csc(-c2cnsc2Cl)n1)Nc1nnc(-c2ccccc2)o1',
#  'C[C@@H](CNC(=O)[C@H]1CN(Cc2ccccc2)CCO1)[NH+]1CCc2sccc2C1',
#  'ClC[C@H]1O[C@H](O)[C@@H]2O[C@@H]3[C@H](O)C[C@]6(C)C[C@@](O)(C(=O)CO)[C@@H]4C[C@@H]21',
#  'CCn1c(=O)c2c(nc3oc(-c4ccc(Br)cc4)c(C)n32)n(C)c1=O',
#  'C=CCCCN(C)C(=O)C1=NN(c2ccc(F)cc2)SC[C@@H]1C',
#  'COc1cc(NC(=O)CCCn2cnc3ccccc32)ccc1OC(F)F',
#  'N#Cc1ccc(OCc2ncc(-c3ccc(Cl)cc3Cl)o2)cc1',
#  'COc1cccc(CNC(=O)c2cccc(C)c2O)c1',
#  'CC(=O)Nc1ccc(-c2nc(Cc3cccc(C)c3)no2)cc1',
#  'C=CCS(=O)(=O)Nc1cc2c(cc1Cl)OCCO2',
#  'Cc1ccc(O[C@H](C)C(=O)NC(N)=S)cn1',
#  'O=C(c1ccc([O-])nn1)N1CCCCCC1',
#  'CC(C)CCN(C1CCCCCC1)S(=O)(=O)c1ccccc1C(N)=O',
#  'COc1c(C)cccc1NC(=O)c1ccc(S(N)(=O)=O)cc1',
#  'C[C@@H]1C[C@H]1NC(=O)c1c[nH]nc1-c1cccc(F)c1',
#  'O=C(c1cccc(F)c1)N1C[C@H]2N[C@@H](C1)[C@H]2c1ccc(-c2ccc(F)cc2)cc1',
#  'C[C@@H]([NH2+][C@@H](C)c1nc2cc(Cl)ccc2n1C)C1CCC(C)(C)CC1=O',
#  'COc1ccc(CCNC(=O)C(=O)Nc2cc(C)c3ccc(C)cc3n2)cc1OC',
#  'Cc1cc(N2CCN(C(=O)c3cc4c(s3)CC[C@H](C)C4)CC2)nc(C(C)C)[nH+]1',
#  'COCC[NH2+]Cc1cc(F)ccc1OCc1cc(F)cc(OC)c1',
#  'CC(C)N(C)c1ccc(NC(=O)c2ccncc2Cl)cc1F',
#  'COc1ccc(CNC(=O)N2CCC(NC(=O)c3cccc4ccsc34)CC2)c(OC)c1',
#  'COc1cccc([C@H](C)CC(=O)Nc2cccc(OC)c2OC)c1',
#  'Cc1cc(C)cc(N2CCC(=O)CC2)c1',
#  'O=C(Nc1ccc(F)cc1Br)[C@@]1(C2)[NH2+]CCN2)C1(CCO)CCCCC1',
#  'O=S(=O)(NCc1ccc(S(=O)(=O)N2CCCCCC2)cc1)c1cc(Cl)cc(Cl)c1',
#  'Cc1cc(F)cc([C@](C)(O)Cc2ccc(Cl)cc2)c1',
#  'CC(C)(C)C(=O)Nc1cccc(NC(=O)[C@H](Cl)c2ccccc2)c1',
#  'COc1ccc(C[NH+](Cc2cccc(F)c2)C[C@@H]2CC[C@@H](C[NH3+])O2)cc1',
#  'Nc1c(NCC[NH+]2CCCCCC2)nc(-c2ccccc2)[nH]c1=O',
#  'O=C(Nc1cccc(CC[NH+]2CCCC2)c1)N[C@@H]1C[C@H]2C[C@@H]1[C@H]1CC=C[C@H]21',
#  'COc1ccccc1[C@H](CNC(=O)Nc1ccc(C(N)=O)cn1)c1ccccc1',
#  'Cc1ccc(F)cc1CCNC(=O)c1ccc(NC(=O)c2ccoc2C)cc1',
#  'CCOC(=O)[C@]1(C(C)C)O[C@]12CCCC[C@H]1CC(C)=O',
#  'COc1cc2c(cc1OC)[C@H](c1ccc(Br)cc1)N(C)CC1=O',
#  'C[NH2+][C@@H](COCCO)C1([NH+](C)C)CCC(C)CC1',
#  'CN1C(=O)C(/C=C/c2ccccc2)=[NH+]\\C1=C/C=C\\c1ccc(-c2cnccn2)cc1',
#  'O=C([O-])c1cnc([C@H]2CSCCS2)nc1',
#  'Cc1ccc(NC(=O)C(=O)N/N=C/c2ccc(C(F)(F)F)cc2)c(Cl)c1',
#  'C[NH+]1CCC([C@@H]2CCOC3(CCSCC3)C2)=[NH+]C1',
#  'COCCCNC(=O)[C@@H](C)N1CCc2ccccc2C1',
#  'C[C@@H](NC(=O)COc1ccc(F)cc1)c1ccccc1Br',
#  'CN(Cc1ncoc1C(=O)NC)c1ccc([N+](=O)[O-])cc1)c1ccccc1',
#  'C[C@@H]1CCCC[NH+]1CCC[NH2+][C@H]1CCO[C@]2(CCSC2)C1',
#  'N#C[C@@H]1CN(C(=O)CSc2ccc(Cl)cc2)CCO1',
#  'CCN(CC1CC[NH2+]CC1)C(=O)C1(c2ccc(Cl)cc2)CC1',
#  'C[C@H](Sc1nnc(C2CC2)n1Cc1ccco1)C(=O)N[C@H]1CCCc2ccccc21',
#  'O=C([O-])[C@@H]1[C@H]2CCC[C@H]1C2C2',
#  'O=C(NCc1ccc(C(=O)[O-])cc1)N1CCC[C@H]1Cn1cccn1',
#  'CCCN1CCO[C@H](c2noc(CCC[NH3+])n2)C1',
#  'C[NH2+]Cc1cnn([C@@H]2CCCO2)[C@H]1c1ccc(Cl)c(F)c1',
#  'CO[C@@H](CN(C)C(=O)C1CC1)[C@@H](C)CN(C(=O)c1ccc(F)cc1)[C@H](C)CO',
#  'O=C(NCc1ncc(-c2ccccc2)o1)N1CCN(Cc2ccccc2)CC1',
#  'CCCN(CCC)C(=O)c1ccc(N)c(N(C)C)n1',
#  'COC1CCC(CN(CCC(F)(F)F)C2CC2)CC1',
#  'N#Cc1ccc(OCCCN2CCO[C@@H](c3cccc(F)c3)C2)cc1',
#  'CCC[C@@H](C)N1C[C@@H](C(=O)Nc2ccc(C(C)=O)c(Cl)c2)CC1=O',
#  'CCN(C[C@H](C)C#N)C(=O)[C@H]1C[C@@H]1c1cccc(F)c1',
#  'COc1ccc(C)cc1[C@@H](O)CNc1ccc([N+](=O)[O-])cc1C',
#  'CN(C)c1cccc(/C=N\\NC(=O)C2CCCCC2)c1O',
#  'Cc1ccc(OCC(=O)O[C@H](C)Cn2cc[nH+]c2C)c[nH+]1',
#  'CCN(CC)C(=O)CN1CCC([NH2+]Cc2c(C)nn(C)c2C)CC1',
#  'O=S1(=O)CC[C@H]([C@H](O)[C@H]2CCCC[NH2+]C2)C1',
#  'C[C@H](CNC(=O)NCC(C)(C)c1ccncc1)c1ccsc1',
#  'C[C@H](O)CNC(=O)NCC(C)(C)c1ccncc1',
#  'O=C(Nc1cc(F)ccc1F)N[C@@H]1CC[C@@H](CC(=O)N2CCN(C)CC2)O[C@H]1CO',
#  'C[NH2+][C@@]1(C(=O)[O-])CCC[C@H]1CCOC1CCCCC1',
#  'O=c1c2cn[nH]c2nnn1C[C@H](Br)C1CC1',
#  'Cc1ccc2c(CN(CC[NH+](C)C)CC(C)C)cc(=O)oc2c1',
#  'CCCC(=O)N1CC(=O)N2[C@@H](CO)[C@@H](c3ccc(-c4ccccc4F)cc3)[C@H]2C1',
#  'Cc1csc([C@H](C)NSC/C(N)=N/O)n1',
#  'COc1cccc(CSc2nnc(-c3ccc(C)cc3)n2N)c1',
#  'C[C@H]1CN(S(=O)(=O)/C=C/c2cccc([N+](=O)[O-])c2)c2ccccc2O1',
#  'Cn1c(Cn2cncn2)nn(-c2ccc(Br)cc2)c1=O',
#  'O=C(NCc1ccc2c(c1)OCCCO2)c1ccc(S(=O)(=O)N2CCCC2)cc1',
#  'C[NH2+][C@H](c1ccc(Br)c(F)c1)c1ccc(F)cc1F',
#  'COc1ccc(N2C[C@@H](C(=O)Nc3cc(C(C)=O)cs3)CC2=O)cc1OC',
#  'Cc1cc([C@@H](C)[C@@H](C)[NH3+])cc(C)c1F',
#  'O[C@H](CNCc1ccc[nH+]c1N1CCOCC1)c1ccc(F)cc1',
#  'C=C1c2ccccc2C(=O)N1CCN1C(=O)c2cc3c(cc2O1)OCCO3',
#  'COc1cccc([C@@H](CNC(=O)N2CCC[C@H]2c2ccc(F)cc2)[NH+](C)C)c1',
#  'NNC(=O)CC[C@H]1NN=C2C3CCC4=CC(=COC5CC[C@]23O)(C1)C[C@](C)(C3)C2',
#  'COc1ccc([C@@H](C)NS(=O)(=O)c2c[nH]cn2)cc1F',
#  'O=C(C[C@H]1CC[C@H]2[C@@H](COC[C@H](O)CN2CCC(F)(F)F)O1c1cccnc1)N[C@@H](CO)c1ccccc1',
#  'CCOC(=O)c1c(NC(=O)c2csc(-c3ccccc3)n2)sc2c1CC[NH+](CC)C2',
#  'CCOC(=O)CCSc1nc2ccc(F)cc2n1C',
#  'C[C@@H](NO)C(=O)N[C@H](C(=O)[O-])c1ccccc1',
#  'Cc1cs/c(=N/C(=O)Cn2cc(C)c3ccccc32)cn1',
#  'CN(Cc1c(F)cccc1C(F)F)C1CCC([NH3+])CC1',
#  'O=C(C1CCC1)N1CCC(C(=O)N2CCN(Cc3cccc(Cl)c3)CC2)CC1',
#  'CCc1sc(C(=O)N[C@H]2CC(=O)N(C)C2)cc1C',
#  'Cc1n[nH]c(C)c1C[C@@H](C)C(=O)N(Cc1cccc(F)c1)C[C@@H]1CC=CCC1',
#  'Cc1ccc(CNC(=O)c2cn(-c3ccc(Cl)cc3)nc2C(N)=O)cc1C',
#  'CC[NH+](CC)CCNc1cnn(CC)c1C(F)(F)F',
#  'Cn1ccc(CN\\C([O-])=[NH+]\\Cc2ccc(Br)cc2)n1',
#  'CCOC(=O)[C@](C)(NCc1ccco1)C1CC1',
#  'Nc1cn(C2CCOCC2)nc1C(=O)Nc1ccccc1',
#  'CN(C)C(=O)c1ccc(-c2ccc([C@@H]3[C@H]4CN(Cc5cccnc5)C[C@@H]3N4)cc2)cc1',
#  'Cc1nc2ccc(NC(=O)[C@H](C)[C@H](O)c3cc(F)cc4ccccc34)cc2o1',
#  'O=C(CSc1ccc([N+](=O)[O-])cc1)Nc1cccc(O)c1',
#  'CCc1ncnc(NC[C@H](CC)CO)c1N',
#  'CCC(=O)Nc1cccc(CNC(=O)Cc2cccc3ccccc23)c1',
#  'C[C@@H](CNC(=O)c1cncc(Br)c1)Oc1ccccc1F',
#  'CCOc1cc([C@@H]2C(c3ccc(Cl)cc3)N=N2)ccc1NC(=O)c1ccco1',
#  'O=C(NCCCn1cc[nH+]c1)[C@H]1C[C@H]1c1ccccc1OC(F)(F)F',
#  'Cc1ccc(-c2ncco2)cc1NC(=O)N1CCOC2(CCCC2)C1',
#  'COc1cccc(C(=O)NNC(=O)NCC(C)C)c1O',
#  'O=C(COC(=O)c1ccc(F)c(F)c1)Nc1ccccc1C(=O)N1CCCCC1',
#  'COc1cccc(CNC(=O)C[C@@H]2[NH2+]C)[C@@H]1Cl)c1',
#  'C[C@H](C[C@H]1CCCC[NH2+]1)[NH2+]Cc1cnc(Br)s1',
#  'COc1cc(CNC(=O)N2CC[C@H](CSc3ccccc3)C2)ccn1',
#  'CCOc1ccccc1/C=N/NC(=O)C(=O)Nc1cc(Cl)ccc1Cl',
#  'CC[NH+](CCCCC#N)C[C@@H]1CCS(=O)(=O)C1',
#  'C/C(=C/C(=O)NNC(=O)c1cc2cccn2cn1)c1ccsc1',
#  'CN(CC(=O)Nc1cc(F)ccc1F)C(=O)c1ccccc1',
#  'C[C@H]([NH3+])c1nncn1Cc1cc(F)cc(Br)c1',
#  'COc1ccccc1Nc1nc(N)n(C)c(=O)c1C#N',
#  'CO[C@@H](C)C(=O)N(C)[C@H]1CCCn2ncnc21',
#  'Cc1cc(C(=O)N2CCC(NC(=O)C(C)(C)C)CC(C)(C)C2)c2ccccc2n1',
#  'COCC(=O)N1[C@H](C#N)[C@@H](c2ccc(-c3cccc(C#N)c3)cc2)[C@H]1CO',
#  'C[C@@H]1CC(C)(C)C[C@@]2(C1)NC(=O)N(C[C@H](O)c1ccc(Cl)cc1)C2=O',
#  'Cc1nn(C)c2nc(N(C)[C@H]3CC[NH2+]C3)c(C(=O)OC(C)C)c12',
#  'COc1cc(CC[NH2+][C@H]2C[C@H]3CC[C@@H]2C3)cc(OC)c1OC',
#  'CO[C@@H]1CN(C)C(=O)c2ccc(NC(=O)NC(C)C)cc2OC[C@@H](C)N(Cc2ccccc2)C[C@H]1C',
#  'CCOC[C@@H]1CCCN(C(=O)N[C@H](C)c2ccc3nncn3n2)C1',
#  'CC(C)c1ccc(S(=O)(=O)N(C)CCC#N)/c(c2ccccc2)c(=O)[nH]1',
#  'C[C@@H](C(=O)Nc1ccc(Oc2ccncc2)cc1)[NH+]1CCCCC1',
#  'Cc1occc1C(=O)NNC(=O)c1scnc1C#CCCO',
#  'C/C=C(\\C)CN1C[C@H](C)OC[C@@H]1C',
#  'Cc1ccc2oc(C(=O)Nc3cnn(C(C)(C)C)c3)cc2c1',
#  'C[C@@H](NC(=O)c1nc(Cl)ccc1Cl)C(=O)N1CCc2ccccc21',
#  'C=CCCC[C@@]1(C(=O)[O-])CC[C@@H]2CCCC[C@@H]2[C@@H]1C(=O)NC',
#  'Cc1csc(S[C@@H](C)C(=O)NCc2ccco2)n1',
#  'Cc1cc(=O)n2cccc(C(=O)N[C@@H]3CC[C@@H]([NH+](C)C)C3)c2n1',
#  'CCCn1c(C)nnc1CSCc1csc(COC)n1',
#  'CC[C@H](C1CCCCC1)[NH+](C)CC(C)(C)[NH2+][C@@H]1CCS(=O)(=O)C1',
#  'C[C@H](CC(=O)Nc1cc(C#N)ccc1OC(F)F)c1ccncc1',
#  'COc1ccc(C2=NN=C(C(=O)NNC(=O)c3ccc4n(c3=O)CCSC3=O)[C@H]2c2ccco2)cc1OC',
#  'Cc1occc1-c1nnc(SCC(=O)N2CCc3ccccc3C2)n1C',
#  'Cc1c(Cl)cccc1NC(=O)CNc1cc(C#N)cc([N+](=O)[O-])c1C',
#  'CCOc1ccc(NC(=O)c2scnc2C)cc1CCl',
#  'CC(C)Sc1ccc([C@@H](C)NC2=[N3+]CCCC2)[nH+]c1',
#  'C=CCOc1ccccc1/C=C1\\SC(=S)N(Cc2ccco2)C1=O',
#  'Cc1ncccc1C(=O)N[C@@H](CCCl)c1ccccn1',
#  'O=C(NCCN1CCOCC1)c1cc(COc2c(F)cccc2Cl)oc1C1CC1',
#  'CCN(CC)C(=O)[C@H](C)Sc1nnc(C)n1C1CC1',
#  'CNC(=O)C1CCN(C(=O)c2cccc(C(F)(F)F)c2)CC1',
#  'O=C1N[C@@H](C(=O)N2CCN(Cc3cc(-c4ccccc4)cs3)CC2)S[C@H]1C1CC1',
#  'CC(=O)c1c(C)[nH]c(C(=O)CSc2ncc(-c3ccccc3C)o2)c1C',
#  'O=C(CCN1CCCC1=O)N[C@H](COC(=O)c1cccs1)C(=O)N1CCCc2ccccc21',
#  'O=C(Cc1cccnc1)N1[C@H](CO)[C@H]2c3ccccc3NC[C@@H]21',
#  'CCC[C@@H](C#N)NC(=O)COC1CCCCC1',
#  'CC(C)NC(=O)N1[C@@H](C#N)C(c2ccc(Cl)cc2)[C@H](CNCC2CCC2)O1',
#  'O=C(NC[C@@H](O)c1ccc(F)cc1)c1ccc(F)cn1',
#  'CCOc1ccccc1[C@@H]1CCCN1C(=O)Nc1sccc1C',
#  'Nc1ccc2c(N3CCN(c4cc[nH+]cc4)CC3)ncnc2c1',
#  'O=C(Cc1csc(NC(=O)C2CC2)n1)Nc1c(Cl)cccc1Cl',
#  'Cc1ccc(O[C@@H]2CCOC3(CCC3)C2)c(C=O)c1',
#  'C[C@H](Oc1ccc(C=O)cc1)C(=O)Oc1ccc(F)cc1C#N',
#  'CCOC(=O)C1=C(CN2CCCc3ccccc32)NC(C(=O)Nc2cccc(C)n2)=[NH+]1',
#  'O=C(NCCN1CCN(C(=O)c2cccnc2)CC1)c1ccc(F)cc1Cl',
#  'Cc1ccccc1C1=NN2C(=N)/C(=C\\C3=c4ccccc4=[NH+]C3=O)SC2=S)c1',
#  'CC(=O)c1ccc(OC[C@@H](O)C[NH+]2CCC(C)CC2)cc1',
#  'NC(=O)c1cc(Cl)ccc1NC(=O)CN1CCC[C@H]([NH+]2CCCC2)C1',
#  'COCCCn1c2c(c(=O)c3ccccc31)c1cc3ccccc3nc12',
#  'C/C=C(/C(N)=C/C(C)=O)[C@@H]1CC[C@]2(C)CCC2=O)C1',
#  'CCCC[C@@H]([NH3+])c1noc(-c2ccc(CO)cc2)n1',
#  'CCN(Cc1ccc(Br)cc1)C(=O)C1=NN(c2ccc(F)cc2)[C@H](C(N)=O)C1',
#  'C=C(C)COc1cc(C(=O)N2CCN(c3ccc([N+](=O)[O-])cc3)CC2)ccc1OC',
#  'COc1ccc(NC(=O)Cc2nc(C)c(-c3csc(C)n3)s2)c(OC)c1',
#  'C[C@@H](Cc1cccc(Cl)c1)N(C)C(=O)C1CCN(C(=O)N(C)C)CC1',
#  'Cc1cc2c3c([nH]c2cc1S(=O)(=O)NCCOc1cccc(C)c1)CCCC3',
#  'CC1(C)C[C@@H]([NH2+]C[C@@H](O)c2ccc(Cl)cc2)CN1[C@@H]1SCc1nc(C)sc1C',
#  'CC[C@H]1CN(C(=O)c2csc(-c3cccs3)n2)C[C@@H]1c1cccc(F)c1']
