# %%
import pandas as pd
import scanpy as sc
sc.set_figure_params(dpi=100, frameon=False)
sc.logging.print_header()
# Out:
# scanpy==1.8.1 anndata==0.7.6 umap==0.5.1 numpy==1.19.2 scipy==1.6.2 pandas==1.2.4 scikit-learn==0.24.2 statsmodels==0.12.2 python-igraph==0.9.1 louvain==0.7.0 pynndescent==0.5.2

# %%
import os
os.chdir('./../')
from compert.helper import rank_genes_groups_by_cov
# Out:
# Using backend: pytorch

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
full = True 
load_adata = True 
adata_in = 'datasets/lincs_full.h5ad' if full else 'datasets/lincs.h5ad'
adata = sc.read(adata_in) if load_adata else None

# %%
adata.obs['condition'] = adata.obs['pert_iname']
adata.obs['cell_type'] = adata.obs['cell_id']
adata.obs['dose_val'] = adata.obs['pert_dose']
adata.obs['cov_drug_dose_name'] = adata.obs.cell_type.astype(str) + '_' + adata.obs.condition.astype(str) + '_' + adata.obs.dose_val.astype(str)
adata.obs['control'] = (adata.obs['condition'] == 'DMSO').astype(int)

# %%
pd.crosstab(adata.obs.condition, adata.obs.cell_type)
# Out:
# cell_type                         A375  A549  A673  AGS  ASC  ASC.C  BT20  \
# condition
# 1,2,3,4,5,6-hexabromocyclohexane     5     5     0    0    3      0     0
# 1,2,3,4-tetrahydroisoquinoline       0     0     0    0    0      0     0
# 1,2-dichlorobenzene                  3     6     0    0    4      0     0
# 1,2-propylene-glycol                 0     0     0    0    0      0     0
# 1-benzylimidazole                    4     4     0    0    0      0     0
# ...                                ...   ...   ...  ...  ...    ...   ...
# zonisamide                          23     6     0    0    0      0     0
# zopiclone                            0     0     0    0    0      0     0
# zosuquidar                          20     6     0    0    3      0     0
# zoxazolamine                         6     5     0    0    4      0     0
# zuclopenthixol                       3     6     0    0    4      0     0
#
# cell_type                         CD34  CL34  CORL23  ...  SW620  SW948  \
# condition                                             ...
# 1,2,3,4,5,6-hexabromocyclohexane     0     0       0  ...      0      0
# 1,2,3,4-tetrahydroisoquinoline       0     0       0  ...      0      0
# 1,2-dichlorobenzene                  0     0       0  ...      0      0
# 1,2-propylene-glycol                 0     0       0  ...      0      0
# 1-benzylimidazole                    0     0       0  ...      0      0
# ...                                ...   ...     ...  ...    ...    ...
# zonisamide                           0     0       0  ...      0      0
# zopiclone                            0     0       0  ...      0      0
# zosuquidar                           0     0       0  ...      0      0
# zoxazolamine                         0     0       0  ...      0      0
# zuclopenthixol                       0     0       0  ...      0      0
#
# cell_type                         T3M10  THP1  TYKNU  U266  U937  VCAP  \
# condition
# 1,2,3,4,5,6-hexabromocyclohexane      0     0      0     0     0     0
# 1,2,3,4-tetrahydroisoquinoline        0     0      0     0     0     0
# 1,2-dichlorobenzene                   0     0      0     0     0    12
# 1,2-propylene-glycol                  0     0      0     0     0     0
# 1-benzylimidazole                     0     0      0     0     0    10
# ...                                 ...   ...    ...   ...   ...   ...
# zonisamide                            0     0      0     0     0     9
# zopiclone                             0     0      0     0     0     0
# zosuquidar                            0     0      0     0     0    10
# zoxazolamine                          0     0      0     0     0    10
# zuclopenthixol                        0     0      0     0     0    12
#
# cell_type                         WSUDLCL2  YAPC
# condition
# 1,2,3,4,5,6-hexabromocyclohexane         0     0
# 1,2,3,4-tetrahydroisoquinoline           0     0
# 1,2-dichlorobenzene                      0     0
# 1,2-propylene-glycol                     0     0
# 1-benzylimidazole                        0     0
# ...                                    ...   ...
# zonisamide                               0    18
# zopiclone                                0     0
# zosuquidar                               0    17
# zoxazolamine                             0     0
# zuclopenthixol                           0     0
#
# [20551 rows x 83 columns]

# %%
drug_abundance = adata.obs.condition.value_counts()
suff_drug_abundance = drug_abundance.index[drug_abundance>5]

# %%
# Delete conditions isufficient # of observations
adata = adata[adata.obs.condition.isin(suff_drug_abundance)].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 1023036 × 978
#     obs: 'cell_id', 'det_plate', 'det_well', 'lincs_phase', 'pert_dose', 'pert_dose_unit', 'pert_id', 'pert_iname', 'pert_mfc_id', 'pert_time', 'pert_time_unit', 'pert_type', 'rna_plate', 'rna_well', 'condition', 'cell_type', 'dose_val', 'cov_drug_dose_name', 'control'
#     var: 'pr_gene_title', 'pr_is_lm', 'pr_is_bing'
#     uns: 'cydata_pull'

# %% [markdown]
# Calculate differential genes manually, such that the genes are the same per condition.

# %%
# %%time
from tqdm.notebook import tqdm
import numpy as np 

de_genes = {}
de_genes_quick = {}

adata_df = adata.to_df()
adata_df['condition'] = adata.obs.condition
dmso = adata_df[adata_df.condition == "DMSO"].mean()

for cond, df in tqdm(adata_df.groupby('condition')): 
    if cond != 'DMSO':
        drug_mean = df.mean()
        de_50_idx = np.argsort(abs(drug_mean-dmso))[-50:]
        de_genes_quick[cond] = drug_mean.index[de_50_idx].values

if full: 
    de_genes = de_genes_quick

else:
    sc.tl.rank_genes_groups(
        adata,
        groupby='condition', 
        reference='DMSO',
        rankby_abs=True,
        n_genes=50
    )
    for cond in tqdm(np.unique(adata.obs['condition'])):
        if cond != 'DMSO':
            df = sc.get.rank_genes_groups_df(adata, group=cond)  # this takes a while
            de_genes[cond] = df['names'][:50].values
# Out:
#   0%|          | 0/17990 [00:00<?, ?it/s]
# CPU times: user 41 s, sys: 855 ms, total: 41.8 s
# Wall time: 41.8 s

# %%
if not full: 
    adata.uns['rank_genes_groups_cov'] = {cond: de_genes[cond.split('_')[1]] for cond in adata.obs['cov_drug_dose_name'].unique() if cond.split('_')[1] != 'DMSO'}
else:
    adata.uns['rank_genes_groups_cov'] = {cond: de_genes[cond] for cond in adata.obs.condition.unique() if cond != 'DMSO'}

# %%
adata.obs['split'] = 'train'

# take ood from top occurring perturbations to avoid losing data on low occ ones
ood_idx = sc.pp.subsample(
    adata[adata.obs.condition.isin(list(adata.obs.condition.value_counts().index[1:50]))],
    .1,
    copy=True
).obs.index
adata.obs['split'].loc[ood_idx] = 'ood'

# take test from a random subsampling of the rest
test_idx = sc.pp.subsample(
    adata[adata.obs.split != 'ood'],
    .16,
    copy=True
).obs.index
adata.obs['split'].loc[test_idx] = 'test'

# %%
pd.crosstab(adata.obs['split'], adata.obs['condition'])
# Out:
# condition  1,2,3,4,5,6-hexabromocyclohexane  1,2,3,4-tetrahydroisoquinoline  \
# split
# ood                                       0                               0
# test                                      8                               3
# train                                    29                              15
#
# condition  1,2-dichlorobenzene  1,2-propylene-glycol  1-benzylimidazole  \
# split
# ood                          0                     0                  0
# test                        12                     5                 10
# train                       59                    22                 39
#
# condition  1-methylisoquinoline  1-monopalmitin  1-phenylbiguanide  1B Parent  \
# split
# ood                           0               0                  0          0
# test                          5               7                  9          4
# train                        13              27                 19         18
#
# condition  1B-NR  ...  ziprasidone  zofenopril-calcium  zolantidine  \
# split             ...
# ood            0  ...            0                   0            0
# test           4  ...           34                  24            9
# train         20  ...          155                 102           55
#
# condition  zolmitriptan  zolpidem  zonisamide  zopiclone  zosuquidar  \
# split
# ood                   0         0           0          0           0
# test                 21        37          28          5          32
# train                91       168         195          7         150
#
# condition  zoxazolamine  zuclopenthixol
# split
# ood                   0               0
# test                 15              13
# train                77              70
#
# [3 rows x 17990 columns]

# %%
try: 
    del(adata.uns['rank_genes_groups'])  # too large
except: 
    print('All good.')
# Out:
# All good.

# %%
# code compatibility
from scipy import sparse
adata.X = sparse.csr_matrix(adata.X)

# %%
sc.write('datasets/lincs.h5ad', adata)
# Out:
# ... storing 'cov_drug_dose_name' as categorical
# ... storing 'split' as categorical

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1023036 × 978
#     obs: 'cell_id', 'det_plate', 'det_well', 'lincs_phase', 'pert_dose', 'pert_dose_unit', 'pert_id', 'pert_iname', 'pert_mfc_id', 'pert_time', 'pert_time_unit', 'pert_type', 'rna_plate', 'rna_well', 'condition', 'cell_type', 'dose_val', 'cov_drug_dose_name', 'control', 'split'
#     var: 'pr_gene_title', 'pr_is_lm', 'pr_is_bing'
#     uns: 'cydata_pull', 'rank_genes_groups_cov'
