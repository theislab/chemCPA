# %%
import numpy as np 
import pandas as pd
import scanpy as sc

from chemCPA.paths import DATA_DIR, PROJECT_DIR, ROOT
from tqdm.notebook import tqdm
sc.set_figure_params(dpi=100, frameon=False)
sc.logging.print_header()
# Out:
# 2023-05-31 07:31:45.284931: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-31 07:31:45.443202: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-05-31 07:31:45.443229: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-05-31 07:31:46.268162: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-05-31 07:31:46.268283: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-05-31 07:31:46.268292: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# scanpy==1.9.3 anndata==0.8.0 umap==0.5.3 numpy==1.21.6 scipy==1.7.3 pandas==1.3.5 scikit-learn==1.0.2 statsmodels==0.13.2 pynndescent==0.5.7

# %%
import os
os.chdir('./../')
from chemCPA.helper import rank_genes_groups_by_cov

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from pathlib import Path
print(f"DATA_DIR: {PROJECT_DIR / 'datasets'}")
test_path = Path('/storage/kasperek/chemCPA/datasets/')
print(f"Test path: {test_path}")
# Out:
# DATA_DIR: /storage/kasperek/chemCPA/datasets
# Test path: /storage/kasperek/chemCPA/datasets

# %%
full = True 
load_adata = True 

lincs_path = Path('/storage/kasperek/chemCPA/datasets/')
if full:
    adata_in = os.path.join(lincs_path, 'lincs_full.h5ad')
else:
    adata_in = DATA_DIR / 'lincs.h5ad'

# adata_in = DATA_DIR / 'lincs_full.h5ad' if full else 'datasets/lincs.h5ad'
adata = sc.read(adata_in) if load_adata else None

adata_out = ''.join(adata_in.split('.')[:-1]) + '_pp.h5ad'
adata_out
# Out:
# '/storage/kasperek/chemCPA/datasets/lincs_full_pp.h5ad'

# %%
adata.obs.head()
# Out:
#                                cell_id                 det_plate det_well  \
# REP.A001_A375_24H_X1_B22:A03-2    A375  REP.A001_A375_24H_X1_B22      A03
# REP.A001_A375_24H_X1_B22:A04-2    A375  REP.A001_A375_24H_X1_B22      A04
# REP.A001_A375_24H_X1_B22:A05-2    A375  REP.A001_A375_24H_X1_B22      A05
# REP.A001_A375_24H_X1_B22:A06-2    A375  REP.A001_A375_24H_X1_B22      A06
# REP.A001_A375_24H_X1_B22:A07-2    A375  REP.A001_A375_24H_X1_B22      A07
#
#                                lincs_phase  pert_dose pert_dose_unit  \
# REP.A001_A375_24H_X1_B22:A03-2           2     -666.0           -666
# REP.A001_A375_24H_X1_B22:A04-2           2     -666.0           -666
# REP.A001_A375_24H_X1_B22:A05-2           2     -666.0           -666
# REP.A001_A375_24H_X1_B22:A06-2           2     -666.0           -666
# REP.A001_A375_24H_X1_B22:A07-2           2       10.0             um
#
#                                       pert_id      pert_iname  \
# REP.A001_A375_24H_X1_B22:A03-2           DMSO            DMSO
# REP.A001_A375_24H_X1_B22:A04-2           DMSO            DMSO
# REP.A001_A375_24H_X1_B22:A05-2           DMSO            DMSO
# REP.A001_A375_24H_X1_B22:A06-2           DMSO            DMSO
# REP.A001_A375_24H_X1_B22:A07-2  BRD-K25114078  aminoguanidine
#
#                                            pert_mfc_id  pert_time  \
# REP.A001_A375_24H_X1_B22:A03-2                    -666       24.0
# REP.A001_A375_24H_X1_B22:A04-2                    -666       24.0
# REP.A001_A375_24H_X1_B22:A05-2                    -666       24.0
# REP.A001_A375_24H_X1_B22:A06-2                    -666       24.0
# REP.A001_A375_24H_X1_B22:A07-2  BRD-K25114078-003-08-1       24.0
#
#                                pert_time_unit    pert_type rna_plate rna_well
# REP.A001_A375_24H_X1_B22:A03-2              h  ctl_vehicle       nan      nan
# REP.A001_A375_24H_X1_B22:A04-2              h  ctl_vehicle       nan      nan
# REP.A001_A375_24H_X1_B22:A05-2              h  ctl_vehicle       nan      nan
# REP.A001_A375_24H_X1_B22:A06-2              h  ctl_vehicle       nan      nan
# REP.A001_A375_24H_X1_B22:A07-2              h       trt_cp       nan      nan

# %%
adata.obs['condition'] = adata.obs['pert_iname']
adata.obs['condition'] = adata.obs['condition'].str.replace('/','|')

adata.obs['cell_type'] = adata.obs['cell_id']
adata.obs['dose_val'] = adata.obs['pert_dose']
adata.obs['cov_drug_dose_name'] = adata.obs.cell_type.astype(str) + '_' + adata.obs.condition.astype(str) + '_' + adata.obs.dose_val.astype(str)
adata.obs['cov_drug_name'] = adata.obs.cell_type.astype(str) + '_' + adata.obs.condition.astype(str)
adata.obs['eval_category'] = adata.obs['cov_drug_name']
adata.obs['control'] = (adata.obs['condition'] == 'DMSO').astype(int)

# adata.obs['cov_drug_dose_name'] = adata.obs['cov_drug_dose_name'].str.replace('/','|')

# %%
pd.crosstab(adata.obs.condition, adata.obs.cell_type)
# Out:
# cell_type                                         A375  A549  A673  AGS  ASC  \
# condition
# (+)-3-(1-propyl-piperidin-3-yl)-phenol               0     0     0    0    0
# (+|-)-7-hydroxy-2-(N,N-di-n-propylamino)tetralin     0     0     0    0    0
# 1,2,3,4,5,6-hexabromocyclohexane                     5     5     0    0    3
# 1,2,3,4-tetrahydroisoquinoline                       0     0     0    0    0
# 1,2-dichlorobenzene                                  3     6     0    0    4
# ...                                                ...   ...   ...  ...  ...
# zonisamide                                          23     6     0    0    0
# zopiclone                                            0     0     0    0    0
# zosuquidar                                          20     6     0    0    3
# zoxazolamine                                         6     5     0    0    4
# zuclopenthixol                                       3     6     0    0    4
#
# cell_type                                         ASC.C  BT20  CD34  CL34  \
# condition
# (+)-3-(1-propyl-piperidin-3-yl)-phenol                0     0     0     0
# (+|-)-7-hydroxy-2-(N,N-di-n-propylamino)tetralin      0     0     0     0
# 1,2,3,4,5,6-hexabromocyclohexane                      0     0     0     0
# 1,2,3,4-tetrahydroisoquinoline                        0     0     0     0
# 1,2-dichlorobenzene                                   0     0     0     0
# ...                                                 ...   ...   ...   ...
# zonisamide                                            0     0     0     0
# zopiclone                                             0     0     0     0
# zosuquidar                                            0     0     0     0
# zoxazolamine                                          0     0     0     0
# zuclopenthixol                                        0     0     0     0
#
# cell_type                                         CORL23  ...  SW620  SW948  \
# condition                                                 ...
# (+)-3-(1-propyl-piperidin-3-yl)-phenol                 0  ...      0      0
# (+|-)-7-hydroxy-2-(N,N-di-n-propylamino)tetralin       0  ...      0      0
# 1,2,3,4,5,6-hexabromocyclohexane                       0  ...      0      0
# 1,2,3,4-tetrahydroisoquinoline                         0  ...      0      0
# 1,2-dichlorobenzene                                    0  ...      0      0
# ...                                                  ...  ...    ...    ...
# zonisamide                                             0  ...      0      0
# zopiclone                                              0  ...      0      0
# zosuquidar                                             0  ...      0      0
# zoxazolamine                                           0  ...      0      0
# zuclopenthixol                                         0  ...      0      0
#
# cell_type                                         T3M10  THP1  TYKNU  U266  \
# condition
# (+)-3-(1-propyl-piperidin-3-yl)-phenol                0     0      0     0
# (+|-)-7-hydroxy-2-(N,N-di-n-propylamino)tetralin      0     0      0     0
# 1,2,3,4,5,6-hexabromocyclohexane                      0     0      0     0
# 1,2,3,4-tetrahydroisoquinoline                        0     0      0     0
# 1,2-dichlorobenzene                                   0     0      0     0
# ...                                                 ...   ...    ...   ...
# zonisamide                                            0     0      0     0
# zopiclone                                             0     0      0     0
# zosuquidar                                            0     0      0     0
# zoxazolamine                                          0     0      0     0
# zuclopenthixol                                        0     0      0     0
#
# cell_type                                         U937  VCAP  WSUDLCL2  YAPC
# condition
# (+)-3-(1-propyl-piperidin-3-yl)-phenol               0     0         0     0
# (+|-)-7-hydroxy-2-(N,N-di-n-propylamino)tetralin     0     0         0     0
# 1,2,3,4,5,6-hexabromocyclohexane                     0     0         0     0
# 1,2,3,4-tetrahydroisoquinoline                       0     0         0     0
# 1,2-dichlorobenzene                                  0    12         0     0
# ...                                                ...   ...       ...   ...
# zonisamide                                           0     9         0    18
# zopiclone                                            0     0         0     0
# zosuquidar                                           0    10         0    17
# zoxazolamine                                         0    10         0     0
# zuclopenthixol                                       0    12         0     0
#
# [20551 rows x 83 columns]

# %%
drug_abundance = adata.obs.condition.value_counts()
suff_drug_abundance = drug_abundance.index[drug_abundance>5]

# %%
# Delete conditions isufficient # of observations
adata = adata[adata.obs.condition.isin(suff_drug_abundance)].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 1023036 × 978
#     obs: 'cell_id', 'det_plate', 'det_well', 'lincs_phase', 'pert_dose', 'pert_dose_unit', 'pert_id', 'pert_iname', 'pert_mfc_id', 'pert_time', 'pert_time_unit', 'pert_type', 'rna_plate', 'rna_well', 'condition', 'cell_type', 'dose_val', 'cov_drug_dose_name', 'cov_drug_name', 'eval_category', 'control'
#     var: 'pr_gene_title', 'pr_is_lm', 'pr_is_bing'
#     uns: 'cydata_pull'

# %% [markdown]
# Calculate differential genes manually, such that the genes are the same per condition.

# %%
# %%time

de_genes = {}
de_genes_quick = {}

adata_df = adata.to_df()
adata_df['condition'] = adata.obs.condition
dmso = adata_df[adata_df.condition == "DMSO"].mean()

for cond, df in tqdm(adata_df.groupby('condition')): 
    if cond != 'DMSO':
        drug_mean = df.mean()
        de_50_idx = np.argsort(abs(drug_mean-dmso))[-50:]
        de_genes_quick[cond] = drug_mean.index[de_50_idx].values

if full: 
    de_genes = de_genes_quick

else:
    sc.tl.rank_genes_groups(
        adata,
        groupby='condition', 
        reference='DMSO',
        rankby_abs=True,
        n_genes=50
    )
    for cond in tqdm(np.unique(adata.obs['condition'])):
        if cond != 'DMSO':
            df = sc.get.rank_genes_groups_df(adata, group=cond)  # this takes a while
            de_genes[cond] = df['names'][:50].values
# Out:
#   0%|          | 0/17990 [00:00<?, ?it/s]
# CPU times: user 44.6 s, sys: 2.08 s, total: 46.7 s
# Wall time: 46.3 s

# %% [markdown]
# Mapping from `rank_genes_groups_cov` might cause problems when drug contains '_'

# %%
print(adata.obs.eval_category.unique())
print(extract_drug(cat) for cat in adata.obs.eval_category.unique())
print(extract_drug(adata.obs.eval_category.unique()[1]))
# for cat in adata.obs.eval_category.unique():
#     print(extract_drug(cat))
print({adata.obs.eval_category.unique()[1]: de_genes[extract_drug(adata.obs.eval_category.unique()[1])]})
# print(de_genes.keys())
#print adata.obs.eval_category.unique() element which has 'assinex' in it
print([extract_drug(cat) for cat in adata.obs.eval_category.unique() if 'assinex' in cat])
#print which de_genes element has 'assinex' in it
# print([de_genes[extract_drug(cat)] for cat in adata.obs.eval_category.unique() if 'assinex' in cat])
# print(de_genes)
# Out:
# ['A375_DMSO' 'A375_aminoguanidine' 'A375_pritelivir' ... 'PC3_AVA'
#  'PC3_BRD-K64106162' 'PC3_BRD-K16956545']
# <generator object <genexpr> at 0x7f4981926d50>
# aminoguanidine
# {'A375_aminoguanidine': array(['NARFL', 'DYNLT3', 'KIAA0100', 'NPEPL1', 'HN1L', 'FUT1', 'ARNT2',
#        'CDCA4', 'APOE', 'TEX10', 'POLR2I', 'AURKB', 'SCARB1', 'TESK1',
#        'CSK', 'CD58', 'USP22', 'LRRC41', 'CHIC2', 'NR2F6', 'MMP2',
#        'NPDC1', 'NOSIP', 'ECH1', 'PCNA', 'RTN2', 'CCND1', 'PAPD7',
#        'MRPL12', 'BNIP3L', 'MYBL2', 'AKT1', 'METRN', 'ZNF586', 'SNCA',
#        'CCNB1', 'S100A4', 'HSPA8', 'ACD', 'PAF1', 'CIRBP', 'SCAND1',
#        'CHAC1', 'KIF2C', 'COG7', 'SUPV3L1', 'VPS28', 'ZNF274', 'CLTB',
#        'GAPDH'], dtype=object)}
# ['VCAP_assinex']

# %%
def extract_drug(cond): 
    split = cond.split('_')
    if len(split) == 2: 
        return split[-1]
    return '_'.join(split[1:-1])

adata.obs['cov_drug_dose_name'].apply(lambda s: len(s.split('_'))).value_counts()
adata.obs['eval_category'].apply(lambda s: len(s.split('_'))).value_counts()
# Out:
# 2    1022382
# 3        654
# Name: eval_category, dtype: int64

# %%
print(extract_drug('VCAP_assinex_D328'))
# Out:
# VCAP_assinex

# %%
adata.uns['rank_genes_groups_cov'] = {cat: de_genes[extract_drug(cat)] for cat in adata.obs.eval_category.unique() if extract_drug(cat) != 'DMSO'}
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_57917/1304960138.py in <module>
# ----> 1 adata.uns['rank_genes_groups_cov'] = {cat: de_genes[extract_drug(cat)] for cat in adata.obs.eval_category.unique() if extract_drug(cat) != 'DMSO'}
#
# /tmp/ipykernel_57917/1304960138.py in <dictcomp>(.0)
# ----> 1 adata.uns['rank_genes_groups_cov'] = {cat: de_genes[extract_drug(cat)] for cat in adata.obs.eval_category.unique() if extract_drug(cat) != 'DMSO'}
#
# KeyError: 'assinex'

# %%
for cat in adata.obs.eval_category.unique():
    if extract_drug(cat) != 'DMSO':
        adata.uns['rank_genes_groups_cov'] = {cat: de_genes[extract_drug(cat)]}
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_57917/2492550402.py in <module>
#       1 for cat in adata.obs.eval_category.unique():
#       2     if extract_drug(cat) != 'DMSO':
# ----> 3         adata.uns['rank_genes_groups_cov'] = {cat: de_genes[extract_drug(cat)]}
#
# KeyError: 'assinex'

# %%
adata.uns['rank_genes_groups_cov']
# Out:
# {'A375_aminoguanidine': 'aminoguanidine',
#  'A375_pritelivir': 'pritelivir',
#  'A375_batimastat': 'batimastat',
#  'A375_CX-516': 'CX-516',
#  'A375_aminoglutethimide': 'aminoglutethimide',
#  'A375_oxaprozin': 'oxaprozin',
#  'A375_physostigmine': 'physostigmine',
#  'A375_blonanserin': 'blonanserin',
#  'A375_zaldaride': 'zaldaride',
#  'A375_bortezomib': 'bortezomib',
#  'A375_josamycin': 'josamycin',
#  'A375_licochalcone-a': 'licochalcone-a',
#  'A375_clobetasol': 'clobetasol',
#  'A375_propafenone': 'propafenone',
#  'A375_PD-153035': 'PD-153035',
#  'A375_imiquimod': 'imiquimod',
#  'A375_saquinavir': 'saquinavir',
#  'A375_nicardipine': 'nicardipine',
#  'A375_thiocolchicoside': 'thiocolchicoside',
#  'A375_tegobuvir': 'tegobuvir',
#  'A375_VX-765': 'VX-765',
#  'A375_lestaurtinib': 'lestaurtinib',
#  'A375_ASA-404': 'ASA-404',
#  'A375_proguanil': 'proguanil',
#  'A375_tolperisone': 'tolperisone',
#  'A375_lomeguatrib': 'lomeguatrib',
#  'A375_cyproheptadine': 'cyproheptadine',
#  'A375_ganaxolone': 'ganaxolone',
#  'A375_PKI-179': 'PKI-179',
#  'A375_selegiline': 'selegiline',
#  'A375_calcitriol': 'calcitriol',
#  'A375_ramelteon': 'ramelteon',
#  'A375_benzydamine': 'benzydamine',
#  'A375_pyrazinamide': 'pyrazinamide',
#  'A375_inosine': 'inosine',
#  'A375_ZD-7114': 'ZD-7114',
#  'A375_MG-132': 'MG-132',
#  'A375_PCA-4248': 'PCA-4248',
#  'A375_edoxaban': 'edoxaban',
#  'A375_dutasteride': 'dutasteride',
#  'A375_acebutolol': 'acebutolol',
#  'A375_potassium-canrenoate': 'potassium-canrenoate',
#  'A375_ebselen': 'ebselen',
#  'A375_ziprasidone': 'ziprasidone',
#  'A375_topiramate': 'topiramate',
#  'A375_hypericin': 'hypericin',
#  'A375_disopyramide': 'disopyramide',
#  'A375_anisodamine': 'anisodamine',
#  'A375_MK-8245': 'MK-8245',
#  'A375_17-hydroxyprogesterone-caproate': '17-hydroxyprogesterone-caproate',
#  'A375_ostarine': 'ostarine',
#  'A375_dimesna': 'dimesna',
#  'A375_timolol': 'timolol',
#  'A375_torasemide': 'torasemide',
#  'A375_amikacin': 'amikacin',
#  'A375_ASC-J9': 'ASC-J9',
#  'A375_ellagic-acid': 'ellagic-acid',
#  'A375_penitrem-a': 'penitrem-a',
#  'HA1E_aminoguanidine': 'aminoguanidine',
#  'HA1E_pritelivir': 'pritelivir',
#  'HA1E_batimastat': 'batimastat',
#  'HA1E_CX-516': 'CX-516',
#  'HA1E_aminoglutethimide': 'aminoglutethimide',
#  'HA1E_oxaprozin': 'oxaprozin',
#  'HA1E_physostigmine': 'physostigmine',
#  'HA1E_blonanserin': 'blonanserin',
#  'HA1E_zaldaride': 'zaldaride',
#  'HA1E_bortezomib': 'bortezomib',
#  'HA1E_josamycin': 'josamycin',
#  'HA1E_licochalcone-a': 'licochalcone-a',
#  'HA1E_clobetasol': 'clobetasol',
#  'HA1E_propafenone': 'propafenone',
#  'HA1E_PD-153035': 'PD-153035',
#  'HA1E_imiquimod': 'imiquimod',
#  'HA1E_saquinavir': 'saquinavir',
#  'HA1E_nicardipine': 'nicardipine',
#  'HA1E_thiocolchicoside': 'thiocolchicoside',
#  'HA1E_tegobuvir': 'tegobuvir',
#  'HA1E_VX-765': 'VX-765',
#  'HA1E_lestaurtinib': 'lestaurtinib',
#  'HA1E_ASA-404': 'ASA-404',
#  'HA1E_proguanil': 'proguanil',
#  'HA1E_tolperisone': 'tolperisone',
#  'HA1E_lomeguatrib': 'lomeguatrib',
#  'HA1E_cyproheptadine': 'cyproheptadine',
#  'HA1E_ganaxolone': 'ganaxolone',
#  'HA1E_PKI-179': 'PKI-179',
#  'HA1E_selegiline': 'selegiline',
#  'HA1E_calcitriol': 'calcitriol',
#  'HA1E_ramelteon': 'ramelteon',
#  'HA1E_benzydamine': 'benzydamine',
#  'HA1E_pyrazinamide': 'pyrazinamide',
#  'HA1E_inosine': 'inosine',
#  'HA1E_ZD-7114': 'ZD-7114',
#  'HA1E_MG-132': 'MG-132',
#  'HA1E_PCA-4248': 'PCA-4248',
#  'HA1E_edoxaban': 'edoxaban',
#  'HA1E_dutasteride': 'dutasteride',
#  'HA1E_acebutolol': 'acebutolol',
#  'HA1E_potassium-canrenoate': 'potassium-canrenoate',
#  'HA1E_ebselen': 'ebselen',
#  'HA1E_ziprasidone': 'ziprasidone',
#  'HA1E_topiramate': 'topiramate',
#  'HA1E_hypericin': 'hypericin',
#  'HA1E_disopyramide': 'disopyramide',
#  'HA1E_anisodamine': 'anisodamine',
#  'HA1E_MK-8245': 'MK-8245',
#  'HA1E_17-hydroxyprogesterone-caproate': '17-hydroxyprogesterone-caproate',
#  'HA1E_ostarine': 'ostarine',
#  'HA1E_dimesna': 'dimesna',
#  'HA1E_timolol': 'timolol',
#  'HA1E_torasemide': 'torasemide',
#  'HA1E_amikacin': 'amikacin',
#  'HA1E_ASC-J9': 'ASC-J9',
#  'HA1E_ellagic-acid': 'ellagic-acid',
#  'HA1E_penitrem-a': 'penitrem-a',
#  'HELA_aminoguanidine': 'aminoguanidine',
#  'HELA_pritelivir': 'pritelivir',
#  'HELA_batimastat': 'batimastat',
#  'HELA_CX-516': 'CX-516',
#  'HELA_aminoglutethimide': 'aminoglutethimide',
#  'HELA_oxaprozin': 'oxaprozin',
#  'HELA_physostigmine': 'physostigmine',
#  'HELA_blonanserin': 'blonanserin',
#  'HELA_zaldaride': 'zaldaride',
#  'HELA_bortezomib': 'bortezomib',
#  'HELA_josamycin': 'josamycin',
#  'HELA_licochalcone-a': 'licochalcone-a',
#  'HELA_clobetasol': 'clobetasol',
#  'HELA_propafenone': 'propafenone',
#  'HELA_PD-153035': 'PD-153035',
#  'HELA_imiquimod': 'imiquimod',
#  'HELA_saquinavir': 'saquinavir',
#  'HELA_nicardipine': 'nicardipine',
#  'HELA_thiocolchicoside': 'thiocolchicoside',
#  'HELA_tegobuvir': 'tegobuvir',
#  'HELA_VX-765': 'VX-765',
#  'HELA_lestaurtinib': 'lestaurtinib',
#  'HELA_ASA-404': 'ASA-404',
#  'HELA_proguanil': 'proguanil',
#  'HELA_tolperisone': 'tolperisone',
#  'HELA_lomeguatrib': 'lomeguatrib',
#  'HELA_cyproheptadine': 'cyproheptadine',
#  'HELA_ganaxolone': 'ganaxolone',
#  'HELA_PKI-179': 'PKI-179',
#  'HELA_selegiline': 'selegiline',
#  'HELA_calcitriol': 'calcitriol',
#  'HELA_ramelteon': 'ramelteon',
#  'HELA_benzydamine': 'benzydamine',
#  'HELA_pyrazinamide': 'pyrazinamide',
#  'HELA_inosine': 'inosine',
#  'HELA_ZD-7114': 'ZD-7114',
#  'HELA_MG-132': 'MG-132',
#  'HELA_PCA-4248': 'PCA-4248',
#  'HELA_edoxaban': 'edoxaban',
#  'HELA_dutasteride': 'dutasteride',
#  'HELA_acebutolol': 'acebutolol',
#  'HELA_potassium-canrenoate': 'potassium-canrenoate',
#  'HELA_ebselen': 'ebselen',
#  'HELA_ziprasidone': 'ziprasidone',
#  'HELA_topiramate': 'topiramate',
#  'HELA_hypericin': 'hypericin',
#  'HELA_disopyramide': 'disopyramide',
#  'HELA_anisodamine': 'anisodamine',
#  'HELA_MK-8245': 'MK-8245',
#  'HELA_17-hydroxyprogesterone-caproate': '17-hydroxyprogesterone-caproate',
#  'HELA_ostarine': 'ostarine',
#  'HELA_dimesna': 'dimesna',
#  'HELA_timolol': 'timolol',
#  'HELA_torasemide': 'torasemide',
#  'HELA_amikacin': 'amikacin',
#  'HELA_ASC-J9': 'ASC-J9',
#  'HELA_ellagic-acid': 'ellagic-acid',
#  'HELA_penitrem-a': 'penitrem-a',
#  'HT29_aminoguanidine': 'aminoguanidine',
#  'HT29_pritelivir': 'pritelivir',
#  'HT29_batimastat': 'batimastat',
#  'HT29_CX-516': 'CX-516',
#  'HT29_aminoglutethimide': 'aminoglutethimide',
#  'HT29_oxaprozin': 'oxaprozin',
#  'HT29_physostigmine': 'physostigmine',
#  'HT29_blonanserin': 'blonanserin',
#  'HT29_zaldaride': 'zaldaride',
#  'HT29_bortezomib': 'bortezomib',
#  'HT29_josamycin': 'josamycin',
#  'HT29_licochalcone-a': 'licochalcone-a',
#  'HT29_clobetasol': 'clobetasol',
#  'HT29_propafenone': 'propafenone',
#  'HT29_PD-153035': 'PD-153035',
#  'HT29_imiquimod': 'imiquimod',
#  'HT29_saquinavir': 'saquinavir',
#  'HT29_nicardipine': 'nicardipine',
#  'HT29_thiocolchicoside': 'thiocolchicoside',
#  'HT29_tegobuvir': 'tegobuvir',
#  'HT29_VX-765': 'VX-765',
#  'HT29_lestaurtinib': 'lestaurtinib',
#  'HT29_ASA-404': 'ASA-404',
#  'HT29_proguanil': 'proguanil',
#  'HT29_tolperisone': 'tolperisone',
#  'HT29_lomeguatrib': 'lomeguatrib',
#  'HT29_cyproheptadine': 'cyproheptadine',
#  'HT29_ganaxolone': 'ganaxolone',
#  'HT29_PKI-179': 'PKI-179',
#  'HT29_selegiline': 'selegiline',
#  'HT29_calcitriol': 'calcitriol',
#  'HT29_ramelteon': 'ramelteon',
#  'HT29_benzydamine': 'benzydamine',
#  'HT29_pyrazinamide': 'pyrazinamide',
#  'HT29_inosine': 'inosine',
#  'HT29_ZD-7114': 'ZD-7114',
#  'HT29_MG-132': 'MG-132',
#  'HT29_PCA-4248': 'PCA-4248',
#  'HT29_edoxaban': 'edoxaban',
#  'HT29_dutasteride': 'dutasteride',
#  'HT29_acebutolol': 'acebutolol',
#  'HT29_potassium-canrenoate': 'potassium-canrenoate',
#  'HT29_ebselen': 'ebselen',
#  'HT29_ziprasidone': 'ziprasidone',
#  'HT29_topiramate': 'topiramate',
#  'HT29_hypericin': 'hypericin',
#  'HT29_disopyramide': 'disopyramide',
#  'HT29_anisodamine': 'anisodamine',
#  'HT29_MK-8245': 'MK-8245',
#  'HT29_17-hydroxyprogesterone-caproate': '17-hydroxyprogesterone-caproate',
#  'HT29_ostarine': 'ostarine',
#  'HT29_dimesna': 'dimesna',
#  'HT29_timolol': 'timolol',
#  'HT29_torasemide': 'torasemide',
#  'HT29_amikacin': 'amikacin',
#  'HT29_ASC-J9': 'ASC-J9',
#  'HT29_ellagic-acid': 'ellagic-acid',
#  'HT29_penitrem-a': 'penitrem-a',
#  'MCF7_aminoguanidine': 'aminoguanidine',
#  'MCF7_pritelivir': 'pritelivir',
#  'MCF7_batimastat': 'batimastat',
#  'MCF7_CX-516': 'CX-516',
#  'MCF7_aminoglutethimide': 'aminoglutethimide',
#  'MCF7_oxaprozin': 'oxaprozin',
#  'MCF7_physostigmine': 'physostigmine',
#  'MCF7_blonanserin': 'blonanserin',
#  'MCF7_zaldaride': 'zaldaride',
#  'MCF7_bortezomib': 'bortezomib',
#  'MCF7_josamycin': 'josamycin',
#  'MCF7_licochalcone-a': 'licochalcone-a',
#  'MCF7_clobetasol': 'clobetasol',
#  'MCF7_propafenone': 'propafenone',
#  'MCF7_PD-153035': 'PD-153035',
#  'MCF7_imiquimod': 'imiquimod',
#  'MCF7_saquinavir': 'saquinavir',
#  'MCF7_nicardipine': 'nicardipine',
#  'MCF7_thiocolchicoside': 'thiocolchicoside',
#  'MCF7_tegobuvir': 'tegobuvir',
#  'MCF7_VX-765': 'VX-765',
#  'MCF7_lestaurtinib': 'lestaurtinib',
#  'MCF7_ASA-404': 'ASA-404',
#  'MCF7_proguanil': 'proguanil',
#  'MCF7_tolperisone': 'tolperisone',
#  'MCF7_lomeguatrib': 'lomeguatrib',
#  'MCF7_cyproheptadine': 'cyproheptadine',
#  'MCF7_ganaxolone': 'ganaxolone',
#  'MCF7_PKI-179': 'PKI-179',
#  'MCF7_selegiline': 'selegiline',
#  'MCF7_calcitriol': 'calcitriol',
#  'MCF7_ramelteon': 'ramelteon',
#  'MCF7_benzydamine': 'benzydamine',
#  'MCF7_pyrazinamide': 'pyrazinamide',
#  'MCF7_inosine': 'inosine',
#  'MCF7_ZD-7114': 'ZD-7114',
#  'MCF7_MG-132': 'MG-132',
#  'MCF7_PCA-4248': 'PCA-4248',
#  'MCF7_edoxaban': 'edoxaban',
#  'MCF7_dutasteride': 'dutasteride',
#  'MCF7_acebutolol': 'acebutolol',
#  'MCF7_potassium-canrenoate': 'potassium-canrenoate',
#  'MCF7_ebselen': 'ebselen',
#  'MCF7_ziprasidone': 'ziprasidone',
#  'MCF7_topiramate': 'topiramate',
#  'MCF7_hypericin': 'hypericin',
#  'MCF7_disopyramide': 'disopyramide',
#  'MCF7_anisodamine': 'anisodamine',
#  'MCF7_MK-8245': 'MK-8245',
#  'MCF7_17-hydroxyprogesterone-caproate': '17-hydroxyprogesterone-caproate',
#  'MCF7_ostarine': 'ostarine',
#  'MCF7_dimesna': 'dimesna',
#  'MCF7_timolol': 'timolol',
#  'MCF7_torasemide': 'torasemide',
#  'MCF7_amikacin': 'amikacin',
#  'MCF7_ASC-J9': 'ASC-J9',
#  'MCF7_ellagic-acid': 'ellagic-acid',
#  'MCF7_penitrem-a': 'penitrem-a',
#  'PC3_aminoguanidine': 'aminoguanidine',
#  'PC3_pritelivir': 'pritelivir',
#  'PC3_batimastat': 'batimastat',
#  'PC3_CX-516': 'CX-516',
#  'PC3_aminoglutethimide': 'aminoglutethimide',
#  'PC3_oxaprozin': 'oxaprozin',
#  'PC3_physostigmine': 'physostigmine',
#  'PC3_blonanserin': 'blonanserin',
#  'PC3_zaldaride': 'zaldaride',
#  'PC3_bortezomib': 'bortezomib',
#  'PC3_josamycin': 'josamycin',
#  'PC3_licochalcone-a': 'licochalcone-a',
#  'PC3_clobetasol': 'clobetasol',
#  'PC3_propafenone': 'propafenone',
#  'PC3_PD-153035': 'PD-153035',
#  'PC3_imiquimod': 'imiquimod',
#  'PC3_saquinavir': 'saquinavir',
#  'PC3_nicardipine': 'nicardipine',
#  'PC3_thiocolchicoside': 'thiocolchicoside',
#  'PC3_tegobuvir': 'tegobuvir',
#  'PC3_VX-765': 'VX-765',
#  'PC3_lestaurtinib': 'lestaurtinib',
#  'PC3_ASA-404': 'ASA-404',
#  'PC3_proguanil': 'proguanil',
#  'PC3_tolperisone': 'tolperisone',
#  'PC3_lomeguatrib': 'lomeguatrib',
#  'PC3_cyproheptadine': 'cyproheptadine',
#  'PC3_ganaxolone': 'ganaxolone',
#  'PC3_PKI-179': 'PKI-179',
#  'PC3_selegiline': 'selegiline',
#  'PC3_calcitriol': 'calcitriol',
#  'PC3_ramelteon': 'ramelteon',
#  'PC3_benzydamine': 'benzydamine',
#  'PC3_pyrazinamide': 'pyrazinamide',
#  'PC3_inosine': 'inosine',
#  'PC3_ZD-7114': 'ZD-7114',
#  'PC3_MG-132': 'MG-132',
#  'PC3_PCA-4248': 'PCA-4248',
#  'PC3_edoxaban': 'edoxaban',
#  'PC3_dutasteride': 'dutasteride',
#  'PC3_acebutolol': 'acebutolol',
#  'PC3_potassium-canrenoate': 'potassium-canrenoate',
#  'PC3_ebselen': 'ebselen',
#  'PC3_ziprasidone': 'ziprasidone',
#  'PC3_topiramate': 'topiramate',
#  'PC3_hypericin': 'hypericin',
#  'PC3_disopyramide': 'disopyramide',
#  'PC3_anisodamine': 'anisodamine',
#  'PC3_MK-8245': 'MK-8245',
#  'PC3_17-hydroxyprogesterone-caproate': '17-hydroxyprogesterone-caproate',
#  'PC3_ostarine': 'ostarine',
#  'PC3_dimesna': 'dimesna',
#  'PC3_timolol': 'timolol',
#  'PC3_torasemide': 'torasemide',
#  'PC3_amikacin': 'amikacin',
#  'PC3_ASC-J9': 'ASC-J9',
#  'PC3_ellagic-acid': 'ellagic-acid',
#  'PC3_penitrem-a': 'penitrem-a',
#  'YAPC_aminoguanidine': 'aminoguanidine',
#  'YAPC_pritelivir': 'pritelivir',
#  'YAPC_batimastat': 'batimastat',
#  'YAPC_CX-516': 'CX-516',
#  'YAPC_aminoglutethimide': 'aminoglutethimide',
#  'YAPC_oxaprozin': 'oxaprozin',
#  'YAPC_physostigmine': 'physostigmine',
#  'YAPC_blonanserin': 'blonanserin',
#  'YAPC_zaldaride': 'zaldaride',
#  'YAPC_bortezomib': 'bortezomib',
#  'YAPC_josamycin': 'josamycin',
#  'YAPC_licochalcone-a': 'licochalcone-a',
#  'YAPC_clobetasol': 'clobetasol',
#  'YAPC_propafenone': 'propafenone',
#  'YAPC_PD-153035': 'PD-153035',
#  'YAPC_imiquimod': 'imiquimod',
#  'YAPC_saquinavir': 'saquinavir',
#  'YAPC_nicardipine': 'nicardipine',
#  'YAPC_thiocolchicoside': 'thiocolchicoside',
#  'YAPC_tegobuvir': 'tegobuvir',
#  'YAPC_VX-765': 'VX-765',
#  'YAPC_lestaurtinib': 'lestaurtinib',
#  'YAPC_ASA-404': 'ASA-404',
#  'YAPC_proguanil': 'proguanil',
#  'YAPC_tolperisone': 'tolperisone',
#  'YAPC_lomeguatrib': 'lomeguatrib',
#  'YAPC_cyproheptadine': 'cyproheptadine',
#  'YAPC_ganaxolone': 'ganaxolone',
#  'YAPC_PKI-179': 'PKI-179',
#  'YAPC_selegiline': 'selegiline',
#  'YAPC_calcitriol': 'calcitriol',
#  'YAPC_ramelteon': 'ramelteon',
#  'YAPC_benzydamine': 'benzydamine',
#  'YAPC_pyrazinamide': 'pyrazinamide',
#  'YAPC_inosine': 'inosine',
#  'YAPC_ZD-7114': 'ZD-7114',
#  'YAPC_MG-132': 'MG-132',
#  'YAPC_PCA-4248': 'PCA-4248',
#  'YAPC_edoxaban': 'edoxaban',
#  'YAPC_dutasteride': 'dutasteride',
#  'YAPC_acebutolol': 'acebutolol',
#  'YAPC_potassium-canrenoate': 'potassium-canrenoate',
#  'YAPC_ebselen': 'ebselen',
#  'YAPC_ziprasidone': 'ziprasidone',
#  'YAPC_topiramate': 'topiramate',
#  'YAPC_hypericin': 'hypericin',
#  'YAPC_disopyramide': 'disopyramide',
#  'YAPC_anisodamine': 'anisodamine',
#  'YAPC_MK-8245': 'MK-8245',
#  'YAPC_17-hydroxyprogesterone-caproate': '17-hydroxyprogesterone-caproate',
#  'YAPC_ostarine': 'ostarine',
#  'YAPC_dimesna': 'dimesna',
#  'YAPC_timolol': 'timolol',
#  'YAPC_torasemide': 'torasemide',
#  'YAPC_amikacin': 'amikacin',
#  'YAPC_ASC-J9': 'ASC-J9',
#  'YAPC_ellagic-acid': 'ellagic-acid',
#  'YAPC_penitrem-a': 'penitrem-a',
#  'A375_nevirapine': 'nevirapine',
#  'A375_papaverine': 'papaverine',
#  'A375_rebamipide': 'rebamipide',
#  'A375_tesaglitazar': 'tesaglitazar',
#  'A375_cefdinir': 'cefdinir',
#  'A375_clotrimazole': 'clotrimazole',
#  'A375_ropinirole': 'ropinirole',
#  'A375_Z160': 'Z160',
#  'A375_abiraterone-acetate': 'abiraterone-acetate',
#  'A375_telbivudine': 'telbivudine',
#  'A375_fentiazac': 'fentiazac',
#  'A375_oxymetazoline': 'oxymetazoline',
#  'A375_atrasentan': 'atrasentan',
#  'A375_indobufen': 'indobufen',
#  'A375_ibudilast': 'ibudilast',
#  'A375_diazepam': 'diazepam',
#  'A375_butoconazole': 'butoconazole',
#  'A375_thioctic-acid': 'thioctic-acid',
#  'A375_zaprinast': 'zaprinast',
#  'A375_regorafenib': 'regorafenib',
#  'A375_MK-0893': 'MK-0893',
#  'A375_sotrastaurin': 'sotrastaurin',
#  'A375_bevirimat-dimeglumine': 'bevirimat-dimeglumine',
#  'A375_PRX-08066': 'PRX-08066',
#  'A375_clarithromycin': 'clarithromycin',
#  'A375_filgotinib': 'filgotinib',
#  'A375_protirelin': 'protirelin',
#  'A375_pibenzimol': 'pibenzimol',
#  'A375_chloroxine': 'chloroxine',
#  'A375_carprofen': 'carprofen',
#  'A375_bambuterol': 'bambuterol',
#  'A375_bendamustine': 'bendamustine',
#  'A375_LY-2874455': 'LY-2874455',
#  'A375_atracurium': 'atracurium',
#  'A375_bropirimine': 'bropirimine',
#  'A375_amiodarone': 'amiodarone',
#  'A375_JTC-801': 'JTC-801',
#  'A375_firategrast': 'firategrast',
#  'A375_talmapimod': 'talmapimod',
#  'A375_ibuprofen': 'ibuprofen',
#  'A375_belinostat': 'belinostat',
#  'A375_tranilast': 'tranilast',
#  'A375_indirubin': 'indirubin',
#  'A375_artesunate': 'artesunate',
#  'A375_phensuximide': 'phensuximide',
#  'A375_lenalidomide': 'lenalidomide',
#  'A375_retapamulin': 'retapamulin',
#  'A375_LY-2886721': 'LY-2886721',
#  'A375_bosutinib': 'bosutinib',
#  'A375_mephentermine': 'mephentermine',
#  'A375_NVP-BEZ235': 'NVP-BEZ235',
#  'A375_folic-acid': 'folic-acid',
#  'A375_fdcyd': 'fdcyd',
#  'A375_budipine': 'budipine',
#  'A375_estriol': 'estriol',
#  'A375_ZD-7288': 'ZD-7288',
#  'HA1E_nevirapine': 'nevirapine',
#  'HA1E_papaverine': 'papaverine',
#  'HA1E_rebamipide': 'rebamipide',
#  'HA1E_tesaglitazar': 'tesaglitazar',
#  'HA1E_cefdinir': 'cefdinir',
#  'HA1E_clotrimazole': 'clotrimazole',
#  'HA1E_ropinirole': 'ropinirole',
#  'HA1E_Z160': 'Z160',
#  'HA1E_abiraterone-acetate': 'abiraterone-acetate',
#  'HA1E_telbivudine': 'telbivudine',
#  'HA1E_fentiazac': 'fentiazac',
#  'HA1E_oxymetazoline': 'oxymetazoline',
#  'HA1E_atrasentan': 'atrasentan',
#  'HA1E_indobufen': 'indobufen',
#  'HA1E_ibudilast': 'ibudilast',
#  'HA1E_diazepam': 'diazepam',
#  'HA1E_butoconazole': 'butoconazole',
#  'HA1E_thioctic-acid': 'thioctic-acid',
#  'HA1E_zaprinast': 'zaprinast',
#  'HA1E_regorafenib': 'regorafenib',
#  'HA1E_MK-0893': 'MK-0893',
#  'HA1E_sotrastaurin': 'sotrastaurin',
#  'HA1E_bevirimat-dimeglumine': 'bevirimat-dimeglumine',
#  'HA1E_PRX-08066': 'PRX-08066',
#  'HA1E_clarithromycin': 'clarithromycin',
#  'HA1E_filgotinib': 'filgotinib',
#  'HA1E_protirelin': 'protirelin',
#  'HA1E_pibenzimol': 'pibenzimol',
#  'HA1E_chloroxine': 'chloroxine',
#  'HA1E_carprofen': 'carprofen',
#  'HA1E_bambuterol': 'bambuterol',
#  'HA1E_bendamustine': 'bendamustine',
#  'HA1E_LY-2874455': 'LY-2874455',
#  'HA1E_atracurium': 'atracurium',
#  'HA1E_bropirimine': 'bropirimine',
#  'HA1E_amiodarone': 'amiodarone',
#  'HA1E_JTC-801': 'JTC-801',
#  'HA1E_firategrast': 'firategrast',
#  'HA1E_talmapimod': 'talmapimod',
#  'HA1E_ibuprofen': 'ibuprofen',
#  'HA1E_belinostat': 'belinostat',
#  'HA1E_tranilast': 'tranilast',
#  'HA1E_indirubin': 'indirubin',
#  'HA1E_artesunate': 'artesunate',
#  'HA1E_phensuximide': 'phensuximide',
#  'HA1E_lenalidomide': 'lenalidomide',
#  'HA1E_retapamulin': 'retapamulin',
#  'HA1E_LY-2886721': 'LY-2886721',
#  'HA1E_bosutinib': 'bosutinib',
#  'HA1E_mephentermine': 'mephentermine',
#  'HA1E_NVP-BEZ235': 'NVP-BEZ235',
#  'HA1E_folic-acid': 'folic-acid',
#  'HA1E_fdcyd': 'fdcyd',
#  'HA1E_budipine': 'budipine',
#  'HA1E_estriol': 'estriol',
#  'HA1E_ZD-7288': 'ZD-7288',
#  'HELA_nevirapine': 'nevirapine',
#  'HELA_papaverine': 'papaverine',
#  'HELA_rebamipide': 'rebamipide',
#  'HELA_tesaglitazar': 'tesaglitazar',
#  'HELA_cefdinir': 'cefdinir',
#  'HELA_clotrimazole': 'clotrimazole',
#  'HELA_ropinirole': 'ropinirole',
#  'HELA_Z160': 'Z160',
#  'HELA_abiraterone-acetate': 'abiraterone-acetate',
#  'HELA_telbivudine': 'telbivudine',
#  'HELA_fentiazac': 'fentiazac',
#  'HELA_oxymetazoline': 'oxymetazoline',
#  'HELA_atrasentan': 'atrasentan',
#  'HELA_indobufen': 'indobufen',
#  'HELA_ibudilast': 'ibudilast',
#  'HELA_diazepam': 'diazepam',
#  'HELA_butoconazole': 'butoconazole',
#  'HELA_thioctic-acid': 'thioctic-acid',
#  'HELA_zaprinast': 'zaprinast',
#  'HELA_regorafenib': 'regorafenib',
#  'HELA_MK-0893': 'MK-0893',
#  'HELA_sotrastaurin': 'sotrastaurin',
#  'HELA_bevirimat-dimeglumine': 'bevirimat-dimeglumine',
#  'HELA_PRX-08066': 'PRX-08066',
#  'HELA_clarithromycin': 'clarithromycin',
#  'HELA_filgotinib': 'filgotinib',
#  'HELA_protirelin': 'protirelin',
#  'HELA_pibenzimol': 'pibenzimol',
#  'HELA_chloroxine': 'chloroxine',
#  'HELA_carprofen': 'carprofen',
#  'HELA_bambuterol': 'bambuterol',
#  'HELA_bendamustine': 'bendamustine',
#  'HELA_LY-2874455': 'LY-2874455',
#  'HELA_atracurium': 'atracurium',
#  'HELA_bropirimine': 'bropirimine',
#  'HELA_amiodarone': 'amiodarone',
#  'HELA_JTC-801': 'JTC-801',
#  'HELA_firategrast': 'firategrast',
#  'HELA_talmapimod': 'talmapimod',
#  'HELA_ibuprofen': 'ibuprofen',
#  'HELA_belinostat': 'belinostat',
#  'HELA_tranilast': 'tranilast',
#  'HELA_indirubin': 'indirubin',
#  'HELA_artesunate': 'artesunate',
#  'HELA_phensuximide': 'phensuximide',
#  'HELA_lenalidomide': 'lenalidomide',
#  'HELA_retapamulin': 'retapamulin',
#  'HELA_LY-2886721': 'LY-2886721',
#  'HELA_bosutinib': 'bosutinib',
#  'HELA_mephentermine': 'mephentermine',
#  'HELA_NVP-BEZ235': 'NVP-BEZ235',
#  'HELA_folic-acid': 'folic-acid',
#  'HELA_fdcyd': 'fdcyd',
#  'HELA_budipine': 'budipine',
#  'HELA_estriol': 'estriol',
#  'HELA_ZD-7288': 'ZD-7288',
#  'HT29_nevirapine': 'nevirapine',
#  'HT29_papaverine': 'papaverine',
#  'HT29_rebamipide': 'rebamipide',
#  'HT29_tesaglitazar': 'tesaglitazar',
#  'HT29_cefdinir': 'cefdinir',
#  'HT29_clotrimazole': 'clotrimazole',
#  'HT29_ropinirole': 'ropinirole',
#  'HT29_Z160': 'Z160',
#  'HT29_abiraterone-acetate': 'abiraterone-acetate',
#  'HT29_telbivudine': 'telbivudine',
#  'HT29_fentiazac': 'fentiazac',
#  'HT29_oxymetazoline': 'oxymetazoline',
#  'HT29_atrasentan': 'atrasentan',
#  'HT29_indobufen': 'indobufen',
#  'HT29_ibudilast': 'ibudilast',
#  'HT29_diazepam': 'diazepam',
#  'HT29_butoconazole': 'butoconazole',
#  'HT29_thioctic-acid': 'thioctic-acid',
#  'HT29_zaprinast': 'zaprinast',
#  'HT29_regorafenib': 'regorafenib',
#  'HT29_MK-0893': 'MK-0893',
#  'HT29_sotrastaurin': 'sotrastaurin',
#  'HT29_bevirimat-dimeglumine': 'bevirimat-dimeglumine',
#  'HT29_PRX-08066': 'PRX-08066',
#  'HT29_clarithromycin': 'clarithromycin',
#  'HT29_filgotinib': 'filgotinib',
#  'HT29_protirelin': 'protirelin',
#  'HT29_pibenzimol': 'pibenzimol',
#  'HT29_chloroxine': 'chloroxine',
#  'HT29_carprofen': 'carprofen',
#  'HT29_bambuterol': 'bambuterol',
#  'HT29_bendamustine': 'bendamustine',
#  'HT29_LY-2874455': 'LY-2874455',
#  'HT29_atracurium': 'atracurium',
#  'HT29_bropirimine': 'bropirimine',
#  'HT29_amiodarone': 'amiodarone',
#  'HT29_JTC-801': 'JTC-801',
#  'HT29_firategrast': 'firategrast',
#  'HT29_talmapimod': 'talmapimod',
#  'HT29_ibuprofen': 'ibuprofen',
#  'HT29_belinostat': 'belinostat',
#  'HT29_tranilast': 'tranilast',
#  'HT29_indirubin': 'indirubin',
#  'HT29_artesunate': 'artesunate',
#  'HT29_phensuximide': 'phensuximide',
#  'HT29_lenalidomide': 'lenalidomide',
#  'HT29_retapamulin': 'retapamulin',
#  'HT29_LY-2886721': 'LY-2886721',
#  'HT29_bosutinib': 'bosutinib',
#  'HT29_mephentermine': 'mephentermine',
#  'HT29_NVP-BEZ235': 'NVP-BEZ235',
#  'HT29_folic-acid': 'folic-acid',
#  'HT29_fdcyd': 'fdcyd',
#  'HT29_budipine': 'budipine',
#  'HT29_estriol': 'estriol',
#  'HT29_ZD-7288': 'ZD-7288',
#  'MCF7_nevirapine': 'nevirapine',
#  'MCF7_papaverine': 'papaverine',
#  'MCF7_rebamipide': 'rebamipide',
#  'MCF7_tesaglitazar': 'tesaglitazar',
#  'MCF7_cefdinir': 'cefdinir',
#  'MCF7_clotrimazole': 'clotrimazole',
#  'MCF7_ropinirole': 'ropinirole',
#  'MCF7_Z160': 'Z160',
#  'MCF7_abiraterone-acetate': 'abiraterone-acetate',
#  'MCF7_telbivudine': 'telbivudine',
#  'MCF7_fentiazac': 'fentiazac',
#  'MCF7_oxymetazoline': 'oxymetazoline',
#  'MCF7_atrasentan': 'atrasentan',
#  'MCF7_indobufen': 'indobufen',
#  'MCF7_ibudilast': 'ibudilast',
#  'MCF7_diazepam': 'diazepam',
#  'MCF7_butoconazole': 'butoconazole',
#  'MCF7_thioctic-acid': 'thioctic-acid',
#  'MCF7_zaprinast': 'zaprinast',
#  'MCF7_regorafenib': 'regorafenib',
#  'MCF7_MK-0893': 'MK-0893',
#  'MCF7_sotrastaurin': 'sotrastaurin',
#  'MCF7_bevirimat-dimeglumine': 'bevirimat-dimeglumine',
#  'MCF7_PRX-08066': 'PRX-08066',
#  'MCF7_clarithromycin': 'clarithromycin',
#  'MCF7_filgotinib': 'filgotinib',
#  'MCF7_protirelin': 'protirelin',
#  'MCF7_pibenzimol': 'pibenzimol',
#  'MCF7_chloroxine': 'chloroxine',
#  'MCF7_carprofen': 'carprofen',
#  'MCF7_bambuterol': 'bambuterol',
#  'MCF7_bendamustine': 'bendamustine',
#  'MCF7_LY-2874455': 'LY-2874455',
#  'MCF7_atracurium': 'atracurium',
#  'MCF7_bropirimine': 'bropirimine',
#  'MCF7_amiodarone': 'amiodarone',
#  'MCF7_JTC-801': 'JTC-801',
#  'MCF7_firategrast': 'firategrast',
#  'MCF7_talmapimod': 'talmapimod',
#  'MCF7_ibuprofen': 'ibuprofen',
#  'MCF7_belinostat': 'belinostat',
#  'MCF7_tranilast': 'tranilast',
#  'MCF7_indirubin': 'indirubin',
#  'MCF7_artesunate': 'artesunate',
#  'MCF7_phensuximide': 'phensuximide',
#  'MCF7_lenalidomide': 'lenalidomide',
#  'MCF7_retapamulin': 'retapamulin',
#  'MCF7_LY-2886721': 'LY-2886721',
#  'MCF7_bosutinib': 'bosutinib',
#  'MCF7_mephentermine': 'mephentermine',
#  'MCF7_NVP-BEZ235': 'NVP-BEZ235',
#  'MCF7_folic-acid': 'folic-acid',
#  'MCF7_fdcyd': 'fdcyd',
#  'MCF7_budipine': 'budipine',
#  'MCF7_estriol': 'estriol',
#  'MCF7_ZD-7288': 'ZD-7288',
#  'PC3_nevirapine': 'nevirapine',
#  'PC3_papaverine': 'papaverine',
#  'PC3_rebamipide': 'rebamipide',
#  'PC3_tesaglitazar': 'tesaglitazar',
#  'PC3_cefdinir': 'cefdinir',
#  'PC3_clotrimazole': 'clotrimazole',
#  'PC3_ropinirole': 'ropinirole',
#  'PC3_Z160': 'Z160',
#  'PC3_abiraterone-acetate': 'abiraterone-acetate',
#  'PC3_telbivudine': 'telbivudine',
#  'PC3_fentiazac': 'fentiazac',
#  'PC3_oxymetazoline': 'oxymetazoline',
#  'PC3_atrasentan': 'atrasentan',
#  'PC3_indobufen': 'indobufen',
#  'PC3_ibudilast': 'ibudilast',
#  'PC3_diazepam': 'diazepam',
#  'PC3_butoconazole': 'butoconazole',
#  'PC3_thioctic-acid': 'thioctic-acid',
#  'PC3_zaprinast': 'zaprinast',
#  'PC3_regorafenib': 'regorafenib',
#  'PC3_MK-0893': 'MK-0893',
#  'PC3_sotrastaurin': 'sotrastaurin',
#  'PC3_bevirimat-dimeglumine': 'bevirimat-dimeglumine',
#  'PC3_PRX-08066': 'PRX-08066',
#  'PC3_clarithromycin': 'clarithromycin',
#  'PC3_filgotinib': 'filgotinib',
#  'PC3_protirelin': 'protirelin',
#  'PC3_pibenzimol': 'pibenzimol',
#  'PC3_chloroxine': 'chloroxine',
#  'PC3_carprofen': 'carprofen',
#  'PC3_bambuterol': 'bambuterol',
#  'PC3_bendamustine': 'bendamustine',
#  'PC3_LY-2874455': 'LY-2874455',
#  'PC3_atracurium': 'atracurium',
#  'PC3_bropirimine': 'bropirimine',
#  'PC3_amiodarone': 'amiodarone',
#  'PC3_JTC-801': 'JTC-801',
#  'PC3_firategrast': 'firategrast',
#  'PC3_talmapimod': 'talmapimod',
#  'PC3_ibuprofen': 'ibuprofen',
#  'PC3_belinostat': 'belinostat',
#  'PC3_tranilast': 'tranilast',
#  'PC3_indirubin': 'indirubin',
#  'PC3_artesunate': 'artesunate',
#  'PC3_phensuximide': 'phensuximide',
#  'PC3_lenalidomide': 'lenalidomide',
#  'PC3_retapamulin': 'retapamulin',
#  'PC3_LY-2886721': 'LY-2886721',
#  'PC3_bosutinib': 'bosutinib',
#  'PC3_mephentermine': 'mephentermine',
#  'PC3_NVP-BEZ235': 'NVP-BEZ235',
#  'PC3_folic-acid': 'folic-acid',
#  'PC3_fdcyd': 'fdcyd',
#  'PC3_budipine': 'budipine',
#  'PC3_estriol': 'estriol',
#  'PC3_ZD-7288': 'ZD-7288',
#  'YAPC_nevirapine': 'nevirapine',
#  'YAPC_papaverine': 'papaverine',
#  'YAPC_rebamipide': 'rebamipide',
#  'YAPC_tesaglitazar': 'tesaglitazar',
#  'YAPC_cefdinir': 'cefdinir',
#  'YAPC_clotrimazole': 'clotrimazole',
#  'YAPC_ropinirole': 'ropinirole',
#  'YAPC_Z160': 'Z160',
#  'YAPC_abiraterone-acetate': 'abiraterone-acetate',
#  'YAPC_telbivudine': 'telbivudine',
#  'YAPC_fentiazac': 'fentiazac',
#  'YAPC_oxymetazoline': 'oxymetazoline',
#  'YAPC_atrasentan': 'atrasentan',
#  'YAPC_indobufen': 'indobufen',
#  'YAPC_ibudilast': 'ibudilast',
#  'YAPC_diazepam': 'diazepam',
#  'YAPC_butoconazole': 'butoconazole',
#  'YAPC_thioctic-acid': 'thioctic-acid',
#  'YAPC_zaprinast': 'zaprinast',
#  'YAPC_regorafenib': 'regorafenib',
#  'YAPC_MK-0893': 'MK-0893',
#  'YAPC_sotrastaurin': 'sotrastaurin',
#  'YAPC_bevirimat-dimeglumine': 'bevirimat-dimeglumine',
#  'YAPC_PRX-08066': 'PRX-08066',
#  'YAPC_clarithromycin': 'clarithromycin',
#  'YAPC_filgotinib': 'filgotinib',
#  'YAPC_protirelin': 'protirelin',
#  'YAPC_pibenzimol': 'pibenzimol',
#  'YAPC_chloroxine': 'chloroxine',
#  'YAPC_carprofen': 'carprofen',
#  'YAPC_bambuterol': 'bambuterol',
#  'YAPC_bendamustine': 'bendamustine',
#  'YAPC_LY-2874455': 'LY-2874455',
#  'YAPC_atracurium': 'atracurium',
#  'YAPC_bropirimine': 'bropirimine',
#  'YAPC_amiodarone': 'amiodarone',
#  'YAPC_JTC-801': 'JTC-801',
#  'YAPC_firategrast': 'firategrast',
#  'YAPC_talmapimod': 'talmapimod',
#  'YAPC_ibuprofen': 'ibuprofen',
#  'YAPC_belinostat': 'belinostat',
#  'YAPC_tranilast': 'tranilast',
#  'YAPC_indirubin': 'indirubin',
#  'YAPC_artesunate': 'artesunate',
#  'YAPC_phensuximide': 'phensuximide',
#  'YAPC_lenalidomide': 'lenalidomide',
#  'YAPC_retapamulin': 'retapamulin',
#  'YAPC_LY-2886721': 'LY-2886721',
#  'YAPC_bosutinib': 'bosutinib',
#  'YAPC_mephentermine': 'mephentermine',
#  'YAPC_NVP-BEZ235': 'NVP-BEZ235',
#  'YAPC_folic-acid': 'folic-acid',
#  'YAPC_fdcyd': 'fdcyd',
#  'YAPC_budipine': 'budipine',
#  'YAPC_estriol': 'estriol',
#  'YAPC_ZD-7288': 'ZD-7288',
#  'A375_dimethyl-fumarate': 'dimethyl-fumarate',
#  'A375_fluoxetine': 'fluoxetine',
#  'A375_alvespimycin': 'alvespimycin',
#  'A375_IB-MECA': 'IB-MECA',
#  'A375_lucitanib': 'lucitanib',
#  'A375_ivabradine': 'ivabradine',
#  'A375_methocarbamol': 'methocarbamol',
#  'A375_pemirolast': 'pemirolast',
#  'A375_levobunolol': 'levobunolol',
#  'A375_rimexolone': 'rimexolone',
#  'A375_miltefosine': 'miltefosine',
#  'A375_oxypurinol': 'oxypurinol',
#  'A375_LX-1031': 'LX-1031',
#  'A375_primidone': 'primidone',
#  'A375_AMG-208': 'AMG-208',
#  'A375_etomoxir': 'etomoxir',
#  'A375_disulfiram': 'disulfiram',
#  'A375_VGX-1027': 'VGX-1027',
#  'A375_vanoxerine': 'vanoxerine',
#  'A375_azathioprine': 'azathioprine',
#  'A375_L-NAME': 'L-NAME',
#  'A375_dextromethorphan': 'dextromethorphan',
#  'A375_oxfendazole': 'oxfendazole',
#  'A375_sotalol': 'sotalol',
#  'A375_indinavir': 'indinavir',
#  'A375_tivantinib': 'tivantinib',
#  'A375_levocabastine': 'levocabastine',
#  'A375_metixene': 'metixene',
#  'A375_arofylline': 'arofylline',
#  'A375_suprofen': 'suprofen',
#  'A375_clofarabine': 'clofarabine',
#  'A375_methylnaltrexone': 'methylnaltrexone',
#  'A375_ZK-93423': 'ZK-93423',
#  'A375_tracazolate': 'tracazolate',
#  'A375_linagliptin': 'linagliptin',
#  'A375_lacitol': 'lacitol',
#  'A375_glimepiride': 'glimepiride',
#  'A375_glasdegib': 'glasdegib',
#  'A375_levalbuterol': 'levalbuterol',
#  'A375_PD-123319': 'PD-123319',
#  'A375_adoprazine': 'adoprazine',
#  'A375_ciclesonide': 'ciclesonide',
#  'A375_yohimbine': 'yohimbine',
#  'A375_SR-27897': 'SR-27897',
#  'A375_rotundine': 'rotundine',
#  'A375_dacarbazine': 'dacarbazine',
#  'A375_danegaptide': 'danegaptide',
#  'A375_gimeracil': 'gimeracil',
#  'A375_liranaftate': 'liranaftate',
#  'A375_oprozomib': 'oprozomib',
#  'A375_bindarit': 'bindarit',
#  'A375_omecamtiv-mecarbil': 'omecamtiv-mecarbil',
#  'A375_tofacitinib': 'tofacitinib',
#  'A375_dolutegravir': 'dolutegravir',
#  'A375_tamibarotene': 'tamibarotene',
#  'A375_setiptiline': 'setiptiline',
#  'HA1E_dimethyl-fumarate': 'dimethyl-fumarate',
#  'HA1E_fluoxetine': 'fluoxetine',
#  'HA1E_alvespimycin': 'alvespimycin',
#  'HA1E_IB-MECA': 'IB-MECA',
#  'HA1E_lucitanib': 'lucitanib',
#  'HA1E_ivabradine': 'ivabradine',
#  'HA1E_methocarbamol': 'methocarbamol',
#  'HA1E_pemirolast': 'pemirolast',
#  'HA1E_levobunolol': 'levobunolol',
#  'HA1E_rimexolone': 'rimexolone',
#  'HA1E_miltefosine': 'miltefosine',
#  'HA1E_oxypurinol': 'oxypurinol',
#  'HA1E_LX-1031': 'LX-1031',
#  'HA1E_primidone': 'primidone',
#  'HA1E_AMG-208': 'AMG-208',
#  'HA1E_etomoxir': 'etomoxir',
#  'HA1E_disulfiram': 'disulfiram',
#  'HA1E_VGX-1027': 'VGX-1027',
#  'HA1E_vanoxerine': 'vanoxerine',
#  'HA1E_azathioprine': 'azathioprine',
#  'HA1E_L-NAME': 'L-NAME',
#  'HA1E_dextromethorphan': 'dextromethorphan',
#  'HA1E_oxfendazole': 'oxfendazole',
#  'HA1E_sotalol': 'sotalol',
#  'HA1E_indinavir': 'indinavir',
#  'HA1E_tivantinib': 'tivantinib',
#  'HA1E_levocabastine': 'levocabastine',
#  'HA1E_metixene': 'metixene',
#  'HA1E_arofylline': 'arofylline',
#  'HA1E_suprofen': 'suprofen',
#  'HA1E_clofarabine': 'clofarabine',
#  'HA1E_methylnaltrexone': 'methylnaltrexone',
#  'HA1E_ZK-93423': 'ZK-93423',
#  'HA1E_tracazolate': 'tracazolate',
#  'HA1E_linagliptin': 'linagliptin',
#  'HA1E_lacitol': 'lacitol',
#  'HA1E_glimepiride': 'glimepiride',
#  'HA1E_glasdegib': 'glasdegib',
#  'HA1E_levalbuterol': 'levalbuterol',
#  'HA1E_PD-123319': 'PD-123319',
#  'HA1E_adoprazine': 'adoprazine',
#  'HA1E_ciclesonide': 'ciclesonide',
#  'HA1E_yohimbine': 'yohimbine',
#  'HA1E_SR-27897': 'SR-27897',
#  'HA1E_rotundine': 'rotundine',
#  'HA1E_dacarbazine': 'dacarbazine',
#  'HA1E_danegaptide': 'danegaptide',
#  'HA1E_gimeracil': 'gimeracil',
#  'HA1E_liranaftate': 'liranaftate',
#  'HA1E_oprozomib': 'oprozomib',
#  'HA1E_bindarit': 'bindarit',
#  'HA1E_omecamtiv-mecarbil': 'omecamtiv-mecarbil',
#  'HA1E_tofacitinib': 'tofacitinib',
#  'HA1E_dolutegravir': 'dolutegravir',
#  'HA1E_tamibarotene': 'tamibarotene',
#  'HA1E_setiptiline': 'setiptiline',
#  'HELA_dimethyl-fumarate': 'dimethyl-fumarate',
#  'HELA_fluoxetine': 'fluoxetine',
#  'HELA_alvespimycin': 'alvespimycin',
#  'HELA_IB-MECA': 'IB-MECA',
#  'HELA_lucitanib': 'lucitanib',
#  'HELA_ivabradine': 'ivabradine',
#  'HELA_methocarbamol': 'methocarbamol',
#  'HELA_pemirolast': 'pemirolast',
#  'HELA_levobunolol': 'levobunolol',
#  'HELA_rimexolone': 'rimexolone',
#  'HELA_miltefosine': 'miltefosine',
#  'HELA_oxypurinol': 'oxypurinol',
#  'HELA_LX-1031': 'LX-1031',
#  'HELA_primidone': 'primidone',
#  'HELA_AMG-208': 'AMG-208',
#  'HELA_etomoxir': 'etomoxir',
#  'HELA_disulfiram': 'disulfiram',
#  'HELA_VGX-1027': 'VGX-1027',
#  'HELA_vanoxerine': 'vanoxerine',
#  'HELA_azathioprine': 'azathioprine',
#  'HELA_L-NAME': 'L-NAME',
#  'HELA_dextromethorphan': 'dextromethorphan',
#  'HELA_oxfendazole': 'oxfendazole',
#  'HELA_sotalol': 'sotalol',
#  'HELA_indinavir': 'indinavir',
#  'HELA_tivantinib': 'tivantinib',
#  'HELA_levocabastine': 'levocabastine',
#  'HELA_metixene': 'metixene',
#  'HELA_arofylline': 'arofylline',
#  'HELA_suprofen': 'suprofen',
#  'HELA_clofarabine': 'clofarabine',
#  'HELA_methylnaltrexone': 'methylnaltrexone',
#  'HELA_ZK-93423': 'ZK-93423',
#  'HELA_tracazolate': 'tracazolate',
#  'HELA_linagliptin': 'linagliptin',
#  'HELA_lacitol': 'lacitol',
#  'HELA_glimepiride': 'glimepiride',
#  'HELA_glasdegib': 'glasdegib',
#  'HELA_levalbuterol': 'levalbuterol',
#  'HELA_PD-123319': 'PD-123319',
#  'HELA_adoprazine': 'adoprazine',
#  'HELA_ciclesonide': 'ciclesonide',
#  'HELA_yohimbine': 'yohimbine',
#  'HELA_SR-27897': 'SR-27897',
#  'HELA_rotundine': 'rotundine',
#  'HELA_dacarbazine': 'dacarbazine',
#  'HELA_danegaptide': 'danegaptide',
#  'HELA_gimeracil': 'gimeracil',
#  'HELA_liranaftate': 'liranaftate',
#  'HELA_oprozomib': 'oprozomib',
#  'HELA_bindarit': 'bindarit',
#  'HELA_omecamtiv-mecarbil': 'omecamtiv-mecarbil',
#  'HELA_tofacitinib': 'tofacitinib',
#  'HELA_dolutegravir': 'dolutegravir',
#  'HELA_tamibarotene': 'tamibarotene',
#  'HELA_setiptiline': 'setiptiline',
#  'HT29_dimethyl-fumarate': 'dimethyl-fumarate',
#  'HT29_fluoxetine': 'fluoxetine',
#  'HT29_alvespimycin': 'alvespimycin',
#  'HT29_IB-MECA': 'IB-MECA',
#  'HT29_lucitanib': 'lucitanib',
#  'HT29_ivabradine': 'ivabradine',
#  'HT29_methocarbamol': 'methocarbamol',
#  'HT29_pemirolast': 'pemirolast',
#  'HT29_levobunolol': 'levobunolol',
#  'HT29_rimexolone': 'rimexolone',
#  'HT29_miltefosine': 'miltefosine',
#  'HT29_oxypurinol': 'oxypurinol',
#  'HT29_LX-1031': 'LX-1031',
#  'HT29_primidone': 'primidone',
#  'HT29_AMG-208': 'AMG-208',
#  'HT29_etomoxir': 'etomoxir',
#  'HT29_disulfiram': 'disulfiram',
#  'HT29_VGX-1027': 'VGX-1027',
#  'HT29_vanoxerine': 'vanoxerine',
#  'HT29_azathioprine': 'azathioprine',
#  'HT29_L-NAME': 'L-NAME',
#  'HT29_dextromethorphan': 'dextromethorphan',
#  'HT29_oxfendazole': 'oxfendazole',
#  'HT29_sotalol': 'sotalol',
#  'HT29_indinavir': 'indinavir',
#  'HT29_tivantinib': 'tivantinib',
#  'HT29_levocabastine': 'levocabastine',
#  'HT29_metixene': 'metixene',
#  'HT29_arofylline': 'arofylline',
#  'HT29_suprofen': 'suprofen',
#  'HT29_clofarabine': 'clofarabine',
#  'HT29_methylnaltrexone': 'methylnaltrexone',
#  'HT29_ZK-93423': 'ZK-93423',
#  'HT29_tracazolate': 'tracazolate',
#  ...}

# %%
adata.uns['rank_genes_groups_cov']
# Out:
# {'A375_aminoglutethimide': array(['MAST2', 'CSNK2A2', 'ECH1', 'GATA2', 'SPAG7', 'KAT6A', 'CEBPA',
#         'EPN2', 'SCAND1', 'SUPV3L1', 'UBQLN2', 'SKP1', 'ACOT9', 'RNH1',
#         'USP22', 'MIF', 'PAF1', 'ACD', 'SRC', 'MLEC', 'PAK4', 'MRPS2',
#         'TLR4', 'PCNA', 'CCNB1', 'CDC42', 'PLSCR3', 'PYCR1', 'ZNF586',
#         'CDKN1B', 'TRAPPC6A', 'TEX10', 'HSPA8', 'SPP1', 'AKT1', 'INSIG1',
#         'CIRBP', 'IKZF1', 'DPH2', 'KIAA0100', 'COG7', 'CCDC92', 'CLTB',
#         'HOMER2', 'GRB7', 'MBTPS1', 'HSPA1A', 'ZNF274', 'BNIP3L', 'GAPDH'],
#        dtype=object),
#  'A375_nicardipine': array(['CCND3', 'PLK1', 'EAPP', 'SYNE2', 'ID2', 'IGF1R', 'DMTF1', 'BNIP3',
#         'RAB31', 'SOX4', 'GRB7', 'NCOA3', 'PPIC', 'CCDC92', 'SOX2',
#         'PSMB8', 'PEX11A', 'GNAI1', 'PSMD10', 'CDC25B', 'LRRC16A',
#         'TSC22D3', 'HMGCR', 'SPP1', 'MAP4K4', 'CDKN1A', 'NGRN', 'UBQLN2',
#         'SERPINE1', 'FOSL1', 'MAPKAPK2', 'RAB4A', 'MTFR1', 'SNAP25',
#         'DNAJA3', 'PAF1', 'SPDEF', 'RALGDS', 'SIRT3', 'MIF', 'VPS28',
#         'PSME1', 'HOMER2', 'MALT1', 'HMGCS1', 'MBTPS1', 'INSIG1', 'KIF2C',
#         'PYCR1', 'SNCA'], dtype=object),
#  'A375_VX-765': array(['CANT1', 'HOMER2', 'SLC25A46', 'CSK', 'NPDC1', 'TEX10', 'SCARB1',
#         'ASAH1', 'TESK1', 'APBB2', 'HN1L', 'USP22', 'CDCA4', 'LRRC41',
#         'NR2F6', 'FUT1', 'NOSIP', 'NPEPL1', 'CD58', 'DYNLT3', 'CHIC2',
#         'ECH1', 'MMP2', 'MYBL2', 'NARFL', 'CCND1', 'MRPL12', 'RTN2',
#         'SNCA', 'S100A4', 'CCNB1', 'METRN', 'AKT1', 'CIRBP', 'PCNA',
#         'PAPD7', 'BNIP3L', 'ACD', 'PAF1', 'ZNF586', 'KIF2C', 'SCAND1',
#         'HSPA8', 'CHAC1', 'SUPV3L1', 'COG7', 'VPS28', 'CLTB', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'A375_ramelteon': array(['CANT1', 'NPEPL1', 'HOMER2', 'AURKB', 'NOSIP', 'TESK1', 'APBB2',
#         'CSK', 'APOE', 'ASAH1', 'USP22', 'SCARB1', 'TEX10', 'FUT1',
#         'DYNLT3', 'NPDC1', 'CDCA4', 'HN1L', 'NARFL', 'ECH1', 'LRRC41',
#         'NR2F6', 'CHIC2', 'MYBL2', 'S100A4', 'CCND1', 'MMP2', 'ZNF586',
#         'MRPL12', 'AKT1', 'PAPD7', 'CIRBP', 'SNCA', 'RTN2', 'BNIP3L',
#         'CCNB1', 'METRN', 'ACD', 'SCAND1', 'PAF1', 'PCNA', 'KIF2C',
#         'CHAC1', 'SUPV3L1', 'HSPA8', 'COG7', 'VPS28', 'CLTB', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'A375_dutasteride': array(['MRPS2', 'NOSIP', 'NPEPL1', 'TEX10', 'CD58', 'USP22', 'SCARB1',
#         'NPDC1', 'LRRC41', 'NR2F6', 'CDCA4', 'HN1L', 'ASAH1', 'CANT1',
#         'AURKB', 'SLC25A46', 'CSK', 'DYNLT3', 'KIAA0100', 'CHIC2', 'ECH1',
#         'APBB2', 'PAPD7', 'METRN', 'NARFL', 'MYBL2', 'MMP2', 'AKT1',
#         'RTN2', 'CCNB1', 'S100A4', 'CCND1', 'SNCA', 'MRPL12', 'BNIP3L',
#         'CIRBP', 'ACD', 'HSPA8', 'ZNF586', 'KIF2C', 'PAF1', 'PCNA',
#         'SCAND1', 'CHAC1', 'SUPV3L1', 'COG7', 'VPS28', 'CLTB', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'A375_ostarine': array(['POLR2I', 'CANT1', 'CDCA4', 'CSK', 'ASAH1', 'PSMD4', 'HN1L',
#         'SCARB1', 'APBB2', 'USP22', 'KIAA0100', 'CHIC2', 'SLC25A46',
#         'NPDC1', 'NPEPL1', 'ECH1', 'DYNLT3', 'LRRC41', 'TEX10', 'NR2F6',
#         'CD58', 'RTN2', 'PCNA', 'MYBL2', 'MMP2', 'CCNB1', 'NOSIP', 'CCND1',
#         'S100A4', 'PAPD7', 'MRPL12', 'METRN', 'AKT1', 'CIRBP', 'BNIP3L',
#         'HSPA8', 'NARFL', 'ACD', 'SNCA', 'CHAC1', 'SUPV3L1', 'PAF1',
#         'ZNF586', 'SCAND1', 'KIF2C', 'COG7', 'VPS28', 'CLTB', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'A375_amikacin': array(['CNDP2', 'ARNT2', 'SPR', 'MMP2', 'EIF4EBP1', 'TESK1', 'ATF5',
#         'CSK', 'NPDC1', 'APOE', 'CHIC2', 'APBB2', 'HN1L', 'CHP1', 'PAPD7',
#         'RPN1', 'CDKN1A', 'CCNB1', 'MRPL12', 'TEX10', 'S100A4', 'ECH1',
#         'CDCA4', 'CD58', 'SNCA', 'METRN', 'ZNF586', 'POLR2I', 'FBXO21',
#         'CCND1', 'PCNA', 'NR2F6', 'LRRC41', 'KIAA0100', 'USP22', 'MYBL2',
#         'BNIP3L', 'HSPA8', 'PAF1', 'ACD', 'KIF2C', 'CHAC1', 'CIRBP',
#         'CLTB', 'SUPV3L1', 'VPS28', 'SCAND1', 'ZNF274', 'COG7', 'GAPDH'],
#        dtype=object),
#  'A375_ASC-J9': array(['TESK1', 'CANT1', 'APOE', 'NPEPL1', 'CHP1', 'NOSIP', 'DNAJB6',
#         'PCNA', 'APBB2', 'TEX10', 'CAPN1', 'HN1L', 'POLR2I', 'RTN2',
#         'LRRC41', 'CSK', 'SCARB1', 'NPDC1', 'BNIP3L', 'CD58', 'PAPD7',
#         'CDCA4', 'CHIC2', 'KIAA0100', 'MMP2', 'USP22', 'CHAC1', 'ECH1',
#         'NR2F6', 'CCNB1', 'S100A4', 'CCND1', 'AKT1', 'MRPL12', 'MYBL2',
#         'SNCA', 'HSPA8', 'SUPV3L1', 'ACD', 'METRN', 'PAF1', 'CIRBP',
#         'ZNF586', 'COG7', 'SCAND1', 'KIF2C', 'VPS28', 'ZNF274', 'CLTB',
#         'GAPDH'], dtype=object),
#  'A375_ellagic-acid': array(['CLIC4', 'HOMER2', 'RUVBL1', 'PAK4', 'POLR2I', 'NR2F6', 'SPDEF',
#         'APOE', 'APBB2', 'PSMD4', 'ATF5', 'MRPS2', 'CIRBP', 'S100A4',
#         'CHIC2', 'METRN', 'HN1L', 'EIF4EBP1', 'RAP1GAP', 'CEBPA',
#         'KIAA0100', 'TEX10', 'CSK', 'ECH1', 'ACD', 'SPR', 'SMARCD2',
#         'CDCA4', 'AKT1', 'PCNA', 'PAF1', 'VPS28', 'CCNB1', 'SUPV3L1',
#         'MYBL2', 'SCARB1', 'FZD7', 'SNCA', 'MRPL12', 'CCND1', 'CHAC1',
#         'HSPA8', 'SCAND1', 'KIF2C', 'ZNF586', 'BNIP3L', 'COG7', 'CLTB',
#         'ZNF274', 'GAPDH'], dtype=object),
#  'HA1E_aminoglutethimide': array(['MAST2', 'CSNK2A2', 'ECH1', 'GATA2', 'SPAG7', 'KAT6A', 'CEBPA',
#         'EPN2', 'SCAND1', 'SUPV3L1', 'UBQLN2', 'SKP1', 'ACOT9', 'RNH1',
#         'USP22', 'MIF', 'PAF1', 'ACD', 'SRC', 'MLEC', 'PAK4', 'MRPS2',
#         'TLR4', 'PCNA', 'CCNB1', 'CDC42', 'PLSCR3', 'PYCR1', 'ZNF586',
#         'CDKN1B', 'TRAPPC6A', 'TEX10', 'HSPA8', 'SPP1', 'AKT1', 'INSIG1',
#         'CIRBP', 'IKZF1', 'DPH2', 'KIAA0100', 'COG7', 'CCDC92', 'CLTB',
#         'HOMER2', 'GRB7', 'MBTPS1', 'HSPA1A', 'ZNF274', 'BNIP3L', 'GAPDH'],
#        dtype=object),
#  'HA1E_nicardipine': array(['CCND3', 'PLK1', 'EAPP', 'SYNE2', 'ID2', 'IGF1R', 'DMTF1', 'BNIP3',
#         'RAB31', 'SOX4', 'GRB7', 'NCOA3', 'PPIC', 'CCDC92', 'SOX2',
#         'PSMB8', 'PEX11A', 'GNAI1', 'PSMD10', 'CDC25B', 'LRRC16A',
#         'TSC22D3', 'HMGCR', 'SPP1', 'MAP4K4', 'CDKN1A', 'NGRN', 'UBQLN2',
#         'SERPINE1', 'FOSL1', 'MAPKAPK2', 'RAB4A', 'MTFR1', 'SNAP25',
#         'DNAJA3', 'PAF1', 'SPDEF', 'RALGDS', 'SIRT3', 'MIF', 'VPS28',
#         'PSME1', 'HOMER2', 'MALT1', 'HMGCS1', 'MBTPS1', 'INSIG1', 'KIF2C',
#         'PYCR1', 'SNCA'], dtype=object),
#  'HA1E_VX-765': array(['CANT1', 'HOMER2', 'SLC25A46', 'CSK', 'NPDC1', 'TEX10', 'SCARB1',
#         'ASAH1', 'TESK1', 'APBB2', 'HN1L', 'USP22', 'CDCA4', 'LRRC41',
#         'NR2F6', 'FUT1', 'NOSIP', 'NPEPL1', 'CD58', 'DYNLT3', 'CHIC2',
#         'ECH1', 'MMP2', 'MYBL2', 'NARFL', 'CCND1', 'MRPL12', 'RTN2',
#         'SNCA', 'S100A4', 'CCNB1', 'METRN', 'AKT1', 'CIRBP', 'PCNA',
#         'PAPD7', 'BNIP3L', 'ACD', 'PAF1', 'ZNF586', 'KIF2C', 'SCAND1',
#         'HSPA8', 'CHAC1', 'SUPV3L1', 'COG7', 'VPS28', 'CLTB', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'HA1E_ramelteon': array(['CANT1', 'NPEPL1', 'HOMER2', 'AURKB', 'NOSIP', 'TESK1', 'APBB2',
#         'CSK', 'APOE', 'ASAH1', 'USP22', 'SCARB1', 'TEX10', 'FUT1',
#         'DYNLT3', 'NPDC1', 'CDCA4', 'HN1L', 'NARFL', 'ECH1', 'LRRC41',
#         'NR2F6', 'CHIC2', 'MYBL2', 'S100A4', 'CCND1', 'MMP2', 'ZNF586',
#         'MRPL12', 'AKT1', 'PAPD7', 'CIRBP', 'SNCA', 'RTN2', 'BNIP3L',
#         'CCNB1', 'METRN', 'ACD', 'SCAND1', 'PAF1', 'PCNA', 'KIF2C',
#         'CHAC1', 'SUPV3L1', 'HSPA8', 'COG7', 'VPS28', 'CLTB', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'HA1E_dutasteride': array(['MRPS2', 'NOSIP', 'NPEPL1', 'TEX10', 'CD58', 'USP22', 'SCARB1',
#         'NPDC1', 'LRRC41', 'NR2F6', 'CDCA4', 'HN1L', 'ASAH1', 'CANT1',
#         'AURKB', 'SLC25A46', 'CSK', 'DYNLT3', 'KIAA0100', 'CHIC2', 'ECH1',
#         'APBB2', 'PAPD7', 'METRN', 'NARFL', 'MYBL2', 'MMP2', 'AKT1',
#         'RTN2', 'CCNB1', 'S100A4', 'CCND1', 'SNCA', 'MRPL12', 'BNIP3L',
#         'CIRBP', 'ACD', 'HSPA8', 'ZNF586', 'KIF2C', 'PAF1', 'PCNA',
#         'SCAND1', 'CHAC1', 'SUPV3L1', 'COG7', 'VPS28', 'CLTB', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'HA1E_ostarine': array(['POLR2I', 'CANT1', 'CDCA4', 'CSK', 'ASAH1', 'PSMD4', 'HN1L',
#         'SCARB1', 'APBB2', 'USP22', 'KIAA0100', 'CHIC2', 'SLC25A46',
#         'NPDC1', 'NPEPL1', 'ECH1', 'DYNLT3', 'LRRC41', 'TEX10', 'NR2F6',
#         'CD58', 'RTN2', 'PCNA', 'MYBL2', 'MMP2', 'CCNB1', 'NOSIP', 'CCND1',
#         'S100A4', 'PAPD7', 'MRPL12', 'METRN', 'AKT1', 'CIRBP', 'BNIP3L',
#         'HSPA8', 'NARFL', 'ACD', 'SNCA', 'CHAC1', 'SUPV3L1', 'PAF1',
#         'ZNF586', 'SCAND1', 'KIF2C', 'COG7', 'VPS28', 'CLTB', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'HA1E_amikacin': array(['CNDP2', 'ARNT2', 'SPR', 'MMP2', 'EIF4EBP1', 'TESK1', 'ATF5',
#         'CSK', 'NPDC1', 'APOE', 'CHIC2', 'APBB2', 'HN1L', 'CHP1', 'PAPD7',
#         'RPN1', 'CDKN1A', 'CCNB1', 'MRPL12', 'TEX10', 'S100A4', 'ECH1',
#         'CDCA4', 'CD58', 'SNCA', 'METRN', 'ZNF586', 'POLR2I', 'FBXO21',
#         'CCND1', 'PCNA', 'NR2F6', 'LRRC41', 'KIAA0100', 'USP22', 'MYBL2',
#         'BNIP3L', 'HSPA8', 'PAF1', 'ACD', 'KIF2C', 'CHAC1', 'CIRBP',
#         'CLTB', 'SUPV3L1', 'VPS28', 'SCAND1', 'ZNF274', 'COG7', 'GAPDH'],
#        dtype=object),
#  'HA1E_ASC-J9': array(['TESK1', 'CANT1', 'APOE', 'NPEPL1', 'CHP1', 'NOSIP', 'DNAJB6',
#         'PCNA', 'APBB2', 'TEX10', 'CAPN1', 'HN1L', 'POLR2I', 'RTN2',
#         'LRRC41', 'CSK', 'SCARB1', 'NPDC1', 'BNIP3L', 'CD58', 'PAPD7',
#         'CDCA4', 'CHIC2', 'KIAA0100', 'MMP2', 'USP22', 'CHAC1', 'ECH1',
#         'NR2F6', 'CCNB1', 'S100A4', 'CCND1', 'AKT1', 'MRPL12', 'MYBL2',
#         'SNCA', 'HSPA8', 'SUPV3L1', 'ACD', 'METRN', 'PAF1', 'CIRBP',
#         'ZNF586', 'COG7', 'SCAND1', 'KIF2C', 'VPS28', 'ZNF274', 'CLTB',
#         'GAPDH'], dtype=object),
#  'HA1E_ellagic-acid': array(['CLIC4', 'HOMER2', 'RUVBL1', 'PAK4', 'POLR2I', 'NR2F6', 'SPDEF',
#         'APOE', 'APBB2', 'PSMD4', 'ATF5', 'MRPS2', 'CIRBP', 'S100A4',
#         'CHIC2', 'METRN', 'HN1L', 'EIF4EBP1', 'RAP1GAP', 'CEBPA',
#         'KIAA0100', 'TEX10', 'CSK', 'ECH1', 'ACD', 'SPR', 'SMARCD2',
#         'CDCA4', 'AKT1', 'PCNA', 'PAF1', 'VPS28', 'CCNB1', 'SUPV3L1',
#         'MYBL2', 'SCARB1', 'FZD7', 'SNCA', 'MRPL12', 'CCND1', 'CHAC1',
#         'HSPA8', 'SCAND1', 'KIF2C', 'ZNF586', 'BNIP3L', 'COG7', 'CLTB',
#         'ZNF274', 'GAPDH'], dtype=object),
#  'HELA_aminoglutethimide': array(['MAST2', 'CSNK2A2', 'ECH1', 'GATA2', 'SPAG7', 'KAT6A', 'CEBPA',
#         'EPN2', 'SCAND1', 'SUPV3L1', 'UBQLN2', 'SKP1', 'ACOT9', 'RNH1',
#         'USP22', 'MIF', 'PAF1', 'ACD', 'SRC', 'MLEC', 'PAK4', 'MRPS2',
#         'TLR4', 'PCNA', 'CCNB1', 'CDC42', 'PLSCR3', 'PYCR1', 'ZNF586',
#         'CDKN1B', 'TRAPPC6A', 'TEX10', 'HSPA8', 'SPP1', 'AKT1', 'INSIG1',
#         'CIRBP', 'IKZF1', 'DPH2', 'KIAA0100', 'COG7', 'CCDC92', 'CLTB',
#         'HOMER2', 'GRB7', 'MBTPS1', 'HSPA1A', 'ZNF274', 'BNIP3L', 'GAPDH'],
#        dtype=object),
#  'HELA_nicardipine': array(['CCND3', 'PLK1', 'EAPP', 'SYNE2', 'ID2', 'IGF1R', 'DMTF1', 'BNIP3',
#         'RAB31', 'SOX4', 'GRB7', 'NCOA3', 'PPIC', 'CCDC92', 'SOX2',
#         'PSMB8', 'PEX11A', 'GNAI1', 'PSMD10', 'CDC25B', 'LRRC16A',
#         'TSC22D3', 'HMGCR', 'SPP1', 'MAP4K4', 'CDKN1A', 'NGRN', 'UBQLN2',
#         'SERPINE1', 'FOSL1', 'MAPKAPK2', 'RAB4A', 'MTFR1', 'SNAP25',
#         'DNAJA3', 'PAF1', 'SPDEF', 'RALGDS', 'SIRT3', 'MIF', 'VPS28',
#         'PSME1', 'HOMER2', 'MALT1', 'HMGCS1', 'MBTPS1', 'INSIG1', 'KIF2C',
#         'PYCR1', 'SNCA'], dtype=object),
#  'HELA_VX-765': array(['CANT1', 'HOMER2', 'SLC25A46', 'CSK', 'NPDC1', 'TEX10', 'SCARB1',
#         'ASAH1', 'TESK1', 'APBB2', 'HN1L', 'USP22', 'CDCA4', 'LRRC41',
#         'NR2F6', 'FUT1', 'NOSIP', 'NPEPL1', 'CD58', 'DYNLT3', 'CHIC2',
#         'ECH1', 'MMP2', 'MYBL2', 'NARFL', 'CCND1', 'MRPL12', 'RTN2',
#         'SNCA', 'S100A4', 'CCNB1', 'METRN', 'AKT1', 'CIRBP', 'PCNA',
#         'PAPD7', 'BNIP3L', 'ACD', 'PAF1', 'ZNF586', 'KIF2C', 'SCAND1',
#         'HSPA8', 'CHAC1', 'SUPV3L1', 'COG7', 'VPS28', 'CLTB', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'HELA_ramelteon': array(['CANT1', 'NPEPL1', 'HOMER2', 'AURKB', 'NOSIP', 'TESK1', 'APBB2',
#         'CSK', 'APOE', 'ASAH1', 'USP22', 'SCARB1', 'TEX10', 'FUT1',
#         'DYNLT3', 'NPDC1', 'CDCA4', 'HN1L', 'NARFL', 'ECH1', 'LRRC41',
#         'NR2F6', 'CHIC2', 'MYBL2', 'S100A4', 'CCND1', 'MMP2', 'ZNF586',
#         'MRPL12', 'AKT1', 'PAPD7', 'CIRBP', 'SNCA', 'RTN2', 'BNIP3L',
#         'CCNB1', 'METRN', 'ACD', 'SCAND1', 'PAF1', 'PCNA', 'KIF2C',
#         'CHAC1', 'SUPV3L1', 'HSPA8', 'COG7', 'VPS28', 'CLTB', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'HELA_dutasteride': array(['MRPS2', 'NOSIP', 'NPEPL1', 'TEX10', 'CD58', 'USP22', 'SCARB1',
#         'NPDC1', 'LRRC41', 'NR2F6', 'CDCA4', 'HN1L', 'ASAH1', 'CANT1',
#         'AURKB', 'SLC25A46', 'CSK', 'DYNLT3', 'KIAA0100', 'CHIC2', 'ECH1',
#         'APBB2', 'PAPD7', 'METRN', 'NARFL', 'MYBL2', 'MMP2', 'AKT1',
#         'RTN2', 'CCNB1', 'S100A4', 'CCND1', 'SNCA', 'MRPL12', 'BNIP3L',
#         'CIRBP', 'ACD', 'HSPA8', 'ZNF586', 'KIF2C', 'PAF1', 'PCNA',
#         'SCAND1', 'CHAC1', 'SUPV3L1', 'COG7', 'VPS28', 'CLTB', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'HELA_ostarine': array(['POLR2I', 'CANT1', 'CDCA4', 'CSK', 'ASAH1', 'PSMD4', 'HN1L',
#         'SCARB1', 'APBB2', 'USP22', 'KIAA0100', 'CHIC2', 'SLC25A46',
#         'NPDC1', 'NPEPL1', 'ECH1', 'DYNLT3', 'LRRC41', 'TEX10', 'NR2F6',
#         'CD58', 'RTN2', 'PCNA', 'MYBL2', 'MMP2', 'CCNB1', 'NOSIP', 'CCND1',
#         'S100A4', 'PAPD7', 'MRPL12', 'METRN', 'AKT1', 'CIRBP', 'BNIP3L',
#         'HSPA8', 'NARFL', 'ACD', 'SNCA', 'CHAC1', 'SUPV3L1', 'PAF1',
#         'ZNF586', 'SCAND1', 'KIF2C', 'COG7', 'VPS28', 'CLTB', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'HELA_amikacin': array(['CNDP2', 'ARNT2', 'SPR', 'MMP2', 'EIF4EBP1', 'TESK1', 'ATF5',
#         'CSK', 'NPDC1', 'APOE', 'CHIC2', 'APBB2', 'HN1L', 'CHP1', 'PAPD7',
#         'RPN1', 'CDKN1A', 'CCNB1', 'MRPL12', 'TEX10', 'S100A4', 'ECH1',
#         'CDCA4', 'CD58', 'SNCA', 'METRN', 'ZNF586', 'POLR2I', 'FBXO21',
#         'CCND1', 'PCNA', 'NR2F6', 'LRRC41', 'KIAA0100', 'USP22', 'MYBL2',
#         'BNIP3L', 'HSPA8', 'PAF1', 'ACD', 'KIF2C', 'CHAC1', 'CIRBP',
#         'CLTB', 'SUPV3L1', 'VPS28', 'SCAND1', 'ZNF274', 'COG7', 'GAPDH'],
#        dtype=object),
#  'HELA_ASC-J9': array(['TESK1', 'CANT1', 'APOE', 'NPEPL1', 'CHP1', 'NOSIP', 'DNAJB6',
#         'PCNA', 'APBB2', 'TEX10', 'CAPN1', 'HN1L', 'POLR2I', 'RTN2',
#         'LRRC41', 'CSK', 'SCARB1', 'NPDC1', 'BNIP3L', 'CD58', 'PAPD7',
#         'CDCA4', 'CHIC2', 'KIAA0100', 'MMP2', 'USP22', 'CHAC1', 'ECH1',
#         'NR2F6', 'CCNB1', 'S100A4', 'CCND1', 'AKT1', 'MRPL12', 'MYBL2',
#         'SNCA', 'HSPA8', 'SUPV3L1', 'ACD', 'METRN', 'PAF1', 'CIRBP',
#         'ZNF586', 'COG7', 'SCAND1', 'KIF2C', 'VPS28', 'ZNF274', 'CLTB',
#         'GAPDH'], dtype=object),
#  'HELA_ellagic-acid': array(['CLIC4', 'HOMER2', 'RUVBL1', 'PAK4', 'POLR2I', 'NR2F6', 'SPDEF',
#         'APOE', 'APBB2', 'PSMD4', 'ATF5', 'MRPS2', 'CIRBP', 'S100A4',
#         'CHIC2', 'METRN', 'HN1L', 'EIF4EBP1', 'RAP1GAP', 'CEBPA',
#         'KIAA0100', 'TEX10', 'CSK', 'ECH1', 'ACD', 'SPR', 'SMARCD2',
#         'CDCA4', 'AKT1', 'PCNA', 'PAF1', 'VPS28', 'CCNB1', 'SUPV3L1',
#         'MYBL2', 'SCARB1', 'FZD7', 'SNCA', 'MRPL12', 'CCND1', 'CHAC1',
#         'HSPA8', 'SCAND1', 'KIF2C', 'ZNF586', 'BNIP3L', 'COG7', 'CLTB',
#         'ZNF274', 'GAPDH'], dtype=object),
#  'HT29_aminoglutethimide': array(['MAST2', 'CSNK2A2', 'ECH1', 'GATA2', 'SPAG7', 'KAT6A', 'CEBPA',
#         'EPN2', 'SCAND1', 'SUPV3L1', 'UBQLN2', 'SKP1', 'ACOT9', 'RNH1',
#         'USP22', 'MIF', 'PAF1', 'ACD', 'SRC', 'MLEC', 'PAK4', 'MRPS2',
#         'TLR4', 'PCNA', 'CCNB1', 'CDC42', 'PLSCR3', 'PYCR1', 'ZNF586',
#         'CDKN1B', 'TRAPPC6A', 'TEX10', 'HSPA8', 'SPP1', 'AKT1', 'INSIG1',
#         'CIRBP', 'IKZF1', 'DPH2', 'KIAA0100', 'COG7', 'CCDC92', 'CLTB',
#         'HOMER2', 'GRB7', 'MBTPS1', 'HSPA1A', 'ZNF274', 'BNIP3L', 'GAPDH'],
#        dtype=object),
#  'HT29_nicardipine': array(['CCND3', 'PLK1', 'EAPP', 'SYNE2', 'ID2', 'IGF1R', 'DMTF1', 'BNIP3',
#         'RAB31', 'SOX4', 'GRB7', 'NCOA3', 'PPIC', 'CCDC92', 'SOX2',
#         'PSMB8', 'PEX11A', 'GNAI1', 'PSMD10', 'CDC25B', 'LRRC16A',
#         'TSC22D3', 'HMGCR', 'SPP1', 'MAP4K4', 'CDKN1A', 'NGRN', 'UBQLN2',
#         'SERPINE1', 'FOSL1', 'MAPKAPK2', 'RAB4A', 'MTFR1', 'SNAP25',
#         'DNAJA3', 'PAF1', 'SPDEF', 'RALGDS', 'SIRT3', 'MIF', 'VPS28',
#         'PSME1', 'HOMER2', 'MALT1', 'HMGCS1', 'MBTPS1', 'INSIG1', 'KIF2C',
#         'PYCR1', 'SNCA'], dtype=object),
#  'HT29_VX-765': array(['CANT1', 'HOMER2', 'SLC25A46', 'CSK', 'NPDC1', 'TEX10', 'SCARB1',
#         'ASAH1', 'TESK1', 'APBB2', 'HN1L', 'USP22', 'CDCA4', 'LRRC41',
#         'NR2F6', 'FUT1', 'NOSIP', 'NPEPL1', 'CD58', 'DYNLT3', 'CHIC2',
#         'ECH1', 'MMP2', 'MYBL2', 'NARFL', 'CCND1', 'MRPL12', 'RTN2',
#         'SNCA', 'S100A4', 'CCNB1', 'METRN', 'AKT1', 'CIRBP', 'PCNA',
#         'PAPD7', 'BNIP3L', 'ACD', 'PAF1', 'ZNF586', 'KIF2C', 'SCAND1',
#         'HSPA8', 'CHAC1', 'SUPV3L1', 'COG7', 'VPS28', 'CLTB', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'HT29_ramelteon': array(['CANT1', 'NPEPL1', 'HOMER2', 'AURKB', 'NOSIP', 'TESK1', 'APBB2',
#         'CSK', 'APOE', 'ASAH1', 'USP22', 'SCARB1', 'TEX10', 'FUT1',
#         'DYNLT3', 'NPDC1', 'CDCA4', 'HN1L', 'NARFL', 'ECH1', 'LRRC41',
#         'NR2F6', 'CHIC2', 'MYBL2', 'S100A4', 'CCND1', 'MMP2', 'ZNF586',
#         'MRPL12', 'AKT1', 'PAPD7', 'CIRBP', 'SNCA', 'RTN2', 'BNIP3L',
#         'CCNB1', 'METRN', 'ACD', 'SCAND1', 'PAF1', 'PCNA', 'KIF2C',
#         'CHAC1', 'SUPV3L1', 'HSPA8', 'COG7', 'VPS28', 'CLTB', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'HT29_dutasteride': array(['MRPS2', 'NOSIP', 'NPEPL1', 'TEX10', 'CD58', 'USP22', 'SCARB1',
#         'NPDC1', 'LRRC41', 'NR2F6', 'CDCA4', 'HN1L', 'ASAH1', 'CANT1',
#         'AURKB', 'SLC25A46', 'CSK', 'DYNLT3', 'KIAA0100', 'CHIC2', 'ECH1',
#         'APBB2', 'PAPD7', 'METRN', 'NARFL', 'MYBL2', 'MMP2', 'AKT1',
#         'RTN2', 'CCNB1', 'S100A4', 'CCND1', 'SNCA', 'MRPL12', 'BNIP3L',
#         'CIRBP', 'ACD', 'HSPA8', 'ZNF586', 'KIF2C', 'PAF1', 'PCNA',
#         'SCAND1', 'CHAC1', 'SUPV3L1', 'COG7', 'VPS28', 'CLTB', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'HT29_ostarine': array(['POLR2I', 'CANT1', 'CDCA4', 'CSK', 'ASAH1', 'PSMD4', 'HN1L',
#         'SCARB1', 'APBB2', 'USP22', 'KIAA0100', 'CHIC2', 'SLC25A46',
#         'NPDC1', 'NPEPL1', 'ECH1', 'DYNLT3', 'LRRC41', 'TEX10', 'NR2F6',
#         'CD58', 'RTN2', 'PCNA', 'MYBL2', 'MMP2', 'CCNB1', 'NOSIP', 'CCND1',
#         'S100A4', 'PAPD7', 'MRPL12', 'METRN', 'AKT1', 'CIRBP', 'BNIP3L',
#         'HSPA8', 'NARFL', 'ACD', 'SNCA', 'CHAC1', 'SUPV3L1', 'PAF1',
#         'ZNF586', 'SCAND1', 'KIF2C', 'COG7', 'VPS28', 'CLTB', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'HT29_amikacin': array(['CNDP2', 'ARNT2', 'SPR', 'MMP2', 'EIF4EBP1', 'TESK1', 'ATF5',
#         'CSK', 'NPDC1', 'APOE', 'CHIC2', 'APBB2', 'HN1L', 'CHP1', 'PAPD7',
#         'RPN1', 'CDKN1A', 'CCNB1', 'MRPL12', 'TEX10', 'S100A4', 'ECH1',
#         'CDCA4', 'CD58', 'SNCA', 'METRN', 'ZNF586', 'POLR2I', 'FBXO21',
#         'CCND1', 'PCNA', 'NR2F6', 'LRRC41', 'KIAA0100', 'USP22', 'MYBL2',
#         'BNIP3L', 'HSPA8', 'PAF1', 'ACD', 'KIF2C', 'CHAC1', 'CIRBP',
#         'CLTB', 'SUPV3L1', 'VPS28', 'SCAND1', 'ZNF274', 'COG7', 'GAPDH'],
#        dtype=object),
#  'HT29_ASC-J9': array(['TESK1', 'CANT1', 'APOE', 'NPEPL1', 'CHP1', 'NOSIP', 'DNAJB6',
#         'PCNA', 'APBB2', 'TEX10', 'CAPN1', 'HN1L', 'POLR2I', 'RTN2',
#         'LRRC41', 'CSK', 'SCARB1', 'NPDC1', 'BNIP3L', 'CD58', 'PAPD7',
#         'CDCA4', 'CHIC2', 'KIAA0100', 'MMP2', 'USP22', 'CHAC1', 'ECH1',
#         'NR2F6', 'CCNB1', 'S100A4', 'CCND1', 'AKT1', 'MRPL12', 'MYBL2',
#         'SNCA', 'HSPA8', 'SUPV3L1', 'ACD', 'METRN', 'PAF1', 'CIRBP',
#         'ZNF586', 'COG7', 'SCAND1', 'KIF2C', 'VPS28', 'ZNF274', 'CLTB',
#         'GAPDH'], dtype=object),
#  'HT29_ellagic-acid': array(['CLIC4', 'HOMER2', 'RUVBL1', 'PAK4', 'POLR2I', 'NR2F6', 'SPDEF',
#         'APOE', 'APBB2', 'PSMD4', 'ATF5', 'MRPS2', 'CIRBP', 'S100A4',
#         'CHIC2', 'METRN', 'HN1L', 'EIF4EBP1', 'RAP1GAP', 'CEBPA',
#         'KIAA0100', 'TEX10', 'CSK', 'ECH1', 'ACD', 'SPR', 'SMARCD2',
#         'CDCA4', 'AKT1', 'PCNA', 'PAF1', 'VPS28', 'CCNB1', 'SUPV3L1',
#         'MYBL2', 'SCARB1', 'FZD7', 'SNCA', 'MRPL12', 'CCND1', 'CHAC1',
#         'HSPA8', 'SCAND1', 'KIF2C', 'ZNF586', 'BNIP3L', 'COG7', 'CLTB',
#         'ZNF274', 'GAPDH'], dtype=object),
#  'MCF7_aminoglutethimide': array(['MAST2', 'CSNK2A2', 'ECH1', 'GATA2', 'SPAG7', 'KAT6A', 'CEBPA',
#         'EPN2', 'SCAND1', 'SUPV3L1', 'UBQLN2', 'SKP1', 'ACOT9', 'RNH1',
#         'USP22', 'MIF', 'PAF1', 'ACD', 'SRC', 'MLEC', 'PAK4', 'MRPS2',
#         'TLR4', 'PCNA', 'CCNB1', 'CDC42', 'PLSCR3', 'PYCR1', 'ZNF586',
#         'CDKN1B', 'TRAPPC6A', 'TEX10', 'HSPA8', 'SPP1', 'AKT1', 'INSIG1',
#         'CIRBP', 'IKZF1', 'DPH2', 'KIAA0100', 'COG7', 'CCDC92', 'CLTB',
#         'HOMER2', 'GRB7', 'MBTPS1', 'HSPA1A', 'ZNF274', 'BNIP3L', 'GAPDH'],
#        dtype=object),
#  'MCF7_nicardipine': array(['CCND3', 'PLK1', 'EAPP', 'SYNE2', 'ID2', 'IGF1R', 'DMTF1', 'BNIP3',
#         'RAB31', 'SOX4', 'GRB7', 'NCOA3', 'PPIC', 'CCDC92', 'SOX2',
#         'PSMB8', 'PEX11A', 'GNAI1', 'PSMD10', 'CDC25B', 'LRRC16A',
#         'TSC22D3', 'HMGCR', 'SPP1', 'MAP4K4', 'CDKN1A', 'NGRN', 'UBQLN2',
#         'SERPINE1', 'FOSL1', 'MAPKAPK2', 'RAB4A', 'MTFR1', 'SNAP25',
#         'DNAJA3', 'PAF1', 'SPDEF', 'RALGDS', 'SIRT3', 'MIF', 'VPS28',
#         'PSME1', 'HOMER2', 'MALT1', 'HMGCS1', 'MBTPS1', 'INSIG1', 'KIF2C',
#         'PYCR1', 'SNCA'], dtype=object),
#  'MCF7_VX-765': array(['CANT1', 'HOMER2', 'SLC25A46', 'CSK', 'NPDC1', 'TEX10', 'SCARB1',
#         'ASAH1', 'TESK1', 'APBB2', 'HN1L', 'USP22', 'CDCA4', 'LRRC41',
#         'NR2F6', 'FUT1', 'NOSIP', 'NPEPL1', 'CD58', 'DYNLT3', 'CHIC2',
#         'ECH1', 'MMP2', 'MYBL2', 'NARFL', 'CCND1', 'MRPL12', 'RTN2',
#         'SNCA', 'S100A4', 'CCNB1', 'METRN', 'AKT1', 'CIRBP', 'PCNA',
#         'PAPD7', 'BNIP3L', 'ACD', 'PAF1', 'ZNF586', 'KIF2C', 'SCAND1',
#         'HSPA8', 'CHAC1', 'SUPV3L1', 'COG7', 'VPS28', 'CLTB', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'MCF7_ramelteon': array(['CANT1', 'NPEPL1', 'HOMER2', 'AURKB', 'NOSIP', 'TESK1', 'APBB2',
#         'CSK', 'APOE', 'ASAH1', 'USP22', 'SCARB1', 'TEX10', 'FUT1',
#         'DYNLT3', 'NPDC1', 'CDCA4', 'HN1L', 'NARFL', 'ECH1', 'LRRC41',
#         'NR2F6', 'CHIC2', 'MYBL2', 'S100A4', 'CCND1', 'MMP2', 'ZNF586',
#         'MRPL12', 'AKT1', 'PAPD7', 'CIRBP', 'SNCA', 'RTN2', 'BNIP3L',
#         'CCNB1', 'METRN', 'ACD', 'SCAND1', 'PAF1', 'PCNA', 'KIF2C',
#         'CHAC1', 'SUPV3L1', 'HSPA8', 'COG7', 'VPS28', 'CLTB', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'MCF7_dutasteride': array(['MRPS2', 'NOSIP', 'NPEPL1', 'TEX10', 'CD58', 'USP22', 'SCARB1',
#         'NPDC1', 'LRRC41', 'NR2F6', 'CDCA4', 'HN1L', 'ASAH1', 'CANT1',
#         'AURKB', 'SLC25A46', 'CSK', 'DYNLT3', 'KIAA0100', 'CHIC2', 'ECH1',
#         'APBB2', 'PAPD7', 'METRN', 'NARFL', 'MYBL2', 'MMP2', 'AKT1',
#         'RTN2', 'CCNB1', 'S100A4', 'CCND1', 'SNCA', 'MRPL12', 'BNIP3L',
#         'CIRBP', 'ACD', 'HSPA8', 'ZNF586', 'KIF2C', 'PAF1', 'PCNA',
#         'SCAND1', 'CHAC1', 'SUPV3L1', 'COG7', 'VPS28', 'CLTB', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'MCF7_ostarine': array(['POLR2I', 'CANT1', 'CDCA4', 'CSK', 'ASAH1', 'PSMD4', 'HN1L',
#         'SCARB1', 'APBB2', 'USP22', 'KIAA0100', 'CHIC2', 'SLC25A46',
#         'NPDC1', 'NPEPL1', 'ECH1', 'DYNLT3', 'LRRC41', 'TEX10', 'NR2F6',
#         'CD58', 'RTN2', 'PCNA', 'MYBL2', 'MMP2', 'CCNB1', 'NOSIP', 'CCND1',
#         'S100A4', 'PAPD7', 'MRPL12', 'METRN', 'AKT1', 'CIRBP', 'BNIP3L',
#         'HSPA8', 'NARFL', 'ACD', 'SNCA', 'CHAC1', 'SUPV3L1', 'PAF1',
#         'ZNF586', 'SCAND1', 'KIF2C', 'COG7', 'VPS28', 'CLTB', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'MCF7_amikacin': array(['CNDP2', 'ARNT2', 'SPR', 'MMP2', 'EIF4EBP1', 'TESK1', 'ATF5',
#         'CSK', 'NPDC1', 'APOE', 'CHIC2', 'APBB2', 'HN1L', 'CHP1', 'PAPD7',
#         'RPN1', 'CDKN1A', 'CCNB1', 'MRPL12', 'TEX10', 'S100A4', 'ECH1',
#         'CDCA4', 'CD58', 'SNCA', 'METRN', 'ZNF586', 'POLR2I', 'FBXO21',
#         'CCND1', 'PCNA', 'NR2F6', 'LRRC41', 'KIAA0100', 'USP22', 'MYBL2',
#         'BNIP3L', 'HSPA8', 'PAF1', 'ACD', 'KIF2C', 'CHAC1', 'CIRBP',
#         'CLTB', 'SUPV3L1', 'VPS28', 'SCAND1', 'ZNF274', 'COG7', 'GAPDH'],
#        dtype=object),
#  'MCF7_ASC-J9': array(['TESK1', 'CANT1', 'APOE', 'NPEPL1', 'CHP1', 'NOSIP', 'DNAJB6',
#         'PCNA', 'APBB2', 'TEX10', 'CAPN1', 'HN1L', 'POLR2I', 'RTN2',
#         'LRRC41', 'CSK', 'SCARB1', 'NPDC1', 'BNIP3L', 'CD58', 'PAPD7',
#         'CDCA4', 'CHIC2', 'KIAA0100', 'MMP2', 'USP22', 'CHAC1', 'ECH1',
#         'NR2F6', 'CCNB1', 'S100A4', 'CCND1', 'AKT1', 'MRPL12', 'MYBL2',
#         'SNCA', 'HSPA8', 'SUPV3L1', 'ACD', 'METRN', 'PAF1', 'CIRBP',
#         'ZNF586', 'COG7', 'SCAND1', 'KIF2C', 'VPS28', 'ZNF274', 'CLTB',
#         'GAPDH'], dtype=object),
#  'MCF7_ellagic-acid': array(['CLIC4', 'HOMER2', 'RUVBL1', 'PAK4', 'POLR2I', 'NR2F6', 'SPDEF',
#         'APOE', 'APBB2', 'PSMD4', 'ATF5', 'MRPS2', 'CIRBP', 'S100A4',
#         'CHIC2', 'METRN', 'HN1L', 'EIF4EBP1', 'RAP1GAP', 'CEBPA',
#         'KIAA0100', 'TEX10', 'CSK', 'ECH1', 'ACD', 'SPR', 'SMARCD2',
#         'CDCA4', 'AKT1', 'PCNA', 'PAF1', 'VPS28', 'CCNB1', 'SUPV3L1',
#         'MYBL2', 'SCARB1', 'FZD7', 'SNCA', 'MRPL12', 'CCND1', 'CHAC1',
#         'HSPA8', 'SCAND1', 'KIF2C', 'ZNF586', 'BNIP3L', 'COG7', 'CLTB',
#         'ZNF274', 'GAPDH'], dtype=object),
#  'PC3_aminoglutethimide': array(['MAST2', 'CSNK2A2', 'ECH1', 'GATA2', 'SPAG7', 'KAT6A', 'CEBPA',
#         'EPN2', 'SCAND1', 'SUPV3L1', 'UBQLN2', 'SKP1', 'ACOT9', 'RNH1',
#         'USP22', 'MIF', 'PAF1', 'ACD', 'SRC', 'MLEC', 'PAK4', 'MRPS2',
#         'TLR4', 'PCNA', 'CCNB1', 'CDC42', 'PLSCR3', 'PYCR1', 'ZNF586',
#         'CDKN1B', 'TRAPPC6A', 'TEX10', 'HSPA8', 'SPP1', 'AKT1', 'INSIG1',
#         'CIRBP', 'IKZF1', 'DPH2', 'KIAA0100', 'COG7', 'CCDC92', 'CLTB',
#         'HOMER2', 'GRB7', 'MBTPS1', 'HSPA1A', 'ZNF274', 'BNIP3L', 'GAPDH'],
#        dtype=object),
#  'PC3_nicardipine': array(['CCND3', 'PLK1', 'EAPP', 'SYNE2', 'ID2', 'IGF1R', 'DMTF1', 'BNIP3',
#         'RAB31', 'SOX4', 'GRB7', 'NCOA3', 'PPIC', 'CCDC92', 'SOX2',
#         'PSMB8', 'PEX11A', 'GNAI1', 'PSMD10', 'CDC25B', 'LRRC16A',
#         'TSC22D3', 'HMGCR', 'SPP1', 'MAP4K4', 'CDKN1A', 'NGRN', 'UBQLN2',
#         'SERPINE1', 'FOSL1', 'MAPKAPK2', 'RAB4A', 'MTFR1', 'SNAP25',
#         'DNAJA3', 'PAF1', 'SPDEF', 'RALGDS', 'SIRT3', 'MIF', 'VPS28',
#         'PSME1', 'HOMER2', 'MALT1', 'HMGCS1', 'MBTPS1', 'INSIG1', 'KIF2C',
#         'PYCR1', 'SNCA'], dtype=object),
#  'PC3_VX-765': array(['CANT1', 'HOMER2', 'SLC25A46', 'CSK', 'NPDC1', 'TEX10', 'SCARB1',
#         'ASAH1', 'TESK1', 'APBB2', 'HN1L', 'USP22', 'CDCA4', 'LRRC41',
#         'NR2F6', 'FUT1', 'NOSIP', 'NPEPL1', 'CD58', 'DYNLT3', 'CHIC2',
#         'ECH1', 'MMP2', 'MYBL2', 'NARFL', 'CCND1', 'MRPL12', 'RTN2',
#         'SNCA', 'S100A4', 'CCNB1', 'METRN', 'AKT1', 'CIRBP', 'PCNA',
#         'PAPD7', 'BNIP3L', 'ACD', 'PAF1', 'ZNF586', 'KIF2C', 'SCAND1',
#         'HSPA8', 'CHAC1', 'SUPV3L1', 'COG7', 'VPS28', 'CLTB', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'PC3_ramelteon': array(['CANT1', 'NPEPL1', 'HOMER2', 'AURKB', 'NOSIP', 'TESK1', 'APBB2',
#         'CSK', 'APOE', 'ASAH1', 'USP22', 'SCARB1', 'TEX10', 'FUT1',
#         'DYNLT3', 'NPDC1', 'CDCA4', 'HN1L', 'NARFL', 'ECH1', 'LRRC41',
#         'NR2F6', 'CHIC2', 'MYBL2', 'S100A4', 'CCND1', 'MMP2', 'ZNF586',
#         'MRPL12', 'AKT1', 'PAPD7', 'CIRBP', 'SNCA', 'RTN2', 'BNIP3L',
#         'CCNB1', 'METRN', 'ACD', 'SCAND1', 'PAF1', 'PCNA', 'KIF2C',
#         'CHAC1', 'SUPV3L1', 'HSPA8', 'COG7', 'VPS28', 'CLTB', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'PC3_dutasteride': array(['MRPS2', 'NOSIP', 'NPEPL1', 'TEX10', 'CD58', 'USP22', 'SCARB1',
#         'NPDC1', 'LRRC41', 'NR2F6', 'CDCA4', 'HN1L', 'ASAH1', 'CANT1',
#         'AURKB', 'SLC25A46', 'CSK', 'DYNLT3', 'KIAA0100', 'CHIC2', 'ECH1',
#         'APBB2', 'PAPD7', 'METRN', 'NARFL', 'MYBL2', 'MMP2', 'AKT1',
#         'RTN2', 'CCNB1', 'S100A4', 'CCND1', 'SNCA', 'MRPL12', 'BNIP3L',
#         'CIRBP', 'ACD', 'HSPA8', 'ZNF586', 'KIF2C', 'PAF1', 'PCNA',
#         'SCAND1', 'CHAC1', 'SUPV3L1', 'COG7', 'VPS28', 'CLTB', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'PC3_ostarine': array(['POLR2I', 'CANT1', 'CDCA4', 'CSK', 'ASAH1', 'PSMD4', 'HN1L',
#         'SCARB1', 'APBB2', 'USP22', 'KIAA0100', 'CHIC2', 'SLC25A46',
#         'NPDC1', 'NPEPL1', 'ECH1', 'DYNLT3', 'LRRC41', 'TEX10', 'NR2F6',
#         'CD58', 'RTN2', 'PCNA', 'MYBL2', 'MMP2', 'CCNB1', 'NOSIP', 'CCND1',
#         'S100A4', 'PAPD7', 'MRPL12', 'METRN', 'AKT1', 'CIRBP', 'BNIP3L',
#         'HSPA8', 'NARFL', 'ACD', 'SNCA', 'CHAC1', 'SUPV3L1', 'PAF1',
#         'ZNF586', 'SCAND1', 'KIF2C', 'COG7', 'VPS28', 'CLTB', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'PC3_amikacin': array(['CNDP2', 'ARNT2', 'SPR', 'MMP2', 'EIF4EBP1', 'TESK1', 'ATF5',
#         'CSK', 'NPDC1', 'APOE', 'CHIC2', 'APBB2', 'HN1L', 'CHP1', 'PAPD7',
#         'RPN1', 'CDKN1A', 'CCNB1', 'MRPL12', 'TEX10', 'S100A4', 'ECH1',
#         'CDCA4', 'CD58', 'SNCA', 'METRN', 'ZNF586', 'POLR2I', 'FBXO21',
#         'CCND1', 'PCNA', 'NR2F6', 'LRRC41', 'KIAA0100', 'USP22', 'MYBL2',
#         'BNIP3L', 'HSPA8', 'PAF1', 'ACD', 'KIF2C', 'CHAC1', 'CIRBP',
#         'CLTB', 'SUPV3L1', 'VPS28', 'SCAND1', 'ZNF274', 'COG7', 'GAPDH'],
#        dtype=object),
#  'PC3_ASC-J9': array(['TESK1', 'CANT1', 'APOE', 'NPEPL1', 'CHP1', 'NOSIP', 'DNAJB6',
#         'PCNA', 'APBB2', 'TEX10', 'CAPN1', 'HN1L', 'POLR2I', 'RTN2',
#         'LRRC41', 'CSK', 'SCARB1', 'NPDC1', 'BNIP3L', 'CD58', 'PAPD7',
#         'CDCA4', 'CHIC2', 'KIAA0100', 'MMP2', 'USP22', 'CHAC1', 'ECH1',
#         'NR2F6', 'CCNB1', 'S100A4', 'CCND1', 'AKT1', 'MRPL12', 'MYBL2',
#         'SNCA', 'HSPA8', 'SUPV3L1', 'ACD', 'METRN', 'PAF1', 'CIRBP',
#         'ZNF586', 'COG7', 'SCAND1', 'KIF2C', 'VPS28', 'ZNF274', 'CLTB',
#         'GAPDH'], dtype=object),
#  'PC3_ellagic-acid': array(['CLIC4', 'HOMER2', 'RUVBL1', 'PAK4', 'POLR2I', 'NR2F6', 'SPDEF',
#         'APOE', 'APBB2', 'PSMD4', 'ATF5', 'MRPS2', 'CIRBP', 'S100A4',
#         'CHIC2', 'METRN', 'HN1L', 'EIF4EBP1', 'RAP1GAP', 'CEBPA',
#         'KIAA0100', 'TEX10', 'CSK', 'ECH1', 'ACD', 'SPR', 'SMARCD2',
#         'CDCA4', 'AKT1', 'PCNA', 'PAF1', 'VPS28', 'CCNB1', 'SUPV3L1',
#         'MYBL2', 'SCARB1', 'FZD7', 'SNCA', 'MRPL12', 'CCND1', 'CHAC1',
#         'HSPA8', 'SCAND1', 'KIF2C', 'ZNF586', 'BNIP3L', 'COG7', 'CLTB',
#         'ZNF274', 'GAPDH'], dtype=object),
#  'YAPC_aminoglutethimide': array(['MAST2', 'CSNK2A2', 'ECH1', 'GATA2', 'SPAG7', 'KAT6A', 'CEBPA',
#         'EPN2', 'SCAND1', 'SUPV3L1', 'UBQLN2', 'SKP1', 'ACOT9', 'RNH1',
#         'USP22', 'MIF', 'PAF1', 'ACD', 'SRC', 'MLEC', 'PAK4', 'MRPS2',
#         'TLR4', 'PCNA', 'CCNB1', 'CDC42', 'PLSCR3', 'PYCR1', 'ZNF586',
#         'CDKN1B', 'TRAPPC6A', 'TEX10', 'HSPA8', 'SPP1', 'AKT1', 'INSIG1',
#         'CIRBP', 'IKZF1', 'DPH2', 'KIAA0100', 'COG7', 'CCDC92', 'CLTB',
#         'HOMER2', 'GRB7', 'MBTPS1', 'HSPA1A', 'ZNF274', 'BNIP3L', 'GAPDH'],
#        dtype=object),
#  'YAPC_nicardipine': array(['CCND3', 'PLK1', 'EAPP', 'SYNE2', 'ID2', 'IGF1R', 'DMTF1', 'BNIP3',
#         'RAB31', 'SOX4', 'GRB7', 'NCOA3', 'PPIC', 'CCDC92', 'SOX2',
#         'PSMB8', 'PEX11A', 'GNAI1', 'PSMD10', 'CDC25B', 'LRRC16A',
#         'TSC22D3', 'HMGCR', 'SPP1', 'MAP4K4', 'CDKN1A', 'NGRN', 'UBQLN2',
#         'SERPINE1', 'FOSL1', 'MAPKAPK2', 'RAB4A', 'MTFR1', 'SNAP25',
#         'DNAJA3', 'PAF1', 'SPDEF', 'RALGDS', 'SIRT3', 'MIF', 'VPS28',
#         'PSME1', 'HOMER2', 'MALT1', 'HMGCS1', 'MBTPS1', 'INSIG1', 'KIF2C',
#         'PYCR1', 'SNCA'], dtype=object),
#  'YAPC_VX-765': array(['CANT1', 'HOMER2', 'SLC25A46', 'CSK', 'NPDC1', 'TEX10', 'SCARB1',
#         'ASAH1', 'TESK1', 'APBB2', 'HN1L', 'USP22', 'CDCA4', 'LRRC41',
#         'NR2F6', 'FUT1', 'NOSIP', 'NPEPL1', 'CD58', 'DYNLT3', 'CHIC2',
#         'ECH1', 'MMP2', 'MYBL2', 'NARFL', 'CCND1', 'MRPL12', 'RTN2',
#         'SNCA', 'S100A4', 'CCNB1', 'METRN', 'AKT1', 'CIRBP', 'PCNA',
#         'PAPD7', 'BNIP3L', 'ACD', 'PAF1', 'ZNF586', 'KIF2C', 'SCAND1',
#         'HSPA8', 'CHAC1', 'SUPV3L1', 'COG7', 'VPS28', 'CLTB', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'YAPC_ramelteon': array(['CANT1', 'NPEPL1', 'HOMER2', 'AURKB', 'NOSIP', 'TESK1', 'APBB2',
#         'CSK', 'APOE', 'ASAH1', 'USP22', 'SCARB1', 'TEX10', 'FUT1',
#         'DYNLT3', 'NPDC1', 'CDCA4', 'HN1L', 'NARFL', 'ECH1', 'LRRC41',
#         'NR2F6', 'CHIC2', 'MYBL2', 'S100A4', 'CCND1', 'MMP2', 'ZNF586',
#         'MRPL12', 'AKT1', 'PAPD7', 'CIRBP', 'SNCA', 'RTN2', 'BNIP3L',
#         'CCNB1', 'METRN', 'ACD', 'SCAND1', 'PAF1', 'PCNA', 'KIF2C',
#         'CHAC1', 'SUPV3L1', 'HSPA8', 'COG7', 'VPS28', 'CLTB', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'YAPC_dutasteride': array(['MRPS2', 'NOSIP', 'NPEPL1', 'TEX10', 'CD58', 'USP22', 'SCARB1',
#         'NPDC1', 'LRRC41', 'NR2F6', 'CDCA4', 'HN1L', 'ASAH1', 'CANT1',
#         'AURKB', 'SLC25A46', 'CSK', 'DYNLT3', 'KIAA0100', 'CHIC2', 'ECH1',
#         'APBB2', 'PAPD7', 'METRN', 'NARFL', 'MYBL2', 'MMP2', 'AKT1',
#         'RTN2', 'CCNB1', 'S100A4', 'CCND1', 'SNCA', 'MRPL12', 'BNIP3L',
#         'CIRBP', 'ACD', 'HSPA8', 'ZNF586', 'KIF2C', 'PAF1', 'PCNA',
#         'SCAND1', 'CHAC1', 'SUPV3L1', 'COG7', 'VPS28', 'CLTB', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'YAPC_ostarine': array(['POLR2I', 'CANT1', 'CDCA4', 'CSK', 'ASAH1', 'PSMD4', 'HN1L',
#         'SCARB1', 'APBB2', 'USP22', 'KIAA0100', 'CHIC2', 'SLC25A46',
#         'NPDC1', 'NPEPL1', 'ECH1', 'DYNLT3', 'LRRC41', 'TEX10', 'NR2F6',
#         'CD58', 'RTN2', 'PCNA', 'MYBL2', 'MMP2', 'CCNB1', 'NOSIP', 'CCND1',
#         'S100A4', 'PAPD7', 'MRPL12', 'METRN', 'AKT1', 'CIRBP', 'BNIP3L',
#         'HSPA8', 'NARFL', 'ACD', 'SNCA', 'CHAC1', 'SUPV3L1', 'PAF1',
#         'ZNF586', 'SCAND1', 'KIF2C', 'COG7', 'VPS28', 'CLTB', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'YAPC_amikacin': array(['CNDP2', 'ARNT2', 'SPR', 'MMP2', 'EIF4EBP1', 'TESK1', 'ATF5',
#         'CSK', 'NPDC1', 'APOE', 'CHIC2', 'APBB2', 'HN1L', 'CHP1', 'PAPD7',
#         'RPN1', 'CDKN1A', 'CCNB1', 'MRPL12', 'TEX10', 'S100A4', 'ECH1',
#         'CDCA4', 'CD58', 'SNCA', 'METRN', 'ZNF586', 'POLR2I', 'FBXO21',
#         'CCND1', 'PCNA', 'NR2F6', 'LRRC41', 'KIAA0100', 'USP22', 'MYBL2',
#         'BNIP3L', 'HSPA8', 'PAF1', 'ACD', 'KIF2C', 'CHAC1', 'CIRBP',
#         'CLTB', 'SUPV3L1', 'VPS28', 'SCAND1', 'ZNF274', 'COG7', 'GAPDH'],
#        dtype=object),
#  'YAPC_ASC-J9': array(['TESK1', 'CANT1', 'APOE', 'NPEPL1', 'CHP1', 'NOSIP', 'DNAJB6',
#         'PCNA', 'APBB2', 'TEX10', 'CAPN1', 'HN1L', 'POLR2I', 'RTN2',
#         'LRRC41', 'CSK', 'SCARB1', 'NPDC1', 'BNIP3L', 'CD58', 'PAPD7',
#         'CDCA4', 'CHIC2', 'KIAA0100', 'MMP2', 'USP22', 'CHAC1', 'ECH1',
#         'NR2F6', 'CCNB1', 'S100A4', 'CCND1', 'AKT1', 'MRPL12', 'MYBL2',
#         'SNCA', 'HSPA8', 'SUPV3L1', 'ACD', 'METRN', 'PAF1', 'CIRBP',
#         'ZNF586', 'COG7', 'SCAND1', 'KIF2C', 'VPS28', 'ZNF274', 'CLTB',
#         'GAPDH'], dtype=object),
#  'YAPC_ellagic-acid': array(['CLIC4', 'HOMER2', 'RUVBL1', 'PAK4', 'POLR2I', 'NR2F6', 'SPDEF',
#         'APOE', 'APBB2', 'PSMD4', 'ATF5', 'MRPS2', 'CIRBP', 'S100A4',
#         'CHIC2', 'METRN', 'HN1L', 'EIF4EBP1', 'RAP1GAP', 'CEBPA',
#         'KIAA0100', 'TEX10', 'CSK', 'ECH1', 'ACD', 'SPR', 'SMARCD2',
#         'CDCA4', 'AKT1', 'PCNA', 'PAF1', 'VPS28', 'CCNB1', 'SUPV3L1',
#         'MYBL2', 'SCARB1', 'FZD7', 'SNCA', 'MRPL12', 'CCND1', 'CHAC1',
#         'HSPA8', 'SCAND1', 'KIF2C', 'ZNF586', 'BNIP3L', 'COG7', 'CLTB',
#         'ZNF274', 'GAPDH'], dtype=object),
#  'A375_diazepam': array(['CSK', 'PAFAH1B3', 'CTNNAL1', 'PSME1', 'OXA1L', 'PCK2', 'SPR',
#         'CHEK1', 'TEX10', 'HOXA10', 'RTN2', 'LRRC41', 'TRIB3', 'DYNLT3',
#         'AKT1', 'MBTPS1', 'CDKN1B', 'CIRBP', 'PSMD4', 'ARNT2', 'RNH1',
#         'IGF2BP2', 'RBM34', 'CEBPA', 'PAPD7', 'MMP2', 'SCAND1', 'CCNB1',
#         'CDKN1A', 'CLIC4', 'ACOT9', 'FOSL1', 'HN1L', 'RPN1', 'FUT1', 'ACD',
#         'GRB7', 'NR2F6', 'MRPS2', 'SKP1', 'HSPA8', 'PCNA', 'COG7',
#         'SUPV3L1', 'PAF1', 'CHAC1', 'CLTB', 'ZNF274', 'BNIP3L', 'GAPDH'],
#        dtype=object),
#  'A375_zaprinast': array(['S100A4', 'ORC1', 'CNDP2', 'IPO13', 'MYLK', 'AKT1', 'EPN2',
#         'MAST2', 'CASP3', 'OXA1L', 'MLEC', 'KIAA0100', 'GRB7', 'PSMD4',
#         'SPR', 'FBXO21', 'HN1L', 'HOMER2', 'IGF2BP2', 'MMP2', 'TRIB3',
#         'TRAPPC6A', 'RNH1', 'ARNT2', 'MBTPS1', 'SKP1', 'CANT1', 'RTN2',
#         'RPN1', 'E2F2', 'VPS28', 'DNAJB6', 'MRPS2', 'CIRBP', 'PAPD7',
#         'ACD', 'PAF1', 'NR2F6', 'RBM34', 'CCNB1', 'FUT1', 'ZNF274',
#         'SUPV3L1', 'CLTB', 'HSPA8', 'COG7', 'CHAC1', 'BNIP3L', 'PCNA',
#         'GAPDH'], dtype=object),
#  'A375_regorafenib': array(['CDC20', 'DUSP6', 'IGF2BP2', 'COG7', 'DPH2', 'LSR', 'UBE2C',
#         'HDGFRP3', 'CLTB', 'CDK4', 'HOMER2', 'NR2F6', 'HMOX1', 'EPB41L2',
#         'RAD9A', 'NOSIP', 'FZD7', 'ACLY', 'CDKN2A', 'PIK3C3', 'BIRC5',
#         'ZNF586', 'BAD', 'SCAND1', 'NCK1', 'MLLT11', 'SSBP2', 'UBE2L6',
#         'CHP1', 'TSC22D3', 'MRPL12', 'RALB', 'ME2', 'HMGA2', 'ZNF274',
#         'CAPN1', 'FYN', 'CCND1', 'SMARCD2', 'BNIP3L', 'COL4A1', 'MYBL2',
#         'CLIC4', 'GRB7', 'COL1A1', 'SERPINE1', 'KIF2C', 'SNCA', 'VPS28',
#         'ASAH1'], dtype=object),
#  'A375_filgotinib': array(['KIAA0100', 'DNMT3A', 'AKT1', 'DNAJB6', 'CANT1', 'METRN', 'MYBL2',
#         'DYNLT3', 'ECH1', 'ORC1', 'SKP1', 'LRRC41', 'FBXO21', 'NPDC1',
#         'PSMD4', 'PLA2G4A', 'NARFL', 'NPEPL1', 'TRIB3', 'RPN1', 'AURKB',
#         'HN1L', 'PCNA', 'KIF2C', 'TESK1', 'CIRBP', 'MRPS2', 'SCAND1',
#         'S100A4', 'MRPL12', 'CCNB1', 'ACD', 'FUT1', 'CCND1', 'SNCA',
#         'ARNT2', 'NR2F6', 'MMP2', 'RTN2', 'PAPD7', 'VPS28', 'PAF1',
#         'HSPA8', 'BNIP3L', 'CLTB', 'SUPV3L1', 'COG7', 'CHAC1', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'A375_belinostat': array(['COL4A1', 'AURKA', 'XBP1', 'KIF2C', 'CDC20', 'CAPN1', 'SUV39H1',
#         'CCNA2', 'CHP1', 'SPR', 'JADE2', 'ALDOC', 'RNF167', 'CCNB2',
#         'P4HTM', 'CLIC4', 'MKNK1', 'PIK3C3', 'NPC1', 'ST7', 'INSIG1',
#         'CDKN1A', 'CBR3', 'MRPL12', 'PLK1', 'GLRX', 'MYBL2', 'CDK1',
#         'UBE2L6', 'KIF20A', 'LIPA', 'FAM57A', 'HMOX1', 'VAT1', 'ATF5',
#         'SSBP2', 'CCND1', 'FYN', 'SNCA', 'COL1A1', 'PCBD1', 'ADI1',
#         'VPS28', 'GRB7', 'BIRC5', 'KEAP1', 'BNIP3L', 'ASAH1', 'SERPINE1',
#         'UBE2C'], dtype=object),
#  'A375_lenalidomide': array(['EIF5', 'CDKN2A', 'GNAS', 'NR2F6', 'PSME1', 'HMGCS1', 'S100A4',
#         'DPH2', 'KIF20A', 'CCDC92', 'PSMD10', 'MAP7', 'ACOT9', 'RAB31',
#         'MTA1', 'RALGDS', 'NT5DC2', 'MTFR1', 'MALT1', 'SUPV3L1', 'XBP1',
#         'PPP2R5E', 'DUSP6', 'ATF5', 'RAB4A', 'IGF2BP2', 'CLTB', 'GRB7',
#         'UBQLN2', 'PAK4', 'CDK4', 'GATA2', 'PAF1', 'FOSL1', 'CBR1',
#         'CANT1', 'MIF', 'CCND3', 'KIF2C', 'PSMB8', 'INSIG1', 'NCOA3',
#         'DHRS7', 'MBTPS1', 'HOMER2', 'SNCA', 'BNIP3L', 'SPDEF', 'GAPDH',
#         'PYCR1'], dtype=object),
#  'A375_LY-2886721': array(['PUF60', 'CD58', 'SPR', 'FUT1', 'EPN2', 'TRIB3', 'NPEPL1', 'ASAH1',
#         'PSMD4', 'SLC25A46', 'CSK', 'LRRC41', 'DNAJB6', 'KIAA0100',
#         'DYNLT3', 'MYBL2', 'RPN1', 'AKT1', 'NOSIP', 'HN1L', 'RTN2',
#         'CANT1', 'SKP1', 'NPDC1', 'AURKB', 'MRPS2', 'NARFL', 'CCNB1',
#         'MMP2', 'SCAND1', 'CIRBP', 'PAPD7', 'NR2F6', 'ACD', 'SNCA',
#         'KIF2C', 'MRPL12', 'CCND1', 'S100A4', 'PCNA', 'PAF1', 'HSPA8',
#         'VPS28', 'SUPV3L1', 'BNIP3L', 'CHAC1', 'CLTB', 'COG7', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'A375_bosutinib': array(['CHN1', 'SOX2', 'FZD7', 'PLK1', 'LSR', 'CHERP', 'TSTA3', 'ZNF586',
#         'NET1', 'DPH2', 'HMOX1', 'NOSIP', 'KIF20A', 'PRPF4', 'ACLY',
#         'RAD9A', 'SSBP2', 'CDCA4', 'ME2', 'ZNF274', 'RAE1', 'SCAND1',
#         'VAT1', 'CAPN1', 'COG7', 'BNIP3L', 'CHP1', 'HMGCR', 'CLIC4',
#         'UBE2L6', 'SMARCD2', 'MRPL12', 'MLLT11', 'FYN', 'KIF2C', 'CDK1',
#         'CDC20', 'CCND1', 'MYBL2', 'COL1A1', 'INSIG1', 'COL4A1', 'BIRC5',
#         'SERPINE1', 'UBE2C', 'GRB7', 'TSC22D3', 'SNCA', 'ASAH1', 'VPS28'],
#        dtype=object),
#  'HA1E_diazepam': array(['CSK', 'PAFAH1B3', 'CTNNAL1', 'PSME1', 'OXA1L', 'PCK2', 'SPR',
#         'CHEK1', 'TEX10', 'HOXA10', 'RTN2', 'LRRC41', 'TRIB3', 'DYNLT3',
#         'AKT1', 'MBTPS1', 'CDKN1B', 'CIRBP', 'PSMD4', 'ARNT2', 'RNH1',
#         'IGF2BP2', 'RBM34', 'CEBPA', 'PAPD7', 'MMP2', 'SCAND1', 'CCNB1',
#         'CDKN1A', 'CLIC4', 'ACOT9', 'FOSL1', 'HN1L', 'RPN1', 'FUT1', 'ACD',
#         'GRB7', 'NR2F6', 'MRPS2', 'SKP1', 'HSPA8', 'PCNA', 'COG7',
#         'SUPV3L1', 'PAF1', 'CHAC1', 'CLTB', 'ZNF274', 'BNIP3L', 'GAPDH'],
#        dtype=object),
#  'HA1E_zaprinast': array(['S100A4', 'ORC1', 'CNDP2', 'IPO13', 'MYLK', 'AKT1', 'EPN2',
#         'MAST2', 'CASP3', 'OXA1L', 'MLEC', 'KIAA0100', 'GRB7', 'PSMD4',
#         'SPR', 'FBXO21', 'HN1L', 'HOMER2', 'IGF2BP2', 'MMP2', 'TRIB3',
#         'TRAPPC6A', 'RNH1', 'ARNT2', 'MBTPS1', 'SKP1', 'CANT1', 'RTN2',
#         'RPN1', 'E2F2', 'VPS28', 'DNAJB6', 'MRPS2', 'CIRBP', 'PAPD7',
#         'ACD', 'PAF1', 'NR2F6', 'RBM34', 'CCNB1', 'FUT1', 'ZNF274',
#         'SUPV3L1', 'CLTB', 'HSPA8', 'COG7', 'CHAC1', 'BNIP3L', 'PCNA',
#         'GAPDH'], dtype=object),
#  'HA1E_regorafenib': array(['CDC20', 'DUSP6', 'IGF2BP2', 'COG7', 'DPH2', 'LSR', 'UBE2C',
#         'HDGFRP3', 'CLTB', 'CDK4', 'HOMER2', 'NR2F6', 'HMOX1', 'EPB41L2',
#         'RAD9A', 'NOSIP', 'FZD7', 'ACLY', 'CDKN2A', 'PIK3C3', 'BIRC5',
#         'ZNF586', 'BAD', 'SCAND1', 'NCK1', 'MLLT11', 'SSBP2', 'UBE2L6',
#         'CHP1', 'TSC22D3', 'MRPL12', 'RALB', 'ME2', 'HMGA2', 'ZNF274',
#         'CAPN1', 'FYN', 'CCND1', 'SMARCD2', 'BNIP3L', 'COL4A1', 'MYBL2',
#         'CLIC4', 'GRB7', 'COL1A1', 'SERPINE1', 'KIF2C', 'SNCA', 'VPS28',
#         'ASAH1'], dtype=object),
#  'HA1E_filgotinib': array(['KIAA0100', 'DNMT3A', 'AKT1', 'DNAJB6', 'CANT1', 'METRN', 'MYBL2',
#         'DYNLT3', 'ECH1', 'ORC1', 'SKP1', 'LRRC41', 'FBXO21', 'NPDC1',
#         'PSMD4', 'PLA2G4A', 'NARFL', 'NPEPL1', 'TRIB3', 'RPN1', 'AURKB',
#         'HN1L', 'PCNA', 'KIF2C', 'TESK1', 'CIRBP', 'MRPS2', 'SCAND1',
#         'S100A4', 'MRPL12', 'CCNB1', 'ACD', 'FUT1', 'CCND1', 'SNCA',
#         'ARNT2', 'NR2F6', 'MMP2', 'RTN2', 'PAPD7', 'VPS28', 'PAF1',
#         'HSPA8', 'BNIP3L', 'CLTB', 'SUPV3L1', 'COG7', 'CHAC1', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'HA1E_belinostat': array(['COL4A1', 'AURKA', 'XBP1', 'KIF2C', 'CDC20', 'CAPN1', 'SUV39H1',
#         'CCNA2', 'CHP1', 'SPR', 'JADE2', 'ALDOC', 'RNF167', 'CCNB2',
#         'P4HTM', 'CLIC4', 'MKNK1', 'PIK3C3', 'NPC1', 'ST7', 'INSIG1',
#         'CDKN1A', 'CBR3', 'MRPL12', 'PLK1', 'GLRX', 'MYBL2', 'CDK1',
#         'UBE2L6', 'KIF20A', 'LIPA', 'FAM57A', 'HMOX1', 'VAT1', 'ATF5',
#         'SSBP2', 'CCND1', 'FYN', 'SNCA', 'COL1A1', 'PCBD1', 'ADI1',
#         'VPS28', 'GRB7', 'BIRC5', 'KEAP1', 'BNIP3L', 'ASAH1', 'SERPINE1',
#         'UBE2C'], dtype=object),
#  'HA1E_lenalidomide': array(['EIF5', 'CDKN2A', 'GNAS', 'NR2F6', 'PSME1', 'HMGCS1', 'S100A4',
#         'DPH2', 'KIF20A', 'CCDC92', 'PSMD10', 'MAP7', 'ACOT9', 'RAB31',
#         'MTA1', 'RALGDS', 'NT5DC2', 'MTFR1', 'MALT1', 'SUPV3L1', 'XBP1',
#         'PPP2R5E', 'DUSP6', 'ATF5', 'RAB4A', 'IGF2BP2', 'CLTB', 'GRB7',
#         'UBQLN2', 'PAK4', 'CDK4', 'GATA2', 'PAF1', 'FOSL1', 'CBR1',
#         'CANT1', 'MIF', 'CCND3', 'KIF2C', 'PSMB8', 'INSIG1', 'NCOA3',
#         'DHRS7', 'MBTPS1', 'HOMER2', 'SNCA', 'BNIP3L', 'SPDEF', 'GAPDH',
#         'PYCR1'], dtype=object),
#  'HA1E_LY-2886721': array(['PUF60', 'CD58', 'SPR', 'FUT1', 'EPN2', 'TRIB3', 'NPEPL1', 'ASAH1',
#         'PSMD4', 'SLC25A46', 'CSK', 'LRRC41', 'DNAJB6', 'KIAA0100',
#         'DYNLT3', 'MYBL2', 'RPN1', 'AKT1', 'NOSIP', 'HN1L', 'RTN2',
#         'CANT1', 'SKP1', 'NPDC1', 'AURKB', 'MRPS2', 'NARFL', 'CCNB1',
#         'MMP2', 'SCAND1', 'CIRBP', 'PAPD7', 'NR2F6', 'ACD', 'SNCA',
#         'KIF2C', 'MRPL12', 'CCND1', 'S100A4', 'PCNA', 'PAF1', 'HSPA8',
#         'VPS28', 'SUPV3L1', 'BNIP3L', 'CHAC1', 'CLTB', 'COG7', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'HA1E_bosutinib': array(['CHN1', 'SOX2', 'FZD7', 'PLK1', 'LSR', 'CHERP', 'TSTA3', 'ZNF586',
#         'NET1', 'DPH2', 'HMOX1', 'NOSIP', 'KIF20A', 'PRPF4', 'ACLY',
#         'RAD9A', 'SSBP2', 'CDCA4', 'ME2', 'ZNF274', 'RAE1', 'SCAND1',
#         'VAT1', 'CAPN1', 'COG7', 'BNIP3L', 'CHP1', 'HMGCR', 'CLIC4',
#         'UBE2L6', 'SMARCD2', 'MRPL12', 'MLLT11', 'FYN', 'KIF2C', 'CDK1',
#         'CDC20', 'CCND1', 'MYBL2', 'COL1A1', 'INSIG1', 'COL4A1', 'BIRC5',
#         'SERPINE1', 'UBE2C', 'GRB7', 'TSC22D3', 'SNCA', 'ASAH1', 'VPS28'],
#        dtype=object),
#  'HELA_diazepam': array(['CSK', 'PAFAH1B3', 'CTNNAL1', 'PSME1', 'OXA1L', 'PCK2', 'SPR',
#         'CHEK1', 'TEX10', 'HOXA10', 'RTN2', 'LRRC41', 'TRIB3', 'DYNLT3',
#         'AKT1', 'MBTPS1', 'CDKN1B', 'CIRBP', 'PSMD4', 'ARNT2', 'RNH1',
#         'IGF2BP2', 'RBM34', 'CEBPA', 'PAPD7', 'MMP2', 'SCAND1', 'CCNB1',
#         'CDKN1A', 'CLIC4', 'ACOT9', 'FOSL1', 'HN1L', 'RPN1', 'FUT1', 'ACD',
#         'GRB7', 'NR2F6', 'MRPS2', 'SKP1', 'HSPA8', 'PCNA', 'COG7',
#         'SUPV3L1', 'PAF1', 'CHAC1', 'CLTB', 'ZNF274', 'BNIP3L', 'GAPDH'],
#        dtype=object),
#  'HELA_zaprinast': array(['S100A4', 'ORC1', 'CNDP2', 'IPO13', 'MYLK', 'AKT1', 'EPN2',
#         'MAST2', 'CASP3', 'OXA1L', 'MLEC', 'KIAA0100', 'GRB7', 'PSMD4',
#         'SPR', 'FBXO21', 'HN1L', 'HOMER2', 'IGF2BP2', 'MMP2', 'TRIB3',
#         'TRAPPC6A', 'RNH1', 'ARNT2', 'MBTPS1', 'SKP1', 'CANT1', 'RTN2',
#         'RPN1', 'E2F2', 'VPS28', 'DNAJB6', 'MRPS2', 'CIRBP', 'PAPD7',
#         'ACD', 'PAF1', 'NR2F6', 'RBM34', 'CCNB1', 'FUT1', 'ZNF274',
#         'SUPV3L1', 'CLTB', 'HSPA8', 'COG7', 'CHAC1', 'BNIP3L', 'PCNA',
#         'GAPDH'], dtype=object),
#  'HELA_regorafenib': array(['CDC20', 'DUSP6', 'IGF2BP2', 'COG7', 'DPH2', 'LSR', 'UBE2C',
#         'HDGFRP3', 'CLTB', 'CDK4', 'HOMER2', 'NR2F6', 'HMOX1', 'EPB41L2',
#         'RAD9A', 'NOSIP', 'FZD7', 'ACLY', 'CDKN2A', 'PIK3C3', 'BIRC5',
#         'ZNF586', 'BAD', 'SCAND1', 'NCK1', 'MLLT11', 'SSBP2', 'UBE2L6',
#         'CHP1', 'TSC22D3', 'MRPL12', 'RALB', 'ME2', 'HMGA2', 'ZNF274',
#         'CAPN1', 'FYN', 'CCND1', 'SMARCD2', 'BNIP3L', 'COL4A1', 'MYBL2',
#         'CLIC4', 'GRB7', 'COL1A1', 'SERPINE1', 'KIF2C', 'SNCA', 'VPS28',
#         'ASAH1'], dtype=object),
#  'HELA_filgotinib': array(['KIAA0100', 'DNMT3A', 'AKT1', 'DNAJB6', 'CANT1', 'METRN', 'MYBL2',
#         'DYNLT3', 'ECH1', 'ORC1', 'SKP1', 'LRRC41', 'FBXO21', 'NPDC1',
#         'PSMD4', 'PLA2G4A', 'NARFL', 'NPEPL1', 'TRIB3', 'RPN1', 'AURKB',
#         'HN1L', 'PCNA', 'KIF2C', 'TESK1', 'CIRBP', 'MRPS2', 'SCAND1',
#         'S100A4', 'MRPL12', 'CCNB1', 'ACD', 'FUT1', 'CCND1', 'SNCA',
#         'ARNT2', 'NR2F6', 'MMP2', 'RTN2', 'PAPD7', 'VPS28', 'PAF1',
#         'HSPA8', 'BNIP3L', 'CLTB', 'SUPV3L1', 'COG7', 'CHAC1', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'HELA_belinostat': array(['COL4A1', 'AURKA', 'XBP1', 'KIF2C', 'CDC20', 'CAPN1', 'SUV39H1',
#         'CCNA2', 'CHP1', 'SPR', 'JADE2', 'ALDOC', 'RNF167', 'CCNB2',
#         'P4HTM', 'CLIC4', 'MKNK1', 'PIK3C3', 'NPC1', 'ST7', 'INSIG1',
#         'CDKN1A', 'CBR3', 'MRPL12', 'PLK1', 'GLRX', 'MYBL2', 'CDK1',
#         'UBE2L6', 'KIF20A', 'LIPA', 'FAM57A', 'HMOX1', 'VAT1', 'ATF5',
#         'SSBP2', 'CCND1', 'FYN', 'SNCA', 'COL1A1', 'PCBD1', 'ADI1',
#         'VPS28', 'GRB7', 'BIRC5', 'KEAP1', 'BNIP3L', 'ASAH1', 'SERPINE1',
#         'UBE2C'], dtype=object),
#  'HELA_lenalidomide': array(['EIF5', 'CDKN2A', 'GNAS', 'NR2F6', 'PSME1', 'HMGCS1', 'S100A4',
#         'DPH2', 'KIF20A', 'CCDC92', 'PSMD10', 'MAP7', 'ACOT9', 'RAB31',
#         'MTA1', 'RALGDS', 'NT5DC2', 'MTFR1', 'MALT1', 'SUPV3L1', 'XBP1',
#         'PPP2R5E', 'DUSP6', 'ATF5', 'RAB4A', 'IGF2BP2', 'CLTB', 'GRB7',
#         'UBQLN2', 'PAK4', 'CDK4', 'GATA2', 'PAF1', 'FOSL1', 'CBR1',
#         'CANT1', 'MIF', 'CCND3', 'KIF2C', 'PSMB8', 'INSIG1', 'NCOA3',
#         'DHRS7', 'MBTPS1', 'HOMER2', 'SNCA', 'BNIP3L', 'SPDEF', 'GAPDH',
#         'PYCR1'], dtype=object),
#  'HELA_LY-2886721': array(['PUF60', 'CD58', 'SPR', 'FUT1', 'EPN2', 'TRIB3', 'NPEPL1', 'ASAH1',
#         'PSMD4', 'SLC25A46', 'CSK', 'LRRC41', 'DNAJB6', 'KIAA0100',
#         'DYNLT3', 'MYBL2', 'RPN1', 'AKT1', 'NOSIP', 'HN1L', 'RTN2',
#         'CANT1', 'SKP1', 'NPDC1', 'AURKB', 'MRPS2', 'NARFL', 'CCNB1',
#         'MMP2', 'SCAND1', 'CIRBP', 'PAPD7', 'NR2F6', 'ACD', 'SNCA',
#         'KIF2C', 'MRPL12', 'CCND1', 'S100A4', 'PCNA', 'PAF1', 'HSPA8',
#         'VPS28', 'SUPV3L1', 'BNIP3L', 'CHAC1', 'CLTB', 'COG7', 'ZNF274',
#         'GAPDH'], dtype=object),
#  'HELA_bosutinib': array(['CHN1', 'SOX2', 'FZD7', 'PLK1', 'LSR', 'CHERP', 'TSTA3', 'ZNF586',
#         'NET1', 'DPH2', 'HMOX1', 'NOSIP', 'KIF20A', 'PRPF4', 'ACLY',
#         'RAD9A', 'SSBP2', 'CDCA4', 'ME2', 'ZNF274', 'RAE1', 'SCAND1',
#         'VAT1', 'CAPN1', 'COG7', 'BNIP3L', 'CHP1', 'HMGCR', 'CLIC4',
#         'UBE2L6', 'SMARCD2', 'MRPL12', 'MLLT11', 'FYN', 'KIF2C', 'CDK1',
#         'CDC20', 'CCND1', 'MYBL2', 'COL1A1', 'INSIG1', 'COL4A1', 'BIRC5',
#         'SERPINE1', 'UBE2C', 'GRB7', 'TSC22D3', 'SNCA', 'ASAH1', 'VPS28'],
#        dtype=object),
#  'HT29_diazepam': array(['CSK', 'PAFAH1B3', 'CTNNAL1', 'PSME1', 'OXA1L', 'PCK2', 'SPR',
#         'CHEK1', 'TEX10', 'HOXA10', 'RTN2', 'LRRC41', 'TRIB3', 'DYNLT3',
# ...
#         'IGFBP3', 'PIK3CA', 'HIF1A', 'DNMT3A', 'DFFA', 'DAXX', 'CCND3',
#         'BAX', 'CDK4', 'CD40', 'PSMF1', 'PLK1', 'MIF', 'PLA2G4A', 'GRB7'],
#        dtype=object),
#  'MCF7_KW-2478': array(['RHEB', 'BMP4', 'SQSTM1', 'SUZ12', 'NFKBIA', 'RB1', 'SNCA',
#         'CDC25A', 'RALA', 'PLCB3', 'HSPA8', 'CDC20', 'CDKN1B', 'DNAJA3',
#         'ALDOA', 'PSMD9', 'CYCS', 'KIF2C', 'MNAT1', 'EIF4G1', 'NOTCH1',
#         'MKNK1', 'TFDP1', 'CALM3', 'EDN1', 'IFNAR1', 'PSMD2', 'EIF4EBP1',
#         'MMP2', 'MAPKAPK2', 'CHEK1', 'SHC1', 'PIK3CA', 'CSNK1E', 'AURKB',
#         'PGAM1', 'IGFBP3', 'DNMT3A', 'DFFA', 'BAX', 'HIF1A', 'CCND3',
#         'DAXX', 'CDK4', 'PSMF1', 'CD40', 'PLK1', 'PLA2G4A', 'MIF', 'GRB7'],
#        dtype=object),
#  'MCF7_protriptyline': array(['MMP2', 'NRAS', 'CDC20', 'APP', 'PIK3C3', 'SUZ12', 'PLCB3', 'CDK7',
#         'ALDOA', 'BNIP3L', 'NOTCH1', 'GAPDH', 'PSMD2', 'CDKN1B', 'PSMD9',
#         'EED', 'EDN1', 'NCK1', 'CYCS', 'CDC25A', 'EIF4EBP1', 'RALA',
#         'IFNAR1', 'AURKB', 'MAPKAPK2', 'EIF4G1', 'CALM3', 'MNAT1', 'CHEK1',
#         'SHC1', 'RB1', 'PGAM1', 'TFDP1', 'DFFA', 'DNMT3A', 'HSPA8',
#         'HIF1A', 'PIK3CA', 'IGFBP3', 'CSNK1E', 'BAX', 'CD40', 'PSMF1',
#         'PLA2G4A', 'DAXX', 'CCND3', 'PLK1', 'CDK4', 'MIF', 'GRB7'],
#        dtype=object),
#  'MCF7_nateglinide': array(['PTK2B', 'EDN1', 'PSME1', 'PLCB3', 'IGFBP3', 'PIK3C3', 'CLTC',
#         'NFKBIA', 'NOTCH1', 'PSMD2', 'APP', 'CDC25A', 'MKNK1', 'BNIP3L',
#         'TP53', 'CDK7', 'ALDOA', 'EIF4EBP1', 'MNAT1', 'PSMD9', 'NCK1',
#         'EED', 'MAPKAPK2', 'RALA', 'CDKN1B', 'IFNAR1', 'CHEK1', 'TFDP1',
#         'EIF4G1', 'CALM3', 'RB1', 'DFFA', 'HIF1A', 'DNMT3A', 'AURKB',
#         'SHC1', 'HSPA8', 'PIK3CA', 'CSNK1E', 'PGAM1', 'DAXX', 'CD40',
#         'BAX', 'CCND3', 'PSMF1', 'PLA2G4A', 'PLK1', 'MIF', 'CDK4', 'GRB7'],
#        dtype=object),
#  'PC3_betulinic-acid': array(['CDC25A', 'PLCB3', 'MMP2', 'TP53', 'CYCS', 'MKNK1', 'SQSTM1',
#         'EDN1', 'GAPDH', 'NFKBIA', 'DNAJA3', 'MNAT1', 'EIF4EBP1', 'CDK7',
#         'RALA', 'EED', 'RB1', 'PSMD9', 'NCK1', 'CDKN1B', 'EIF4G1', 'CLTC',
#         'CALM3', 'IGFBP3', 'SHC1', 'IFNAR1', 'NOTCH1', 'ALDOA', 'TFDP1',
#         'PSMD2', 'CHEK1', 'AURKB', 'MAPKAPK2', 'DFFA', 'PIK3CA', 'DNMT3A',
#         'CSNK1E', 'HIF1A', 'HSPA8', 'BAX', 'PGAM1', 'PSMF1', 'CD40',
#         'DAXX', 'CCND3', 'PLA2G4A', 'PLK1', 'CDK4', 'MIF', 'GRB7'],
#        dtype=object),
#  'PC3_paroxetine': array(['DFFA', 'MAPKAPK2', 'PRKCQ', 'TXNDC9', 'SHC1', 'CDK7', 'APP',
#         'PLA2G4A', 'TLR4', 'CASP7', 'ALDOA', 'ATF1', 'SUPV3L1', 'TP53',
#         'CD40', 'DNMT3A', 'HIF1A', 'CYCS', 'HSPA8', 'PIK3R4', 'CHEK1',
#         'SKP1', 'CALM3', 'PYCR1', 'FZD7', 'MNAT1', 'ZNF274', 'EIF4G1',
#         'NRAS', 'PSMF1', 'RB1', 'PIK3C3', 'BAX', 'RALGDS', 'PIK3CA',
#         'TFDP1', 'BNIP3L', 'CSNK1E', 'RALA', 'CDC25A', 'NCK1', 'EED',
#         'PGAM1', 'ASAH1', 'DAXX', 'PLK1', 'MIF', 'GRB7', 'CCND3', 'CDK4'],
#        dtype=object),
#  'PC3_imipramine': array(['TERT', 'CEBPD', 'TES', 'C5', 'CDK4', 'PTPRC', 'UBE2L6', 'SNX7',
#         'ZNF395', 'SHB', 'HIST2H2BE', 'RB1', 'APP', 'NCK1', 'BNIP3L',
#         'NFKBIA', 'ZNF274', 'MEST', 'ARNT2', 'SERPINE1', 'MIF', 'CASP10',
#         'MMP2', 'MKNK1', 'CALM3', 'HIF1A', 'ASAH1', 'IGFBP3', 'FGFR2',
#         'PTK2B', 'SHC1', 'ZFP36', 'FAM69A', 'DAXX', 'PLEKHM1', 'P4HTM',
#         'FZD1', 'DNAJA3', 'CCND3', 'PSMF1', 'CTNND1', 'BMP4', 'DNMT3A',
#         'MYL9', 'EDN1', 'IFNAR1', 'PIK3CA', 'PLA2G4A', 'CD40', 'GRB7'],
#        dtype=object),
#  'PC3_AICA-ribonucleotide': array(['HSPA8', 'SOX2', 'AURKB', 'EED', 'APP', 'CYCS', 'ALDOA', 'FZD1',
#         'NOTCH1', 'NFKBIA', 'PYCR1', 'CCND3', 'PIK3C3', 'ASAH1',
#         'MAPKAPK2', 'DFFB', 'NRAS', 'EIF4G1', 'RALGDS', 'CDKN1B', 'RALA',
#         'PGAM1', 'EDN1', 'PTK2B', 'MNAT1', 'PSMD2', 'NCK1', 'DAXX',
#         'PIK3CA', 'CSNK1E', 'MKNK1', 'MMP2', 'CLTC', 'SHC1', 'CALM3',
#         'CHEK1', 'DFFA', 'PLK1', 'IFNAR1', 'RB1', 'HIF1A', 'CDK4',
#         'IGFBP3', 'MIF', 'DNMT3A', 'PLA2G4A', 'CD40', 'BAX', 'PSMF1',
#         'GRB7'], dtype=object),
#  'PC3_vinburnine': array(['ORC1', 'NFATC3', 'CDK7', 'CDKN1B', 'FZD1', 'NFKBIA', 'RB1',
#         'EIF4EBP1', 'PLEKHM1', 'PSMD9', 'TFDP1', 'TERT', 'RALA', 'CHEK1',
#         'APP', 'ALDOA', 'NCK1', 'MNAT1', 'FGFR2', 'PSMD2', 'PTK2B',
#         'IGFBP3', 'MKNK1', 'EIF4G1', 'NOTCH1', 'MAPKAPK2', 'EDN1', 'AURKB',
#         'PGAM1', 'CALM3', 'HSPA8', 'CSNK1E', 'IFNAR1', 'SHC1', 'DNAJA3',
#         'HIF1A', 'PIK3CA', 'DFFA', 'MMP2', 'PLK1', 'BAX', 'DNMT3A',
#         'CCND3', 'DAXX', 'CDK4', 'PSMF1', 'MIF', 'CD40', 'PLA2G4A', 'GRB7'],
#        dtype=object),
#  'PC3_valproic-acid': array(['PIK3R4', 'PIK3CA', 'HMOX1', 'METRN', 'RALA', 'CASP7', 'CCL2',
#         'TLR4', 'ATF1', 'ITGB5', 'XPO7', 'ATF6', 'GTF2E2', 'COPB2', 'SMC3',
#         'TFDP1', 'S100A4', 'GLRX', 'CHP1', 'HSPA1A', 'ADAM10', 'TPM1',
#         'PIK3C3', 'SERPINE1', 'CHEK1', 'SHC1', 'PRKCQ', 'CDK7', 'ERBB3',
#         'COL4A1', 'DCTD', 'BAX', 'PLK1', 'DAXX', 'DDIT4', 'CDK4', 'PYCR1',
#         'RALB', 'GRB7', 'CDC25B', 'ACLY', 'NRAS', 'TP53', 'CCND3', 'NCK1',
#         'ZNF274', 'RB1', 'ASAH1', 'PSME1', 'GAPDH'], dtype=object),
#  'PC3_ORG-9768': array(['RHEB', 'CDC25A', 'CDK7', 'CLTC', 'RB1', 'SNCA', 'NFKBIA', 'PTK2B',
#         'CDKN1B', 'SQSTM1', 'APP', 'RALA', 'CDC20', 'ALDOA', 'TFDP1',
#         'MNAT1', 'EIF4EBP1', 'PSMD9', 'KIF2C', 'MKNK1', 'CHEK1', 'CALM3',
#         'EIF4G1', 'SHC1', 'EDN1', 'IFNAR1', 'NOTCH1', 'MMP2', 'PSMD2',
#         'AURKB', 'PGAM1', 'DNAJA3', 'HSPA8', 'CSNK1E', 'MAPKAPK2',
#         'IGFBP3', 'PIK3CA', 'HIF1A', 'DNMT3A', 'DFFA', 'DAXX', 'CCND3',
#         'BAX', 'CDK4', 'CD40', 'PSMF1', 'PLK1', 'MIF', 'PLA2G4A', 'GRB7'],
#        dtype=object),
#  'PC3_KW-2478': array(['RHEB', 'BMP4', 'SQSTM1', 'SUZ12', 'NFKBIA', 'RB1', 'SNCA',
#         'CDC25A', 'RALA', 'PLCB3', 'HSPA8', 'CDC20', 'CDKN1B', 'DNAJA3',
#         'ALDOA', 'PSMD9', 'CYCS', 'KIF2C', 'MNAT1', 'EIF4G1', 'NOTCH1',
#         'MKNK1', 'TFDP1', 'CALM3', 'EDN1', 'IFNAR1', 'PSMD2', 'EIF4EBP1',
#         'MMP2', 'MAPKAPK2', 'CHEK1', 'SHC1', 'PIK3CA', 'CSNK1E', 'AURKB',
#         'PGAM1', 'IGFBP3', 'DNMT3A', 'DFFA', 'BAX', 'HIF1A', 'CCND3',
#         'DAXX', 'CDK4', 'PSMF1', 'CD40', 'PLK1', 'PLA2G4A', 'MIF', 'GRB7'],
#        dtype=object),
#  'PC3_protriptyline': array(['MMP2', 'NRAS', 'CDC20', 'APP', 'PIK3C3', 'SUZ12', 'PLCB3', 'CDK7',
#         'ALDOA', 'BNIP3L', 'NOTCH1', 'GAPDH', 'PSMD2', 'CDKN1B', 'PSMD9',
#         'EED', 'EDN1', 'NCK1', 'CYCS', 'CDC25A', 'EIF4EBP1', 'RALA',
#         'IFNAR1', 'AURKB', 'MAPKAPK2', 'EIF4G1', 'CALM3', 'MNAT1', 'CHEK1',
#         'SHC1', 'RB1', 'PGAM1', 'TFDP1', 'DFFA', 'DNMT3A', 'HSPA8',
#         'HIF1A', 'PIK3CA', 'IGFBP3', 'CSNK1E', 'BAX', 'CD40', 'PSMF1',
#         'PLA2G4A', 'DAXX', 'CCND3', 'PLK1', 'CDK4', 'MIF', 'GRB7'],
#        dtype=object),
#  'PC3_nateglinide': array(['PTK2B', 'EDN1', 'PSME1', 'PLCB3', 'IGFBP3', 'PIK3C3', 'CLTC',
#         'NFKBIA', 'NOTCH1', 'PSMD2', 'APP', 'CDC25A', 'MKNK1', 'BNIP3L',
#         'TP53', 'CDK7', 'ALDOA', 'EIF4EBP1', 'MNAT1', 'PSMD9', 'NCK1',
#         'EED', 'MAPKAPK2', 'RALA', 'CDKN1B', 'IFNAR1', 'CHEK1', 'TFDP1',
#         'EIF4G1', 'CALM3', 'RB1', 'DFFA', 'HIF1A', 'DNMT3A', 'AURKB',
#         'SHC1', 'HSPA8', 'PIK3CA', 'CSNK1E', 'PGAM1', 'DAXX', 'CD40',
#         'BAX', 'CCND3', 'PSMF1', 'PLA2G4A', 'PLK1', 'MIF', 'CDK4', 'GRB7'],
#        dtype=object),
#  'YAPC_betulinic-acid': array(['CDC25A', 'PLCB3', 'MMP2', 'TP53', 'CYCS', 'MKNK1', 'SQSTM1',
#         'EDN1', 'GAPDH', 'NFKBIA', 'DNAJA3', 'MNAT1', 'EIF4EBP1', 'CDK7',
#         'RALA', 'EED', 'RB1', 'PSMD9', 'NCK1', 'CDKN1B', 'EIF4G1', 'CLTC',
#         'CALM3', 'IGFBP3', 'SHC1', 'IFNAR1', 'NOTCH1', 'ALDOA', 'TFDP1',
#         'PSMD2', 'CHEK1', 'AURKB', 'MAPKAPK2', 'DFFA', 'PIK3CA', 'DNMT3A',
#         'CSNK1E', 'HIF1A', 'HSPA8', 'BAX', 'PGAM1', 'PSMF1', 'CD40',
#         'DAXX', 'CCND3', 'PLA2G4A', 'PLK1', 'CDK4', 'MIF', 'GRB7'],
#        dtype=object),
#  'YAPC_paroxetine': array(['DFFA', 'MAPKAPK2', 'PRKCQ', 'TXNDC9', 'SHC1', 'CDK7', 'APP',
#         'PLA2G4A', 'TLR4', 'CASP7', 'ALDOA', 'ATF1', 'SUPV3L1', 'TP53',
#         'CD40', 'DNMT3A', 'HIF1A', 'CYCS', 'HSPA8', 'PIK3R4', 'CHEK1',
#         'SKP1', 'CALM3', 'PYCR1', 'FZD7', 'MNAT1', 'ZNF274', 'EIF4G1',
#         'NRAS', 'PSMF1', 'RB1', 'PIK3C3', 'BAX', 'RALGDS', 'PIK3CA',
#         'TFDP1', 'BNIP3L', 'CSNK1E', 'RALA', 'CDC25A', 'NCK1', 'EED',
#         'PGAM1', 'ASAH1', 'DAXX', 'PLK1', 'MIF', 'GRB7', 'CCND3', 'CDK4'],
#        dtype=object),
#  'YAPC_imipramine': array(['TERT', 'CEBPD', 'TES', 'C5', 'CDK4', 'PTPRC', 'UBE2L6', 'SNX7',
#         'ZNF395', 'SHB', 'HIST2H2BE', 'RB1', 'APP', 'NCK1', 'BNIP3L',
#         'NFKBIA', 'ZNF274', 'MEST', 'ARNT2', 'SERPINE1', 'MIF', 'CASP10',
#         'MMP2', 'MKNK1', 'CALM3', 'HIF1A', 'ASAH1', 'IGFBP3', 'FGFR2',
#         'PTK2B', 'SHC1', 'ZFP36', 'FAM69A', 'DAXX', 'PLEKHM1', 'P4HTM',
#         'FZD1', 'DNAJA3', 'CCND3', 'PSMF1', 'CTNND1', 'BMP4', 'DNMT3A',
#         'MYL9', 'EDN1', 'IFNAR1', 'PIK3CA', 'PLA2G4A', 'CD40', 'GRB7'],
#        dtype=object),
#  'YAPC_AICA-ribonucleotide': array(['HSPA8', 'SOX2', 'AURKB', 'EED', 'APP', 'CYCS', 'ALDOA', 'FZD1',
#         'NOTCH1', 'NFKBIA', 'PYCR1', 'CCND3', 'PIK3C3', 'ASAH1',
#         'MAPKAPK2', 'DFFB', 'NRAS', 'EIF4G1', 'RALGDS', 'CDKN1B', 'RALA',
#         'PGAM1', 'EDN1', 'PTK2B', 'MNAT1', 'PSMD2', 'NCK1', 'DAXX',
#         'PIK3CA', 'CSNK1E', 'MKNK1', 'MMP2', 'CLTC', 'SHC1', 'CALM3',
#         'CHEK1', 'DFFA', 'PLK1', 'IFNAR1', 'RB1', 'HIF1A', 'CDK4',
#         'IGFBP3', 'MIF', 'DNMT3A', 'PLA2G4A', 'CD40', 'BAX', 'PSMF1',
#         'GRB7'], dtype=object),
#  'YAPC_vinburnine': array(['ORC1', 'NFATC3', 'CDK7', 'CDKN1B', 'FZD1', 'NFKBIA', 'RB1',
#         'EIF4EBP1', 'PLEKHM1', 'PSMD9', 'TFDP1', 'TERT', 'RALA', 'CHEK1',
#         'APP', 'ALDOA', 'NCK1', 'MNAT1', 'FGFR2', 'PSMD2', 'PTK2B',
#         'IGFBP3', 'MKNK1', 'EIF4G1', 'NOTCH1', 'MAPKAPK2', 'EDN1', 'AURKB',
#         'PGAM1', 'CALM3', 'HSPA8', 'CSNK1E', 'IFNAR1', 'SHC1', 'DNAJA3',
#         'HIF1A', 'PIK3CA', 'DFFA', 'MMP2', 'PLK1', 'BAX', 'DNMT3A',
#         'CCND3', 'DAXX', 'CDK4', 'PSMF1', 'MIF', 'CD40', 'PLA2G4A', 'GRB7'],
#        dtype=object),
#  'YAPC_valproic-acid': array(['PIK3R4', 'PIK3CA', 'HMOX1', 'METRN', 'RALA', 'CASP7', 'CCL2',
#         'TLR4', 'ATF1', 'ITGB5', 'XPO7', 'ATF6', 'GTF2E2', 'COPB2', 'SMC3',
#         'TFDP1', 'S100A4', 'GLRX', 'CHP1', 'HSPA1A', 'ADAM10', 'TPM1',
#         'PIK3C3', 'SERPINE1', 'CHEK1', 'SHC1', 'PRKCQ', 'CDK7', 'ERBB3',
#         'COL4A1', 'DCTD', 'BAX', 'PLK1', 'DAXX', 'DDIT4', 'CDK4', 'PYCR1',
#         'RALB', 'GRB7', 'CDC25B', 'ACLY', 'NRAS', 'TP53', 'CCND3', 'NCK1',
#         'ZNF274', 'RB1', 'ASAH1', 'PSME1', 'GAPDH'], dtype=object),
#  'YAPC_ORG-9768': array(['RHEB', 'CDC25A', 'CDK7', 'CLTC', 'RB1', 'SNCA', 'NFKBIA', 'PTK2B',
#         'CDKN1B', 'SQSTM1', 'APP', 'RALA', 'CDC20', 'ALDOA', 'TFDP1',
#         'MNAT1', 'EIF4EBP1', 'PSMD9', 'KIF2C', 'MKNK1', 'CHEK1', 'CALM3',
#         'EIF4G1', 'SHC1', 'EDN1', 'IFNAR1', 'NOTCH1', 'MMP2', 'PSMD2',
#         'AURKB', 'PGAM1', 'DNAJA3', 'HSPA8', 'CSNK1E', 'MAPKAPK2',
#         'IGFBP3', 'PIK3CA', 'HIF1A', 'DNMT3A', 'DFFA', 'DAXX', 'CCND3',
#         'BAX', 'CDK4', 'CD40', 'PSMF1', 'PLK1', 'MIF', 'PLA2G4A', 'GRB7'],
#        dtype=object),
#  'YAPC_KW-2478': array(['RHEB', 'BMP4', 'SQSTM1', 'SUZ12', 'NFKBIA', 'RB1', 'SNCA',
#         'CDC25A', 'RALA', 'PLCB3', 'HSPA8', 'CDC20', 'CDKN1B', 'DNAJA3',
#         'ALDOA', 'PSMD9', 'CYCS', 'KIF2C', 'MNAT1', 'EIF4G1', 'NOTCH1',
#         'MKNK1', 'TFDP1', 'CALM3', 'EDN1', 'IFNAR1', 'PSMD2', 'EIF4EBP1',
#         'MMP2', 'MAPKAPK2', 'CHEK1', 'SHC1', 'PIK3CA', 'CSNK1E', 'AURKB',
#         'PGAM1', 'IGFBP3', 'DNMT3A', 'DFFA', 'BAX', 'HIF1A', 'CCND3',
#         'DAXX', 'CDK4', 'PSMF1', 'CD40', 'PLK1', 'PLA2G4A', 'MIF', 'GRB7'],
#        dtype=object),
#  'YAPC_protriptyline': array(['MMP2', 'NRAS', 'CDC20', 'APP', 'PIK3C3', 'SUZ12', 'PLCB3', 'CDK7',
#         'ALDOA', 'BNIP3L', 'NOTCH1', 'GAPDH', 'PSMD2', 'CDKN1B', 'PSMD9',
#         'EED', 'EDN1', 'NCK1', 'CYCS', 'CDC25A', 'EIF4EBP1', 'RALA',
#         'IFNAR1', 'AURKB', 'MAPKAPK2', 'EIF4G1', 'CALM3', 'MNAT1', 'CHEK1',
#         'SHC1', 'RB1', 'PGAM1', 'TFDP1', 'DFFA', 'DNMT3A', 'HSPA8',
#         'HIF1A', 'PIK3CA', 'IGFBP3', 'CSNK1E', 'BAX', 'CD40', 'PSMF1',
#         'PLA2G4A', 'DAXX', 'CCND3', 'PLK1', 'CDK4', 'MIF', 'GRB7'],
#        dtype=object),
#  'YAPC_nateglinide': array(['PTK2B', 'EDN1', 'PSME1', 'PLCB3', 'IGFBP3', 'PIK3C3', 'CLTC',
#         'NFKBIA', 'NOTCH1', 'PSMD2', 'APP', 'CDC25A', 'MKNK1', 'BNIP3L',
#         'TP53', 'CDK7', 'ALDOA', 'EIF4EBP1', 'MNAT1', 'PSMD9', 'NCK1',
#         'EED', 'MAPKAPK2', 'RALA', 'CDKN1B', 'IFNAR1', 'CHEK1', 'TFDP1',
#         'EIF4G1', 'CALM3', 'RB1', 'DFFA', 'HIF1A', 'DNMT3A', 'AURKB',
#         'SHC1', 'HSPA8', 'PIK3CA', 'CSNK1E', 'PGAM1', 'DAXX', 'CD40',
#         'BAX', 'CCND3', 'PSMF1', 'PLA2G4A', 'PLK1', 'MIF', 'CDK4', 'GRB7'],
#        dtype=object),
#  'A375_omeprazole': array(['RALA', 'HSD17B10', 'GAPDH', 'ABCC5', 'PSME1', 'ZDHHC6', 'MIF',
#         'SKP1', 'PSMD9', 'PGAM1', 'PSMD2', 'RNF167', 'MYL9', 'MEF2C',
#         'CHP1', 'DUSP22', 'MRPL12', 'APOE', 'PSMB8', 'SLC35F2', 'GPER1',
#         'SPP1', 'ALDOA', 'BMP4', 'IER3', 'BAD', 'CCND3', 'FHL2', 'YTHDF1',
#         'CYCS', 'AKR7A2', 'GNAI1', 'TIPARP', 'MBTPS1', 'BNIP3L', 'CTNND1',
#         'HSPA8', 'ISOC1', 'HTRA1', 'CHEK1', 'CDK4', 'GRB7', 'FOSL1',
#         'PRKCQ', 'DYNLT3', 'ZNF274', 'TFAP2A', 'METRN', 'MELK', 'MFSD10'],
#        dtype=object),
#  'A375_testosterone': array(['CYCS', 'GNAS', 'FZD1', 'CCNA2', 'MAT2A', 'ISOC1', 'TFAP2A',
#         'METRN', 'SHB', 'ETS1', 'EXT1', 'SNCA', 'PPP1R13B', 'PGAM1',
#         'CTNNAL1', 'MYC', 'SHC1', 'HTRA1', 'CDKN2A', 'SPP1', 'CEBPA',
#         'CCNB1', 'LRRC41', 'GNAI1', 'BMP4', 'DFFA', 'PSMD9', 'SLC27A3',
#         'COL4A1', 'MBTPS1', 'EDN1', 'HIF1A', 'IFNAR1', 'DNMT3A', 'BAX',
#         'CHAC1', 'MIF', 'MYL9', 'CTNND1', 'HSPA8', 'PSMD2', 'CHEK1',
#         'PLA2G4A', 'S100A4', 'DNAJA3', 'CD40', 'GRB7', 'PYCR1', 'MFSD10',
#         'MELK'], dtype=object),
#  'A375_triamcinolone-acetonide': array(['CEBPA', 'GTPBP8', 'IFRD2', 'BID', 'CCND3', 'PRPF4', 'CDK4',
#         'TSC22D3', 'GADD45B', 'ALAS1', 'DUSP22', 'FZD7', 'ZNF395', 'BPHL',
#         'NPEPL1', 'TIPARP', 'PLEKHM1', 'PLSCR1', 'GAPDH', 'SFN', 'ISOC1',
#         'CYCS', 'TARBP1', 'PSIP1', 'RGS2', 'CD58', 'BNIP3L', 'PRKCQ',
#         'BAD', 'ASAH1', 'SHB', 'ZDHHC6', 'NARFL', 'CCND1', 'APOE', 'SKP1',
#         'MMP2', 'CLIC4', 'DCK', 'KIF2C', 'NPDC1', 'PAICS', 'PAF1',
#         'MRPL12', 'METRN', 'MELK', 'DYNLT3', 'ZNF274', 'TFAP2A', 'MFSD10'],
#        dtype=object),
#  'HA1E_omeprazole': array(['RALA', 'HSD17B10', 'GAPDH', 'ABCC5', 'PSME1', 'ZDHHC6', 'MIF',
#         'SKP1', 'PSMD9', 'PGAM1', 'PSMD2', 'RNF167', 'MYL9', 'MEF2C',
#         'CHP1', 'DUSP22', 'MRPL12', 'APOE', 'PSMB8', 'SLC35F2', 'GPER1',
#         'SPP1', 'ALDOA', 'BMP4', 'IER3', 'BAD', 'CCND3', 'FHL2', 'YTHDF1',
#         'CYCS', 'AKR7A2', 'GNAI1', 'TIPARP', 'MBTPS1', 'BNIP3L', 'CTNND1',
#         'HSPA8', 'ISOC1', 'HTRA1', 'CHEK1', 'CDK4', 'GRB7', 'FOSL1',
#         'PRKCQ', 'DYNLT3', 'ZNF274', 'TFAP2A', 'METRN', 'MELK', 'MFSD10'],
#        dtype=object),
#  'HA1E_testosterone': array(['CYCS', 'GNAS', 'FZD1', 'CCNA2', 'MAT2A', 'ISOC1', 'TFAP2A',
#         'METRN', 'SHB', 'ETS1', 'EXT1', 'SNCA', 'PPP1R13B', 'PGAM1',
#         'CTNNAL1', 'MYC', 'SHC1', 'HTRA1', 'CDKN2A', 'SPP1', 'CEBPA',
#         'CCNB1', 'LRRC41', 'GNAI1', 'BMP4', 'DFFA', 'PSMD9', 'SLC27A3',
#         'COL4A1', 'MBTPS1', 'EDN1', 'HIF1A', 'IFNAR1', 'DNMT3A', 'BAX',
#         'CHAC1', 'MIF', 'MYL9', 'CTNND1', 'HSPA8', 'PSMD2', 'CHEK1',
#         'PLA2G4A', 'S100A4', 'DNAJA3', 'CD40', 'GRB7', 'PYCR1', 'MFSD10',
#         'MELK'], dtype=object),
#  'HA1E_triamcinolone-acetonide': array(['CEBPA', 'GTPBP8', 'IFRD2', 'BID', 'CCND3', 'PRPF4', 'CDK4',
#         'TSC22D3', 'GADD45B', 'ALAS1', 'DUSP22', 'FZD7', 'ZNF395', 'BPHL',
#         'NPEPL1', 'TIPARP', 'PLEKHM1', 'PLSCR1', 'GAPDH', 'SFN', 'ISOC1',
#         'CYCS', 'TARBP1', 'PSIP1', 'RGS2', 'CD58', 'BNIP3L', 'PRKCQ',
#         'BAD', 'ASAH1', 'SHB', 'ZDHHC6', 'NARFL', 'CCND1', 'APOE', 'SKP1',
#         'MMP2', 'CLIC4', 'DCK', 'KIF2C', 'NPDC1', 'PAICS', 'PAF1',
#         'MRPL12', 'METRN', 'MELK', 'DYNLT3', 'ZNF274', 'TFAP2A', 'MFSD10'],
#        dtype=object),
#  ...}

# %%
adata.obs['split'] = 'train'

# take ood from top occurring perturbations to avoid losing data on low occ ones
ood_idx = sc.pp.subsample(
    adata[adata.obs.condition.isin(list(adata.obs.condition.value_counts().index[1:50]))],
    .1,
    copy=True
).obs.index
adata.obs['split'].loc[ood_idx] = 'ood'

# take test from a random subsampling of the rest
test_idx = sc.pp.subsample(
    adata[adata.obs.split != 'ood'],
    .16,
    copy=True
).obs.index
adata.obs['split'].loc[test_idx] = 'test'

# %%
pd.crosstab(adata.obs['split'], adata.obs['condition'])
# Out:
# condition  1B Parent  2-methoxyestradiol  3,6-dimethoxyflavone  \
# split
# ood                0                   0                     0
# test               2                  17                     4
# train             20                 100                    30
#
# condition  3-amino-benzamide  5-methoxy-alpha-methyltryptamine  ABT-737  \
# split
# ood                        0                                 0       64
# test                      59                                 4      125
# train                    343                                14      583
#
# condition  AG-490  AG-14361  AICA-ribonucleotide  ALW-II-38-3  ...  veliparib  \
# split                                                          ...
# ood             0         0                    0            0  ...        135
# test           23        66                   50           89  ...        188
# train         130       272                  249          509  ...        936
#
# condition  vinburnine  voglibose  wiskostatin  xanthohumol  xanthoxyline  \
# split
# ood                 0          0            0            0             0
# test               24         20            7            9             9
# train             150        105           58           58            53
#
# condition  yohimbine  zacopride  zaprinast  zileuton
# split
# ood                0          0          0         0
# test              60         26         33        51
# train            266         81        175       279
#
# [3 rows x 1001 columns]

# %%
try: 
    del(adata.uns['rank_genes_groups'])  # too large
except: 
    print('All good.')

# %%
# code compatibility
from scipy import sparse
adata.X = sparse.csr_matrix(adata.X)

# %%
sc.write(adata_out, adata)

# %%
print('all done.')
# Out:
# all done.

# %% [markdown]
# ### Check that `adata.uns[rank_genes_groups_cov]` has all entries in `adata.obs.cov_drug_dose_name` as keys

# %%
for i, k in enumerate(adata.obs.eval_category.unique()):
    try: 
        adata.uns['rank_genes_groups_cov'][k]
    except: 
        print(f"{i}: {k}") if 'DMSO' not in k else None

# %% [markdown]
# ### Checking the same for the stored adata object

# %%
adata_2 = sc.read(adata_out)

# %%
for i, k in enumerate(adata_2.obs.eval_category.unique()):
    try: 
        adata_2.uns['rank_genes_groups_cov'][k]
    except: 
        print(f"{i}: {k}") if 'DMSO' not in k else None

# %%
set(list(adata.uns['rank_genes_groups_cov'])) - set((list(adata_2.uns['rank_genes_groups_cov'])))
# Out:
# set()

# %%
set((list(adata_2.uns['rank_genes_groups_cov']))) - set(list(adata.uns['rank_genes_groups_cov']))
# Out:
# set()
